# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Vấn đề:
# - Xem xét bộ phận máy móc CNC (Computer Numerical Control), nơi các máy cần nguyên liệu thô để hoàn thành quá trình gia công. Để đáp ứng yêu cầu nguyên vật liệu thô từ các máy, đơn đặt hàng nguyên vật liệu thô được đặt tại kho nguyên vật liệu thô, được giả định có công suất vô hạn. Các công nhân vận hành máy kiểm tra mức tồn kho nguyên vật liệu thô mỗi chu kỳ t (mỗi ngày) và nhận nguyên vật liệu thô được yêu cầu sau một chu kỳ (tức là thời gian giao hàng - procurement lead time), được giả định là hằng số và bằng một ngày (nguyên vật liệu thô luôn được giao vào ngày làm việc tiếp theo). Phân tích này được thực hiện cho máy móc quan trọng (critical machine) và lượng tiêu thụ nguyên vật liệu thô là độc lập và được phân phối theo phân phối chuẩn (normal distribution) với giá trị trung bình μ và độ lệch chuẩn σ
#
# # Input:
# ## Chi phí kho
# - O = 50.0 # Chi phí đặt hàng
# - h_year = 10.0 # Chi phí lưu trữ (10 đô cho 1 sản phẩm / năm)
# - b = 20.0 # Chi phí thiếu hàng (20 đô cho 1 mỗi sản phẩm tồn đọng)
# - LT = 1 # Lead Time = 1 ngày (đơn hàng được đặt hôm nay sẽ đến vào ngày kế tiếp)
# - days_per_year = 365 # Số ngày trong một năm
# - h = h_year/days_per_year # Chi phí lưu trữ quy đổi theo ngày
# - q = 6 # Số lượng đặt hàng mỗi lần
# - r = 3 # Mức tồn kho đặt hàng lại (reorder point) => đây là miêu tả bài toán không phải chi phí kho
#
# ## Nhu cầu
# - mu = 3.0        # Nhu cầu trung bình mỗi ngày
# - sigma = 1.0     # Độ lệch chuẩn của nhu cầu
#
# ## Tham số của Q-learning
# - alpha = 0.5 # Tốc độ học
# - gamma = 0.9 # Hệ số chiết khấu (gamma trong khoảng từ 0=>1)
# - num_episodes = 1000      # tổng số chu kỳ học
# - episode_length = 1000    # mỗi chu kỳ = 1000 ngày mô phỏng
#
# # Output:
# - Chính sách nhập hàng tối ưu gồm:
# + Số lượng hàng trong kho không quá nhiều, đủ để máy chạy mà không thiếu nguyên liệu => Chi phí lưu kho và chi phí thiếu hàng sẽ giảm
# + không bị thiếu hàng quá nhiều => Dẫn đến máy không có nguyên liệu và hình phạt nặng do chi phí thiếu hàng lớn sẽ làm cho daily cost tăng
# +
#
# # Độ đo: trong bài báo không đề cập

# %%
# Khởi tạo tham số cho mô hình
# Chi phí kho
O = 50.0 # Chi phí đặt hàng
h_year = 10.0 # Chi phí lưu trữ (10 đô cho 1 sản phẩm / năm)
b = 20.0 # Chi phí thiếu hàng (20 đô cho 1 mỗi sản phẩm tồn đọng)
LT = 1 # Lead Time = 1 ngày (đơn hàng được đặt hôm nay sẽ đến vào ngày kế tiếp)
days_per_year = 365 # Số ngày trong một năm
h = h_year/days_per_year # Chi phí lưu trữ quy đổi theo ngày
q = 6 # Số lượng đặt hàng mỗi lần
r = 3 # Mức tồn kho đặt hàng lại (reorder point)

# Nhu cầu
mu = 3.0        # Nhu cầu trung bình mỗi ngày
sigma = 1.0     # Độ lệch chuẩn của nhu cầu

# Tham số của Q-learning
alpha = 0.5 # Tốc độ học
gamma = 0.5 # Hệ số chiết khấu (0<gamma<1)
epsilon = 0.1 # Hệ số khám phá là 10%
num_episodes = 1000      # tổng số chu kỳ học
episode_length = 1000    # mỗi chu kỳ = 1000 ngày mô phỏng

# %%
# Tính safety stock theo mức dịch vụ SL và cập nhật r trước khi huấn luyện/evaluate
from scipy.stats import norm  # nếu không có scipy, dùng z=1.645 cho SL=95%

SL = 0.95
z = norm.ppf(SL)  # ~1.645
safety_stock = z * sigma * np.sqrt(LT)
recommended_r = int(np.ceil(mu * LT + safety_stock))

print(f"SL={SL*100:.0f}%, z={z:.3f}, safety_stock={safety_stock:.2f}, recommended r={recommended_r}")

r = recommended_r  # cập nhật reorder point để phản ánh SL
# Out:
# SL=95%, z=1.645, safety_stock=1.64, recommended r=5

# %%
# Môi trường học (state, action)

# Trạng thái: vị trí tồn kho (inventory position)
# Dải giá trị tồn kho [-20, 20] (âm = thiếu hàng)
min_IP, max_IP = -20, 20
states = np.arange(min_IP, max_IP + 1)

# Hành động: 0 = không đặt hàng, 1 = đặt hàng (số lượng q)
actions = [0, 1]

# Khởi tạo bảng Q-table (số trạng thái x số hành động)
Q = np.zeros((len(states), len(actions)))

def ip_to_index(ip):
    """Chuyển giá trị tồn kho sang chỉ số mảng Q-table """
    return int(np.clip(round(ip), min_IP, max_IP)) - min_IP


def sample_demand():
    """Tạo nhu cầu ngẫu nhiên theo phân phối chuẩn N(μ, σ), không âm."""
    d = np.random.normal(mu, sigma)
    return max(0, int(round(d)))


def step(ip, orders_in_transit, action):
    # Nhập hàng đến
    arrivals = 0
    if orders_in_transit > 0:
        arrivals = orders_in_transit
        orders_in_transit = 0

    # Cập nhật tồn kho sau khi nhận hàng
    ip_after_arrival = ip + arrivals

    # Trừ đi nhu cầu
    d = sample_demand()
    ip_after_demand = ip_after_arrival - d

    # Nếu hành động = đặt hàng → đơn hàng sẽ đến vào ngày sau
    order_placed = False
    if action == 1:
        order_placed = True
        orders_in_transit = q
    
    # Tính chi phí
    holding_cost = h * max(ip_after_demand, 0)
    backorder_cost = b * max(-ip_after_demand, 0)
    ordering_cost = O if order_placed else 0

    # HÌNH PHẠT: nếu tồn kho < r và không đặt hàng thì phạt 200
    penalty = 0.0
    if ip_after_demand < r and not order_placed:
        penalty = 200.0

    total_cost = holding_cost + backorder_cost + ordering_cost + penalty

    # Phần thưởng = -chi phí (RL muốn tối đa hóa reward)
    reward = -total_cost
    next_ip = ip_after_demand

    return next_ip, reward, orders_in_transit, total_cost

# %%
# ...existing code...
# -----------------------------
# 5️⃣ Vòng lặp huấn luyện Q-learning (epsilon cố định = 0.1, in log từng episode)
# -----------------------------
episode_costs = []
episode_holding = []
episode_backorder = []
episode_ordering = []

epsilon = 0.1  # Xác suất khám phá cố định

for ep in range(num_episodes):

    ip = r  # tồn kho ban đầu = điểm đặt hàng lại
    orders_in_transit = 0
    total_cost_ep = 0
    holding_ep = 0
    backorder_ep = 0
    ordering_ep = 0

    for day in range(episode_length):
        s_idx = ip_to_index(ip)

        # Epsilon-greedy: khám phá hoặc khai thác
        if np.random.rand() < epsilon:
            a = np.random.choice(actions)
        else:
            qvals = Q[s_idx, :]
            a = np.random.choice(np.flatnonzero(qvals == qvals.max()))

        # --- Mô phỏng một bước ---
        arrivals = 0
        if orders_in_transit > 0:
            arrivals = orders_in_transit
            orders_in_transit = 0

        ip_after_arrival = ip + arrivals
        d = sample_demand()
        ip_after_demand = ip_after_arrival - d

        order_placed = False
        if a == 1:
            order_placed = True
            orders_in_transit = q

        holding_cost = h * max(ip_after_demand, 0)
        backorder_cost = b * max(-ip_after_demand, 0)
        ordering_cost = O if order_placed else 0

        # HÌNH PHẠT: nếu tồn kho < r và không đặt hàng thì phạt 200
        penalty = 0.0
        if ip_after_demand < r and not order_placed:
            penalty = 200.0

        total_cost = holding_cost + backorder_cost + ordering_cost + penalty

        reward = -total_cost
        next_ip = ip_after_demand

        # --- Cập nhật Q-learning ---
        s_next = ip_to_index(next_ip)
        Q[s_idx, a] += alpha * (reward + gamma * np.max(Q[s_next, :]) - Q[s_idx, a])

        # --- Cộng dồn chi phí ---
        total_cost_ep += total_cost
        holding_ep += holding_cost
        backorder_ep += backorder_cost
        ordering_ep += ordering_cost

        ip = next_ip

    # Lưu kết quả của episode này
    episode_costs.append(total_cost_ep)
    episode_holding.append(holding_ep)
    episode_backorder.append(backorder_ep)
    episode_ordering.append(ordering_ep)

    # ✅ In ra từng episode
    print(f"Episode {ep + 1}/{num_episodes} | Tổng chi phí: {total_cost_ep:.2f} "
          f"(Holding={holding_ep:.2f}, Backorder={backorder_ep:.2f}, Ordering={ordering_ep:.2f})")

print("\n✅ Huấn luyện hoàn tất.")
# ...existing code...
# Out:
# Episode 1/1000 | Tổng chi phí: 36025.12 (Holding=225.12, Backorder=2100.00, Ordering=24900.00)
# Episode 2/1000 | Tổng chi phí: 30085.67 (Holding=225.67, Backorder=460.00, Ordering=25600.00)
# Episode 3/1000 | Tổng chi phí: 30096.19 (Holding=256.19, Backorder=440.00, Ordering=25200.00)
# Episode 4/1000 | Tổng chi phí: 29405.81 (Holding=225.81, Backorder=680.00, Ordering=24900.00)
# Episode 5/1000 | Tổng chi phí: 31417.78 (Holding=237.78, Backorder=980.00, Ordering=25000.00)
# Episode 6/1000 | Tổng chi phí: 29838.03 (Holding=238.03, Backorder=300.00, Ordering=25100.00)
# Episode 7/1000 | Tổng chi phí: 30081.37 (Holding=211.37, Backorder=320.00, Ordering=25350.00)
# Episode 8/1000 | Tổng chi phí: 28435.84 (Holding=225.84, Backorder=260.00, Ordering=25150.00)
# Episode 9/1000 | Tổng chi phí: 29123.23 (Holding=243.23, Backorder=180.00, Ordering=24700.00)
# Episode 10/1000 | Tổng chi phí: 27842.71 (Holding=232.71, Backorder=160.00, Ordering=25050.00)
# Episode 11/1000 | Tổng chi phí: 30295.86 (Holding=225.86, Backorder=420.00, Ordering=25450.00)
# Episode 12/1000 | Tổng chi phí: 30434.05 (Holding=234.05, Backorder=400.00, Ordering=25200.00)
# Episode 13/1000 | Tổng chi phí: 30191.34 (Holding=231.34, Backorder=560.00, Ordering=25000.00)
# Episode 14/1000 | Tổng chi phí: 28334.71 (Holding=244.71, Backorder=440.00, Ordering=25050.00)
# Episode 15/1000 | Tổng chi phí: 30706.49 (Holding=236.49, Backorder=420.00, Ordering=24650.00)
# Episode 16/1000 | Tổng chi phí: 30445.34 (Holding=235.34, Backorder=260.00, Ordering=25550.00)
# Episode 17/1000 | Tổng chi phí: 27440.05 (Holding=260.05, Backorder=80.00, Ordering=25300.00)
# Episode 18/1000 | Tổng chi phí: 27868.88 (Holding=248.88, Backorder=120.00, Ordering=24700.00)
# Episode 19/1000 | Tổng chi phí: 28372.30 (Holding=232.30, Backorder=240.00, Ordering=24900.00)
# Episode 20/1000 | Tổng chi phí: 33242.30 (Holding=212.30, Backorder=1080.00, Ordering=25150.00)
# Episode 21/1000 | Tổng chi phí: 30818.58 (Holding=218.58, Backorder=900.00, Ordering=25300.00)
# Episode 22/1000 | Tổng chi phí: 28578.85 (Holding=228.85, Backorder=400.00, Ordering=24550.00)
# Episode 23/1000 | Tổng chi phí: 30477.23 (Holding=227.23, Backorder=800.00, Ordering=25050.00)
# Episode 24/1000 | Tổng chi phí: 30527.10 (Holding=227.10, Backorder=600.00, Ordering=25300.00)
# Episode 25/1000 | Tổng chi phí: 29547.67 (Holding=227.67, Backorder=420.00, Ordering=24700.00)
# Episode 26/1000 | Tổng chi phí: 29000.85 (Holding=220.85, Backorder=380.00, Ordering=24800.00)
# Episode 27/1000 | Tổng chi phí: 29347.81 (Holding=227.81, Backorder=420.00, Ordering=25300.00)
# Episode 28/1000 | Tổng chi phí: 30837.34 (Holding=217.34, Backorder=420.00, Ordering=24800.00)
# Episode 29/1000 | Tổng chi phí: 27896.68 (Holding=236.68, Backorder=160.00, Ordering=24700.00)
# Episode 30/1000 | Tổng chi phí: 29127.73 (Holding=237.73, Backorder=440.00, Ordering=25250.00)
# Episode 31/1000 | Tổng chi phí: 30670.68 (Holding=220.68, Backorder=1500.00, Ordering=25150.00)
# Episode 32/1000 | Tổng chi phí: 30664.19 (Holding=224.19, Backorder=440.00, Ordering=25000.00)
# Episode 33/1000 | Tổng chi phí: 27917.26 (Holding=247.26, Backorder=320.00, Ordering=24550.00)
# Episode 34/1000 | Tổng chi phí: 27284.82 (Holding=254.82, Backorder=180.00, Ordering=24650.00)
# Episode 35/1000 | Tổng chi phí: 28508.71 (Holding=238.71, Backorder=120.00, Ordering=24950.00)
# Episode 36/1000 | Tổng chi phí: 29059.40 (Holding=249.40, Backorder=260.00, Ordering=24950.00)
# Episode 37/1000 | Tổng chi phí: 29507.78 (Holding=227.78, Backorder=280.00, Ordering=25000.00)
# Episode 38/1000 | Tổng chi phí: 29791.51 (Holding=221.51, Backorder=220.00, Ordering=25350.00)
# Episode 39/1000 | Tổng chi phí: 29637.34 (Holding=227.34, Backorder=260.00, Ordering=25350.00)
# Episode 40/1000 | Tổng chi phí: 28619.81 (Holding=229.81, Backorder=440.00, Ordering=24750.00)
# Episode 41/1000 | Tổng chi phí: 28368.88 (Holding=238.88, Backorder=180.00, Ordering=24750.00)
# Episode 42/1000 | Tổng chi phí: 29492.52 (Holding=232.52, Backorder=560.00, Ordering=24700.00)
# Episode 43/1000 | Tổng chi phí: 28999.10 (Holding=239.10, Backorder=360.00, Ordering=25000.00)
# Episode 44/1000 | Tổng chi phí: 30593.73 (Holding=233.73, Backorder=360.00, Ordering=25400.00)
# Episode 45/1000 | Tổng chi phí: 28323.59 (Holding=233.59, Backorder=240.00, Ordering=25050.00)
# Episode 46/1000 | Tổng chi phí: 29772.90 (Holding=242.90, Backorder=80.00, Ordering=24850.00)
# Episode 47/1000 | Tổng chi phí: 28303.40 (Holding=243.40, Backorder=160.00, Ordering=25100.00)
# Episode 48/1000 | Tổng chi phí: 29275.07 (Holding=225.07, Backorder=600.00, Ordering=25050.00)
# Episode 49/1000 | Tổng chi phí: 27804.16 (Holding=244.16, Backorder=160.00, Ordering=25200.00)
# Episode 50/1000 | Tổng chi phí: 29610.38 (Holding=230.38, Backorder=280.00, Ordering=25100.00)
# Episode 51/1000 | Tổng chi phí: 30310.60 (Holding=230.60, Backorder=480.00, Ordering=25600.00)
# Episode 52/1000 | Tổng chi phí: 28680.58 (Holding=240.58, Backorder=540.00, Ordering=24700.00)
# Episode 53/1000 | Tổng chi phí: 27411.53 (Holding=231.53, Backorder=80.00, Ordering=24700.00)
# Episode 54/1000 | Tổng chi phí: 29675.37 (Holding=215.37, Backorder=260.00, Ordering=24600.00)
# Episode 55/1000 | Tổng chi phí: 28732.77 (Holding=242.77, Backorder=140.00, Ordering=24750.00)
# Episode 56/1000 | Tổng chi phí: 28220.38 (Holding=240.38, Backorder=180.00, Ordering=25400.00)
# Episode 57/1000 | Tổng chi phí: 28799.64 (Holding=219.64, Backorder=280.00, Ordering=25300.00)
# Episode 58/1000 | Tổng chi phí: 30609.12 (Holding=219.12, Backorder=540.00, Ordering=24850.00)
# Episode 59/1000 | Tổng chi phí: 29746.47 (Holding=226.47, Backorder=320.00, Ordering=25800.00)
# Episode 60/1000 | Tổng chi phí: 30167.89 (Holding=237.89, Backorder=480.00, Ordering=25450.00)
# Episode 61/1000 | Tổng chi phí: 29022.36 (Holding=242.36, Backorder=280.00, Ordering=25300.00)
# Episode 62/1000 | Tổng chi phí: 29954.85 (Holding=224.85, Backorder=380.00, Ordering=24750.00)
# Episode 63/1000 | Tổng chi phí: 30327.23 (Holding=207.23, Backorder=420.00, Ordering=24700.00)
# Episode 64/1000 | Tổng chi phí: 30412.77 (Holding=232.77, Backorder=480.00, Ordering=25300.00)
# Episode 65/1000 | Tổng chi phí: 30482.55 (Holding=222.55, Backorder=360.00, Ordering=24900.00)
# Episode 66/1000 | Tổng chi phí: 29729.56 (Holding=239.56, Backorder=640.00, Ordering=25450.00)
# Episode 67/1000 | Tổng chi phí: 27559.23 (Holding=249.23, Backorder=60.00, Ordering=24850.00)
# Episode 68/1000 | Tổng chi phí: 30846.05 (Holding=226.05, Backorder=420.00, Ordering=25600.00)
# Episode 69/1000 | Tổng chi phí: 27731.42 (Holding=241.42, Backorder=240.00, Ordering=24650.00)
# Episode 70/1000 | Tổng chi phí: 27038.05 (Holding=238.05, Backorder=100.00, Ordering=24700.00)
# Episode 71/1000 | Tổng chi phí: 28936.52 (Holding=236.52, Backorder=300.00, Ordering=25000.00)
# Episode 72/1000 | Tổng chi phí: 28159.51 (Holding=239.51, Backorder=120.00, Ordering=24800.00)
# Episode 73/1000 | Tổng chi phí: 29896.63 (Holding=226.63, Backorder=120.00, Ordering=25150.00)
# Episode 74/1000 | Tổng chi phí: 29307.07 (Holding=227.07, Backorder=180.00, Ordering=25300.00)
# Episode 75/1000 | Tổng chi phí: 29205.70 (Holding=225.70, Backorder=280.00, Ordering=24700.00)
# Episode 76/1000 | Tổng chi phí: 28439.53 (Holding=239.53, Backorder=200.00, Ordering=25200.00)
# Episode 77/1000 | Tổng chi phí: 28991.18 (Holding=241.18, Backorder=700.00, Ordering=25250.00)
# Episode 78/1000 | Tổng chi phí: 30522.11 (Holding=232.11, Backorder=440.00, Ordering=25050.00)
# Episode 79/1000 | Tổng chi phí: 28488.33 (Holding=238.33, Backorder=100.00, Ordering=24750.00)
# Episode 80/1000 | Tổng chi phí: 29370.33 (Holding=230.33, Backorder=340.00, Ordering=25200.00)
# Episode 81/1000 | Tổng chi phí: 28699.40 (Holding=239.40, Backorder=260.00, Ordering=24800.00)
# Episode 82/1000 | Tổng chi phí: 28713.89 (Holding=233.89, Backorder=280.00, Ordering=24800.00)
# Episode 83/1000 | Tổng chi phí: 27003.51 (Holding=253.51, Backorder=100.00, Ordering=24850.00)
# Episode 84/1000 | Tổng chi phí: 29154.47 (Holding=234.47, Backorder=620.00, Ordering=25300.00)
# Episode 85/1000 | Tổng chi phí: 30481.04 (Holding=231.04, Backorder=500.00, Ordering=25550.00)
# Episode 86/1000 | Tổng chi phí: 30552.05 (Holding=232.05, Backorder=820.00, Ordering=25500.00)
# Episode 87/1000 | Tổng chi phí: 29405.75 (Holding=255.75, Backorder=300.00, Ordering=25050.00)
# Episode 88/1000 | Tổng chi phí: 30817.81 (Holding=217.81, Backorder=600.00, Ordering=25200.00)
# Episode 89/1000 | Tổng chi phí: 31942.93 (Holding=222.93, Backorder=620.00, Ordering=25100.00)
# Episode 90/1000 | Tổng chi phí: 30010.14 (Holding=230.14, Backorder=480.00, Ordering=25100.00)
# Episode 91/1000 | Tổng chi phí: 30948.79 (Holding=218.79, Backorder=480.00, Ordering=25250.00)
# Episode 92/1000 | Tổng chi phí: 29376.22 (Holding=236.22, Backorder=240.00, Ordering=25100.00)
# Episode 93/1000 | Tổng chi phí: 32308.47 (Holding=228.47, Backorder=880.00, Ordering=25200.00)
# Episode 94/1000 | Tổng chi phí: 29221.42 (Holding=231.42, Backorder=240.00, Ordering=25550.00)
# Episode 95/1000 | Tổng chi phí: 28065.86 (Holding=235.86, Backorder=180.00, Ordering=24850.00)
# Episode 96/1000 | Tổng chi phí: 28755.21 (Holding=235.21, Backorder=220.00, Ordering=25100.00)
# Episode 97/1000 | Tổng chi phí: 30398.05 (Holding=228.05, Backorder=620.00, Ordering=24950.00)
# Episode 98/1000 | Tổng chi phí: 31427.40 (Holding=227.40, Backorder=1100.00, Ordering=24700.00)
# Episode 99/1000 | Tổng chi phí: 29328.33 (Holding=238.33, Backorder=440.00, Ordering=25050.00)
# Episode 100/1000 | Tổng chi phí: 30144.49 (Holding=224.49, Backorder=520.00, Ordering=25200.00)
# Episode 101/1000 | Tổng chi phí: 30772.82 (Holding=232.82, Backorder=640.00, Ordering=24900.00)
# Episode 102/1000 | Tổng chi phí: 27849.10 (Holding=249.10, Backorder=100.00, Ordering=25300.00)
# Episode 103/1000 | Tổng chi phí: 28882.63 (Holding=232.63, Backorder=300.00, Ordering=25150.00)
# Episode 104/1000 | Tổng chi phí: 28177.45 (Holding=237.45, Backorder=140.00, Ordering=25000.00)
# Episode 105/1000 | Tổng chi phí: 30162.52 (Holding=222.52, Backorder=640.00, Ordering=24700.00)
# Episode 106/1000 | Tổng chi phí: 28503.48 (Holding=233.48, Backorder=220.00, Ordering=25250.00)
# Episode 107/1000 | Tổng chi phí: 28100.71 (Holding=240.71, Backorder=260.00, Ordering=24400.00)
# Episode 108/1000 | Tổng chi phí: 29005.97 (Holding=235.97, Backorder=320.00, Ordering=25450.00)
# Episode 109/1000 | Tổng chi phí: 30954.05 (Holding=234.05, Backorder=420.00, Ordering=24900.00)
# Episode 110/1000 | Tổng chi phí: 28316.27 (Holding=236.27, Backorder=280.00, Ordering=25200.00)
# Episode 111/1000 | Tổng chi phí: 29096.71 (Holding=236.71, Backorder=460.00, Ordering=25000.00)
# Episode 112/1000 | Tổng chi phí: 28739.10 (Holding=239.10, Backorder=400.00, Ordering=25100.00)
# Episode 113/1000 | Tổng chi phí: 28844.79 (Holding=234.79, Backorder=360.00, Ordering=25050.00)
# Episode 114/1000 | Tổng chi phí: 29573.86 (Holding=233.86, Backorder=240.00, Ordering=24900.00)
# Episode 115/1000 | Tổng chi phí: 29315.70 (Holding=225.70, Backorder=340.00, Ordering=25150.00)
# Episode 116/1000 | Tổng chi phí: 29073.10 (Holding=233.10, Backorder=240.00, Ordering=25600.00)
# Episode 117/1000 | Tổng chi phí: 29970.44 (Holding=220.44, Backorder=400.00, Ordering=25550.00)
# Episode 118/1000 | Tổng chi phí: 30154.77 (Holding=224.77, Backorder=180.00, Ordering=25150.00)
# Episode 119/1000 | Tổng chi phí: 28918.19 (Holding=248.19, Backorder=420.00, Ordering=24850.00)
# Episode 120/1000 | Tổng chi phí: 30459.04 (Holding=229.04, Backorder=280.00, Ordering=24750.00)
# Episode 121/1000 | Tổng chi phí: 28459.95 (Holding=229.95, Backorder=280.00, Ordering=25150.00)
# Episode 122/1000 | Tổng chi phí: 28581.34 (Holding=231.34, Backorder=200.00, Ordering=25150.00)
# Episode 123/1000 | Tổng chi phí: 28804.22 (Holding=244.22, Backorder=160.00, Ordering=25400.00)
# Episode 124/1000 | Tổng chi phí: 31480.27 (Holding=220.27, Backorder=960.00, Ordering=25300.00)
# Episode 125/1000 | Tổng chi phí: 29137.21 (Holding=247.21, Backorder=140.00, Ordering=25350.00)
# Episode 126/1000 | Tổng chi phí: 29366.90 (Holding=236.90, Backorder=380.00, Ordering=24750.00)
# Episode 127/1000 | Tổng chi phí: 29307.92 (Holding=237.92, Backorder=720.00, Ordering=24750.00)
# Episode 128/1000 | Tổng chi phí: 28058.41 (Holding=258.41, Backorder=100.00, Ordering=24900.00)
# Episode 129/1000 | Tổng chi phí: 29105.95 (Holding=245.95, Backorder=460.00, Ordering=25000.00)
# Episode 130/1000 | Tổng chi phí: 29599.42 (Holding=229.42, Backorder=320.00, Ordering=25050.00)
# Episode 131/1000 | Tổng chi phí: 28693.73 (Holding=223.73, Backorder=520.00, Ordering=24550.00)
# Episode 132/1000 | Tổng chi phí: 29006.55 (Holding=236.55, Backorder=520.00, Ordering=25050.00)
# Episode 133/1000 | Tổng chi phí: 28371.64 (Holding=231.64, Backorder=240.00, Ordering=25100.00)
# Episode 134/1000 | Tổng chi phí: 31598.82 (Holding=218.82, Backorder=480.00, Ordering=25100.00)
# Episode 135/1000 | Tổng chi phí: 29257.67 (Holding=237.67, Backorder=320.00, Ordering=25100.00)
# Episode 136/1000 | Tổng chi phí: 29135.92 (Holding=225.92, Backorder=160.00, Ordering=25550.00)
# Episode 137/1000 | Tổng chi phí: 29644.66 (Holding=224.66, Backorder=420.00, Ordering=25000.00)
# Episode 138/1000 | Tổng chi phí: 32153.23 (Holding=233.23, Backorder=1120.00, Ordering=25200.00)
# Episode 139/1000 | Tổng chi phí: 31092.36 (Holding=222.36, Backorder=620.00, Ordering=24850.00)
# Episode 140/1000 | Tổng chi phí: 28373.23 (Holding=233.23, Backorder=640.00, Ordering=24500.00)
# Episode 141/1000 | Tổng chi phí: 29648.58 (Holding=228.58, Backorder=320.00, Ordering=24900.00)
# Episode 142/1000 | Tổng chi phí: 29259.40 (Holding=229.40, Backorder=180.00, Ordering=25050.00)
# Episode 143/1000 | Tổng chi phí: 30024.03 (Holding=224.03, Backorder=300.00, Ordering=25300.00)
# Episode 144/1000 | Tổng chi phí: 30911.18 (Holding=221.18, Backorder=440.00, Ordering=25250.00)
# Episode 145/1000 | Tổng chi phí: 29796.49 (Holding=226.49, Backorder=220.00, Ordering=25350.00)
# Episode 146/1000 | Tổng chi phí: 29588.11 (Holding=238.11, Backorder=300.00, Ordering=25250.00)
# Episode 147/1000 | Tổng chi phí: 28969.73 (Holding=239.73, Backorder=380.00, Ordering=25150.00)
# Episode 148/1000 | Tổng chi phí: 28108.30 (Holding=258.30, Backorder=200.00, Ordering=25250.00)
# Episode 149/1000 | Tổng chi phí: 29445.01 (Holding=235.01, Backorder=260.00, Ordering=25150.00)
# Episode 150/1000 | Tổng chi phí: 28806.03 (Holding=236.03, Backorder=320.00, Ordering=24650.00)
# Episode 151/1000 | Tổng chi phí: 30252.55 (Holding=222.55, Backorder=380.00, Ordering=25250.00)
# Episode 152/1000 | Tổng chi phí: 28918.41 (Holding=218.41, Backorder=300.00, Ordering=24600.00)
# Episode 153/1000 | Tổng chi phí: 30459.15 (Holding=239.15, Backorder=320.00, Ordering=25700.00)
# Episode 154/1000 | Tổng chi phí: 32313.29 (Holding=233.29, Backorder=1680.00, Ordering=24600.00)
# Episode 155/1000 | Tổng chi phí: 30480.19 (Holding=230.19, Backorder=300.00, Ordering=25550.00)
# Episode 156/1000 | Tổng chi phí: 28027.62 (Holding=237.62, Backorder=340.00, Ordering=24850.00)
# Episode 157/1000 | Tổng chi phí: 29009.67 (Holding=229.67, Backorder=80.00, Ordering=25300.00)
# Episode 158/1000 | Tổng chi phí: 28410.14 (Holding=250.14, Backorder=260.00, Ordering=25100.00)
# Episode 159/1000 | Tổng chi phí: 29289.15 (Holding=219.15, Backorder=420.00, Ordering=24650.00)
# Episode 160/1000 | Tổng chi phí: 31549.97 (Holding=219.97, Backorder=780.00, Ordering=25150.00)
# Episode 161/1000 | Tổng chi phí: 29869.73 (Holding=239.73, Backorder=280.00, Ordering=25150.00)
# Episode 162/1000 | Tổng chi phí: 28720.22 (Holding=230.22, Backorder=240.00, Ordering=24850.00)
# Episode 163/1000 | Tổng chi phí: 31550.16 (Holding=220.16, Backorder=980.00, Ordering=24950.00)
# Episode 164/1000 | Tổng chi phí: 28552.79 (Holding=232.79, Backorder=520.00, Ordering=25000.00)
# Episode 165/1000 | Tổng chi phí: 31474.55 (Holding=214.55, Backorder=660.00, Ordering=25200.00)
# Episode 166/1000 | Tổng chi phí: 27500.63 (Holding=240.63, Backorder=160.00, Ordering=24900.00)
# Episode 167/1000 | Tổng chi phí: 28605.95 (Holding=235.95, Backorder=220.00, Ordering=24750.00)
# Episode 168/1000 | Tổng chi phí: 28044.30 (Holding=234.30, Backorder=460.00, Ordering=24950.00)
# Episode 169/1000 | Tổng chi phí: 30235.92 (Holding=235.92, Backorder=600.00, Ordering=25200.00)
# Episode 170/1000 | Tổng chi phí: 27947.18 (Holding=247.18, Backorder=100.00, Ordering=24800.00)
# Episode 171/1000 | Tổng chi phí: 29231.01 (Holding=221.01, Backorder=160.00, Ordering=25250.00)
# Episode 172/1000 | Tổng chi phí: 28537.07 (Holding=257.07, Backorder=280.00, Ordering=24800.00)
# Episode 173/1000 | Tổng chi phí: 28889.10 (Holding=239.10, Backorder=200.00, Ordering=25050.00)
# Episode 174/1000 | Tổng chi phí: 29950.14 (Holding=240.14, Backorder=360.00, Ordering=24750.00)
# Episode 175/1000 | Tổng chi phí: 29322.49 (Holding=252.49, Backorder=120.00, Ordering=25150.00)
# Episode 176/1000 | Tổng chi phí: 27954.36 (Holding=254.36, Backorder=200.00, Ordering=25100.00)
# Episode 177/1000 | Tổng chi phí: 31541.81 (Holding=231.81, Backorder=860.00, Ordering=25250.00)
# Episode 178/1000 | Tổng chi phí: 29670.99 (Holding=220.99, Backorder=400.00, Ordering=24850.00)
# Episode 179/1000 | Tổng chi phí: 30483.81 (Holding=223.81, Backorder=260.00, Ordering=25000.00)
# Episode 180/1000 | Tổng chi phí: 28486.27 (Holding=236.27, Backorder=600.00, Ordering=24450.00)
# Episode 181/1000 | Tổng chi phí: 31162.25 (Holding=212.25, Backorder=600.00, Ordering=25150.00)
# Episode 182/1000 | Tổng chi phí: 29671.81 (Holding=241.81, Backorder=480.00, Ordering=24950.00)
# Episode 183/1000 | Tổng chi phí: 31803.07 (Holding=223.07, Backorder=980.00, Ordering=25800.00)
# Episode 184/1000 | Tổng chi phí: 28929.40 (Holding=229.40, Backorder=100.00, Ordering=25800.00)
# Episode 185/1000 | Tổng chi phí: 29234.47 (Holding=234.47, Backorder=200.00, Ordering=25400.00)
# Episode 186/1000 | Tổng chi phí: 28111.84 (Holding=231.84, Backorder=80.00, Ordering=25200.00)
# Episode 187/1000 | Tổng chi phí: 29950.36 (Holding=240.36, Backorder=460.00, Ordering=25250.00)
# Episode 188/1000 | Tổng chi phí: 29849.26 (Holding=229.26, Backorder=420.00, Ordering=24800.00)
# Episode 189/1000 | Tổng chi phí: 28561.32 (Holding=231.32, Backorder=80.00, Ordering=25050.00)
# Episode 190/1000 | Tổng chi phí: 29763.64 (Holding=243.64, Backorder=220.00, Ordering=25100.00)
# Episode 191/1000 | Tổng chi phí: 28279.53 (Holding=229.53, Backorder=100.00, Ordering=24950.00)
# Episode 192/1000 | Tổng chi phí: 28133.29 (Holding=243.29, Backorder=340.00, Ordering=24750.00)
# Episode 193/1000 | Tổng chi phí: 29154.41 (Holding=234.41, Backorder=320.00, Ordering=25400.00)
# Episode 194/1000 | Tổng chi phí: 28236.08 (Holding=236.08, Backorder=200.00, Ordering=24800.00)
# Episode 195/1000 | Tổng chi phí: 30386.71 (Holding=226.71, Backorder=860.00, Ordering=24900.00)
# Episode 196/1000 | Tổng chi phí: 29318.71 (Holding=228.71, Backorder=140.00, Ordering=24750.00)
# Episode 197/1000 | Tổng chi phí: 30206.25 (Holding=226.25, Backorder=480.00, Ordering=24900.00)
# Episode 198/1000 | Tổng chi phí: 28887.40 (Holding=247.40, Backorder=140.00, Ordering=25100.00)
# Episode 199/1000 | Tổng chi phí: 30336.90 (Holding=236.90, Backorder=600.00, Ordering=24900.00)
# Episode 200/1000 | Tổng chi phí: 31208.96 (Holding=218.96, Backorder=640.00, Ordering=25350.00)
# Episode 201/1000 | Tổng chi phí: 30475.29 (Holding=235.29, Backorder=440.00, Ordering=25200.00)
# Episode 202/1000 | Tổng chi phí: 27458.49 (Holding=238.49, Backorder=220.00, Ordering=24800.00)
# Episode 203/1000 | Tổng chi phí: 31036.22 (Holding=226.22, Backorder=460.00, Ordering=25350.00)
# Episode 204/1000 | Tổng chi phí: 30013.04 (Holding=213.04, Backorder=400.00, Ordering=25200.00)
# Episode 205/1000 | Tổng chi phí: 29804.44 (Holding=234.44, Backorder=520.00, Ordering=25450.00)
# Episode 206/1000 | Tổng chi phí: 29749.64 (Holding=229.64, Backorder=620.00, Ordering=24500.00)
# Episode 207/1000 | Tổng chi phí: 28288.38 (Holding=228.38, Backorder=560.00, Ordering=25100.00)
# Episode 208/1000 | Tổng chi phí: 30268.99 (Holding=218.99, Backorder=500.00, Ordering=24950.00)
# Episode 209/1000 | Tổng chi phí: 29259.95 (Holding=239.95, Backorder=320.00, Ordering=24900.00)
# Episode 210/1000 | Tổng chi phí: 29776.85 (Holding=226.85, Backorder=700.00, Ordering=24650.00)
# Episode 211/1000 | Tổng chi phí: 29361.45 (Holding=231.45, Backorder=280.00, Ordering=24850.00)
# Episode 212/1000 | Tổng chi phí: 27711.59 (Holding=241.59, Backorder=20.00, Ordering=24650.00)
# Episode 213/1000 | Tổng chi phí: 29108.25 (Holding=238.25, Backorder=220.00, Ordering=24850.00)
# Episode 214/1000 | Tổng chi phí: 29237.78 (Holding=237.78, Backorder=200.00, Ordering=25200.00)
# Episode 215/1000 | Tổng chi phí: 27606.14 (Holding=246.14, Backorder=460.00, Ordering=24900.00)
# Episode 216/1000 | Tổng chi phí: 29916.27 (Holding=236.27, Backorder=280.00, Ordering=25600.00)
# Episode 217/1000 | Tổng chi phí: 29750.38 (Holding=230.38, Backorder=320.00, Ordering=25000.00)
# Episode 218/1000 | Tổng chi phí: 29677.18 (Holding=227.18, Backorder=200.00, Ordering=25050.00)
# Episode 219/1000 | Tổng chi phí: 29375.67 (Holding=235.67, Backorder=240.00, Ordering=25900.00)
# Episode 220/1000 | Tổng chi phí: 31617.04 (Holding=237.04, Backorder=1080.00, Ordering=25500.00)
# Episode 221/1000 | Tổng chi phí: 29574.38 (Holding=234.38, Backorder=240.00, Ordering=25100.00)
# Episode 222/1000 | Tổng chi phí: 30408.49 (Holding=228.49, Backorder=280.00, Ordering=24900.00)
# Episode 223/1000 | Tổng chi phí: 30139.15 (Holding=239.15, Backorder=600.00, Ordering=24700.00)
# Episode 224/1000 | Tổng chi phí: 29631.64 (Holding=231.64, Backorder=600.00, Ordering=24600.00)
# Episode 225/1000 | Tổng chi phí: 27374.63 (Holding=234.63, Backorder=240.00, Ordering=24900.00)
# Episode 226/1000 | Tổng chi phí: 30140.88 (Holding=220.88, Backorder=320.00, Ordering=25000.00)
# Episode 227/1000 | Tổng chi phí: 28732.88 (Holding=222.88, Backorder=260.00, Ordering=24850.00)
# Episode 228/1000 | Tổng chi phí: 27999.23 (Holding=249.23, Backorder=100.00, Ordering=24650.00)
# Episode 229/1000 | Tổng chi phí: 28636.63 (Holding=236.63, Backorder=300.00, Ordering=24500.00)
# Episode 230/1000 | Tổng chi phí: 28486.08 (Holding=236.08, Backorder=200.00, Ordering=24650.00)
# Episode 231/1000 | Tổng chi phí: 29078.79 (Holding=238.79, Backorder=340.00, Ordering=25100.00)
# Episode 232/1000 | Tổng chi phí: 29384.68 (Holding=244.68, Backorder=440.00, Ordering=25100.00)
# Episode 233/1000 | Tổng chi phí: 29155.37 (Holding=225.37, Backorder=180.00, Ordering=25350.00)
# Episode 234/1000 | Tổng chi phí: 28161.75 (Holding=231.75, Backorder=80.00, Ordering=24850.00)
# Episode 235/1000 | Tổng chi phí: 27848.00 (Holding=238.00, Backorder=60.00, Ordering=24950.00)
# Episode 236/1000 | Tổng chi phí: 29074.03 (Holding=224.03, Backorder=300.00, Ordering=24550.00)
# Episode 237/1000 | Tổng chi phí: 27712.52 (Holding=242.52, Backorder=20.00, Ordering=24850.00)
# Episode 238/1000 | Tổng chi phí: 28648.90 (Holding=228.90, Backorder=320.00, Ordering=24500.00)
# Episode 239/1000 | Tổng chi phí: 28467.40 (Holding=247.40, Backorder=220.00, Ordering=25000.00)
# Episode 240/1000 | Tổng chi phí: 28990.19 (Holding=230.19, Backorder=360.00, Ordering=25200.00)
# Episode 241/1000 | Tổng chi phí: 28742.41 (Holding=232.41, Backorder=160.00, Ordering=25150.00)
# Episode 242/1000 | Tổng chi phí: 30695.26 (Holding=225.26, Backorder=420.00, Ordering=25450.00)
# Episode 243/1000 | Tổng chi phí: 29160.88 (Holding=220.88, Backorder=240.00, Ordering=25500.00)
# Episode 244/1000 | Tổng chi phí: 31841.89 (Holding=211.89, Backorder=980.00, Ordering=24850.00)
# Episode 245/1000 | Tổng chi phí: 27576.99 (Holding=236.99, Backorder=240.00, Ordering=24900.00)
# Episode 246/1000 | Tổng chi phí: 30118.82 (Holding=228.82, Backorder=340.00, Ordering=25150.00)
# Episode 247/1000 | Tổng chi phí: 31706.63 (Holding=226.63, Backorder=480.00, Ordering=25200.00)
# Episode 248/1000 | Tổng chi phí: 31075.81 (Holding=225.81, Backorder=300.00, Ordering=25750.00)
# Episode 249/1000 | Tổng chi phí: 29892.14 (Holding=232.14, Backorder=560.00, Ordering=24900.00)
# Episode 250/1000 | Tổng chi phí: 28288.16 (Holding=238.16, Backorder=400.00, Ordering=24650.00)
# Episode 251/1000 | Tổng chi phí: 27330.27 (Holding=240.27, Backorder=40.00, Ordering=24850.00)
# Episode 252/1000 | Tổng chi phí: 28688.44 (Holding=238.44, Backorder=300.00, Ordering=25150.00)
# Episode 253/1000 | Tổng chi phí: 28050.79 (Holding=250.79, Backorder=200.00, Ordering=25400.00)
# Episode 254/1000 | Tổng chi phí: 29918.44 (Holding=228.44, Backorder=440.00, Ordering=25250.00)
# Episode 255/1000 | Tổng chi phí: 28536.90 (Holding=236.90, Backorder=200.00, Ordering=25100.00)
# Episode 256/1000 | Tổng chi phí: 29530.22 (Holding=250.22, Backorder=580.00, Ordering=25100.00)
# Episode 257/1000 | Tổng chi phí: 29662.03 (Holding=222.03, Backorder=340.00, Ordering=24900.00)
# Episode 258/1000 | Tổng chi phí: 28950.88 (Holding=240.88, Backorder=360.00, Ordering=24950.00)
# Episode 259/1000 | Tổng chi phí: 30198.44 (Holding=228.44, Backorder=720.00, Ordering=25050.00)
# Episode 260/1000 | Tổng chi phí: 28063.26 (Holding=243.26, Backorder=220.00, Ordering=25200.00)
# Episode 261/1000 | Tổng chi phí: 27844.36 (Holding=244.36, Backorder=200.00, Ordering=24400.00)
# Episode 262/1000 | Tổng chi phí: 29244.49 (Holding=224.49, Backorder=320.00, Ordering=24700.00)
# Episode 263/1000 | Tổng chi phí: 27768.82 (Holding=248.82, Backorder=320.00, Ordering=24600.00)
# Episode 264/1000 | Tổng chi phí: 29491.48 (Holding=231.48, Backorder=260.00, Ordering=25200.00)
# Episode 265/1000 | Tổng chi phí: 29666.77 (Holding=236.77, Backorder=380.00, Ordering=24650.00)
# Episode 266/1000 | Tổng chi phí: 29452.41 (Holding=222.41, Backorder=180.00, Ordering=25450.00)
# Episode 267/1000 | Tổng chi phí: 31172.99 (Holding=212.99, Backorder=360.00, Ordering=25200.00)
# Episode 268/1000 | Tổng chi phí: 28375.97 (Holding=225.97, Backorder=100.00, Ordering=24650.00)
# Episode 269/1000 | Tổng chi phí: 29114.36 (Holding=224.36, Backorder=140.00, Ordering=24750.00)
# Episode 270/1000 | Tổng chi phí: 28414.66 (Holding=234.66, Backorder=280.00, Ordering=24900.00)
# Episode 271/1000 | Tổng chi phí: 30703.01 (Holding=233.01, Backorder=320.00, Ordering=25150.00)
# Episode 272/1000 | Tổng chi phí: 27526.22 (Holding=246.22, Backorder=180.00, Ordering=24700.00)
# Episode 273/1000 | Tổng chi phí: 27684.11 (Holding=254.11, Backorder=280.00, Ordering=24950.00)
# Episode 274/1000 | Tổng chi phí: 30487.04 (Holding=237.04, Backorder=300.00, Ordering=25550.00)
# Episode 275/1000 | Tổng chi phí: 30340.71 (Holding=230.71, Backorder=160.00, Ordering=25550.00)
# Episode 276/1000 | Tổng chi phí: 29913.15 (Holding=223.15, Backorder=340.00, Ordering=25350.00)
# Episode 277/1000 | Tổng chi phí: 28034.08 (Holding=244.08, Backorder=240.00, Ordering=25350.00)
# Episode 278/1000 | Tổng chi phí: 29436.41 (Holding=236.41, Backorder=400.00, Ordering=25000.00)
# Episode 279/1000 | Tổng chi phí: 29449.18 (Holding=239.18, Backorder=360.00, Ordering=25250.00)
# Episode 280/1000 | Tổng chi phí: 27885.97 (Holding=245.97, Backorder=140.00, Ordering=25100.00)
# Episode 281/1000 | Tổng chi phí: 30156.49 (Holding=246.49, Backorder=260.00, Ordering=25050.00)
# Episode 282/1000 | Tổng chi phí: 28425.29 (Holding=245.29, Backorder=180.00, Ordering=25200.00)
# Episode 283/1000 | Tổng chi phí: 31172.79 (Holding=222.79, Backorder=400.00, Ordering=25350.00)
# Episode 284/1000 | Tổng chi phí: 31566.93 (Holding=226.93, Backorder=640.00, Ordering=25100.00)
# Episode 285/1000 | Tổng chi phí: 27680.05 (Holding=260.05, Backorder=320.00, Ordering=24500.00)
# Episode 286/1000 | Tổng chi phí: 31290.58 (Holding=220.58, Backorder=1020.00, Ordering=24850.00)
# Episode 287/1000 | Tổng chi phí: 29405.23 (Holding=225.23, Backorder=180.00, Ordering=25200.00)
# Episode 288/1000 | Tổng chi phí: 29044.52 (Holding=224.52, Backorder=520.00, Ordering=25100.00)
# Episode 289/1000 | Tổng chi phí: 29386.88 (Holding=236.88, Backorder=400.00, Ordering=24750.00)
# Episode 290/1000 | Tổng chi phí: 31388.38 (Holding=218.38, Backorder=1220.00, Ordering=25150.00)
# Episode 291/1000 | Tổng chi phí: 31671.45 (Holding=231.45, Backorder=1340.00, Ordering=24900.00)
# Episode 292/1000 | Tổng chi phí: 27145.48 (Holding=255.48, Backorder=140.00, Ordering=24750.00)
# Episode 293/1000 | Tổng chi phí: 29722.30 (Holding=242.30, Backorder=380.00, Ordering=24900.00)
# Episode 294/1000 | Tổng chi phí: 30976.36 (Holding=216.36, Backorder=660.00, Ordering=24900.00)
# Episode 295/1000 | Tổng chi phí: 30270.55 (Holding=230.55, Backorder=240.00, Ordering=25400.00)
# Episode 296/1000 | Tổng chi phí: 30104.41 (Holding=224.41, Backorder=380.00, Ordering=25300.00)
# Episode 297/1000 | Tổng chi phí: 30226.08 (Holding=226.08, Backorder=700.00, Ordering=25100.00)
# Episode 298/1000 | Tổng chi phí: 30257.18 (Holding=217.18, Backorder=240.00, Ordering=25000.00)
# Episode 299/1000 | Tổng chi phí: 29619.59 (Holding=219.59, Backorder=600.00, Ordering=24800.00)
# Episode 300/1000 | Tổng chi phí: 30161.26 (Holding=231.26, Backorder=380.00, Ordering=24950.00)
# Episode 301/1000 | Tổng chi phí: 28965.70 (Holding=225.70, Backorder=340.00, Ordering=25400.00)
# Episode 302/1000 | Tổng chi phí: 29459.15 (Holding=229.15, Backorder=380.00, Ordering=24850.00)
# Episode 303/1000 | Tổng chi phí: 28427.48 (Holding=227.48, Backorder=200.00, Ordering=25000.00)
# Episode 304/1000 | Tổng chi phí: 28185.97 (Holding=245.97, Backorder=40.00, Ordering=24500.00)
# Episode 305/1000 | Tổng chi phí: 28687.81 (Holding=227.81, Backorder=160.00, Ordering=25300.00)
# Episode 306/1000 | Tổng chi phí: 29198.52 (Holding=238.52, Backorder=260.00, Ordering=25300.00)
# Episode 307/1000 | Tổng chi phí: 30136.05 (Holding=236.05, Backorder=300.00, Ordering=25200.00)
# Episode 308/1000 | Tổng chi phí: 29051.56 (Holding=241.56, Backorder=360.00, Ordering=24850.00)
# Episode 309/1000 | Tổng chi phí: 29606.60 (Holding=246.60, Backorder=160.00, Ordering=25200.00)
# Episode 310/1000 | Tổng chi phí: 28750.66 (Holding=240.66, Backorder=60.00, Ordering=25450.00)
# Episode 311/1000 | Tổng chi phí: 27593.21 (Holding=243.21, Backorder=200.00, Ordering=25150.00)
# Episode 312/1000 | Tổng chi phí: 29100.38 (Holding=260.38, Backorder=240.00, Ordering=25000.00)
# Episode 313/1000 | Tổng chi phí: 31126.38 (Holding=226.38, Backorder=300.00, Ordering=26000.00)
# Episode 314/1000 | Tổng chi phí: 30004.30 (Holding=214.30, Backorder=440.00, Ordering=24750.00)
# Episode 315/1000 | Tổng chi phí: 28901.07 (Holding=241.07, Backorder=60.00, Ordering=25200.00)
# Episode 316/1000 | Tổng chi phí: 27236.60 (Holding=236.60, Backorder=100.00, Ordering=25100.00)
# Episode 317/1000 | Tổng chi phí: 29810.14 (Holding=240.14, Backorder=720.00, Ordering=25050.00)
# Episode 318/1000 | Tổng chi phí: 31549.29 (Holding=219.29, Backorder=880.00, Ordering=25250.00)
# Episode 319/1000 | Tổng chi phí: 30185.67 (Holding=225.67, Backorder=360.00, Ordering=25000.00)
# Episode 320/1000 | Tổng chi phí: 29061.21 (Holding=231.21, Backorder=280.00, Ordering=24950.00)
# Episode 321/1000 | Tổng chi phí: 29452.66 (Holding=242.66, Backorder=60.00, Ordering=24950.00)
# Episode 322/1000 | Tổng chi phí: 29202.71 (Holding=222.71, Backorder=380.00, Ordering=25000.00)
# Episode 323/1000 | Tổng chi phí: 29666.66 (Holding=246.66, Backorder=420.00, Ordering=25200.00)
# Episode 324/1000 | Tổng chi phí: 27516.11 (Holding=246.11, Backorder=120.00, Ordering=25350.00)
# Episode 325/1000 | Tổng chi phí: 29150.05 (Holding=240.05, Backorder=360.00, Ordering=25150.00)
# Episode 326/1000 | Tổng chi phí: 27553.92 (Holding=243.92, Backorder=260.00, Ordering=24450.00)
# Episode 327/1000 | Tổng chi phí: 28890.16 (Holding=240.16, Backorder=100.00, Ordering=25350.00)
# Episode 328/1000 | Tổng chi phí: 28030.60 (Holding=220.60, Backorder=160.00, Ordering=25050.00)
# Episode 329/1000 | Tổng chi phí: 29366.08 (Holding=256.08, Backorder=260.00, Ordering=25050.00)
# Episode 330/1000 | Tổng chi phí: 29057.62 (Holding=237.62, Backorder=320.00, Ordering=24900.00)
# Episode 331/1000 | Tổng chi phí: 28569.81 (Holding=259.81, Backorder=260.00, Ordering=25050.00)
# Episode 332/1000 | Tổng chi phí: 29137.97 (Holding=237.97, Backorder=300.00, Ordering=25200.00)
# Episode 333/1000 | Tổng chi phí: 30775.01 (Holding=225.01, Backorder=900.00, Ordering=25850.00)
# Episode 334/1000 | Tổng chi phí: 27731.26 (Holding=251.26, Backorder=80.00, Ordering=25400.00)
# Episode 335/1000 | Tổng chi phí: 29748.33 (Holding=238.33, Backorder=460.00, Ordering=25050.00)
# Episode 336/1000 | Tổng chi phí: 30442.25 (Holding=232.25, Backorder=260.00, Ordering=25750.00)
# Episode 337/1000 | Tổng chi phí: 28611.45 (Holding=231.45, Backorder=380.00, Ordering=24800.00)
# Episode 338/1000 | Tổng chi phí: 27723.07 (Holding=233.07, Backorder=140.00, Ordering=25350.00)
# Episode 339/1000 | Tổng chi phí: 29836.49 (Holding=226.49, Backorder=660.00, Ordering=24950.00)
# Episode 340/1000 | Tổng chi phí: 27754.00 (Holding=224.00, Backorder=180.00, Ordering=25150.00)
# Episode 341/1000 | Tổng chi phí: 30401.15 (Holding=231.15, Backorder=520.00, Ordering=25250.00)
# Episode 342/1000 | Tổng chi phí: 30154.58 (Holding=224.58, Backorder=680.00, Ordering=25250.00)
# Episode 343/1000 | Tổng chi phí: 30037.37 (Holding=237.37, Backorder=300.00, Ordering=24900.00)
# Episode 344/1000 | Tổng chi phí: 28499.78 (Holding=229.78, Backorder=320.00, Ordering=24750.00)
# Episode 345/1000 | Tổng chi phí: 27883.40 (Holding=233.40, Backorder=100.00, Ordering=24950.00)
# Episode 346/1000 | Tổng chi phí: 28247.21 (Holding=247.21, Backorder=100.00, Ordering=25100.00)
# Episode 347/1000 | Tổng chi phí: 29063.67 (Holding=243.67, Backorder=320.00, Ordering=25100.00)
# Episode 348/1000 | Tổng chi phí: 30230.68 (Holding=230.68, Backorder=300.00, Ordering=24900.00)
# Episode 349/1000 | Tổng chi phí: 30197.73 (Holding=227.73, Backorder=320.00, Ordering=24850.00)
# Episode 350/1000 | Tổng chi phí: 28002.22 (Holding=252.22, Backorder=200.00, Ordering=24750.00)
# Episode 351/1000 | Tổng chi phí: 29037.78 (Holding=237.78, Backorder=300.00, Ordering=24900.00)
# Episode 352/1000 | Tổng chi phí: 28910.74 (Holding=240.74, Backorder=120.00, Ordering=24950.00)
# Episode 353/1000 | Tổng chi phí: 28782.79 (Holding=242.79, Backorder=140.00, Ordering=24800.00)
# Episode 354/1000 | Tổng chi phí: 29787.67 (Holding=227.67, Backorder=260.00, Ordering=24900.00)
# Episode 355/1000 | Tổng chi phí: 29485.78 (Holding=225.78, Backorder=360.00, Ordering=25300.00)
# Episode 356/1000 | Tổng chi phí: 29618.11 (Holding=238.11, Backorder=180.00, Ordering=25000.00)
# Episode 357/1000 | Tổng chi phí: 30958.22 (Holding=228.22, Backorder=980.00, Ordering=25150.00)
# Episode 358/1000 | Tổng chi phí: 30347.59 (Holding=227.59, Backorder=320.00, Ordering=25200.00)
# Episode 359/1000 | Tổng chi phí: 30168.88 (Holding=218.88, Backorder=500.00, Ordering=24650.00)
# Episode 360/1000 | Tổng chi phí: 30397.15 (Holding=227.15, Backorder=220.00, Ordering=25350.00)
# Episode 361/1000 | Tổng chi phí: 31726.30 (Holding=216.30, Backorder=760.00, Ordering=24750.00)
# Episode 362/1000 | Tổng chi phí: 29716.14 (Holding=226.14, Backorder=540.00, Ordering=24950.00)
# Episode 363/1000 | Tổng chi phí: 28464.30 (Holding=244.30, Backorder=320.00, Ordering=24700.00)
# Episode 364/1000 | Tổng chi phí: 29267.84 (Holding=237.84, Backorder=480.00, Ordering=24950.00)
# Episode 365/1000 | Tổng chi phí: 29825.07 (Holding=235.07, Backorder=240.00, Ordering=25150.00)
# Episode 366/1000 | Tổng chi phí: 28302.52 (Holding=232.52, Backorder=220.00, Ordering=24650.00)
# Episode 367/1000 | Tổng chi phí: 30556.55 (Holding=206.55, Backorder=500.00, Ordering=25450.00)
# Episode 368/1000 | Tổng chi phí: 29029.78 (Holding=239.78, Backorder=240.00, Ordering=25150.00)
# Episode 369/1000 | Tổng chi phí: 28354.05 (Holding=234.05, Backorder=220.00, Ordering=24900.00)
# Episode 370/1000 | Tổng chi phí: 28690.85 (Holding=240.85, Backorder=100.00, Ordering=25150.00)
# Episode 371/1000 | Tổng chi phí: 29777.75 (Holding=227.75, Backorder=500.00, Ordering=24850.00)
# Episode 372/1000 | Tổng chi phí: 29351.07 (Holding=231.07, Backorder=320.00, Ordering=25200.00)
# Episode 373/1000 | Tổng chi phí: 29566.16 (Holding=226.16, Backorder=440.00, Ordering=25100.00)
# Episode 374/1000 | Tổng chi phí: 30836.11 (Holding=226.11, Backorder=460.00, Ordering=25150.00)
# Episode 375/1000 | Tổng chi phí: 30157.32 (Holding=227.32, Backorder=380.00, Ordering=24350.00)
# Episode 376/1000 | Tổng chi phí: 27627.18 (Holding=247.18, Backorder=280.00, Ordering=24500.00)
# Episode 377/1000 | Tổng chi phí: 29713.81 (Holding=233.81, Backorder=280.00, Ordering=25000.00)
# Episode 378/1000 | Tổng chi phí: 28822.66 (Holding=232.66, Backorder=140.00, Ordering=25450.00)
# Episode 379/1000 | Tổng chi phí: 29598.25 (Holding=228.25, Backorder=320.00, Ordering=25050.00)
# Episode 380/1000 | Tổng chi phí: 28863.21 (Holding=233.21, Backorder=180.00, Ordering=24850.00)
# Episode 381/1000 | Tổng chi phí: 28100.16 (Holding=250.16, Backorder=100.00, Ordering=24950.00)
# Episode 382/1000 | Tổng chi phí: 29529.23 (Holding=229.23, Backorder=500.00, Ordering=24800.00)
# Episode 383/1000 | Tổng chi phí: 29430.11 (Holding=230.11, Backorder=200.00, Ordering=25000.00)
# Episode 384/1000 | Tổng chi phí: 27062.90 (Holding=252.90, Backorder=60.00, Ordering=24950.00)
# Episode 385/1000 | Tổng chi phí: 32162.88 (Holding=222.88, Backorder=840.00, Ordering=25300.00)
# Episode 386/1000 | Tổng chi phí: 29931.01 (Holding=221.01, Backorder=260.00, Ordering=25050.00)
# Episode 387/1000 | Tổng chi phí: 30396.16 (Holding=226.16, Backorder=520.00, Ordering=25250.00)
# Episode 388/1000 | Tổng chi phí: 28938.05 (Holding=248.05, Backorder=840.00, Ordering=24650.00)
# Episode 389/1000 | Tổng chi phí: 28424.82 (Holding=224.82, Backorder=300.00, Ordering=25300.00)
# Episode 390/1000 | Tổng chi phí: 28715.97 (Holding=225.97, Backorder=340.00, Ordering=25150.00)
# Episode 391/1000 | Tổng chi phí: 29997.73 (Holding=227.73, Backorder=320.00, Ordering=24850.00)
# Episode 392/1000 | Tổng chi phí: 30359.95 (Holding=229.95, Backorder=380.00, Ordering=25550.00)
# Episode 393/1000 | Tổng chi phí: 28554.25 (Holding=234.25, Backorder=220.00, Ordering=24700.00)
# Episode 394/1000 | Tổng chi phí: 31652.22 (Holding=212.22, Backorder=740.00, Ordering=25100.00)
# Episode 395/1000 | Tổng chi phí: 28940.03 (Holding=240.03, Backorder=200.00, Ordering=25100.00)
# Episode 396/1000 | Tổng chi phí: 29167.37 (Holding=227.37, Backorder=440.00, Ordering=25100.00)
# Episode 397/1000 | Tổng chi phí: 31553.51 (Holding=223.51, Backorder=380.00, Ordering=25350.00)
# Episode 398/1000 | Tổng chi phí: 30464.25 (Holding=234.25, Backorder=580.00, Ordering=25250.00)
# Episode 399/1000 | Tổng chi phí: 27747.07 (Holding=247.07, Backorder=300.00, Ordering=25000.00)
# Episode 400/1000 | Tổng chi phí: 29707.40 (Holding=227.40, Backorder=180.00, Ordering=25300.00)
# Episode 401/1000 | Tổng chi phí: 31916.44 (Holding=226.44, Backorder=540.00, Ordering=25550.00)
# Episode 402/1000 | Tổng chi phí: 31487.84 (Holding=227.84, Backorder=960.00, Ordering=25500.00)
# Episode 403/1000 | Tổng chi phí: 28522.47 (Holding=232.47, Backorder=240.00, Ordering=24850.00)
# Episode 404/1000 | Tổng chi phí: 28527.21 (Holding=237.21, Backorder=240.00, Ordering=24850.00)
# Episode 405/1000 | Tổng chi phí: 31061.73 (Holding=221.73, Backorder=340.00, Ordering=25500.00)
# Episode 406/1000 | Tổng chi phí: 30008.38 (Holding=228.38, Backorder=280.00, Ordering=25100.00)
# Episode 407/1000 | Tổng chi phí: 29625.81 (Holding=235.81, Backorder=740.00, Ordering=25250.00)
# Episode 408/1000 | Tổng chi phí: 29180.58 (Holding=230.58, Backorder=100.00, Ordering=25050.00)
# Episode 409/1000 | Tổng chi phí: 30230.08 (Holding=220.08, Backorder=360.00, Ordering=25250.00)
# Episode 410/1000 | Tổng chi phí: 27481.40 (Holding=241.40, Backorder=140.00, Ordering=25100.00)
# Episode 411/1000 | Tổng chi phí: 29812.27 (Holding=232.27, Backorder=480.00, Ordering=25300.00)
# Episode 412/1000 | Tổng chi phí: 29082.05 (Holding=242.05, Backorder=440.00, Ordering=25200.00)
# Episode 413/1000 | Tổng chi phí: 30517.29 (Holding=227.29, Backorder=340.00, Ordering=24750.00)
# Episode 414/1000 | Tổng chi phí: 29812.82 (Holding=222.82, Backorder=340.00, Ordering=24850.00)
# Episode 415/1000 | Tổng chi phí: 30763.29 (Holding=213.29, Backorder=400.00, Ordering=25150.00)
# Episode 416/1000 | Tổng chi phí: 31966.68 (Holding=206.68, Backorder=760.00, Ordering=25200.00)
# Episode 417/1000 | Tổng chi phí: 27293.15 (Holding=243.15, Backorder=100.00, Ordering=25150.00)
# Episode 418/1000 | Tổng chi phí: 28174.44 (Holding=234.44, Backorder=140.00, Ordering=25000.00)
# Episode 419/1000 | Tổng chi phí: 31197.59 (Holding=247.59, Backorder=800.00, Ordering=25150.00)
# Episode 420/1000 | Tổng chi phí: 29010.93 (Holding=230.93, Backorder=180.00, Ordering=25000.00)
# Episode 421/1000 | Tổng chi phí: 29702.63 (Holding=242.63, Backorder=360.00, Ordering=25100.00)
# Episode 422/1000 | Tổng chi phí: 30336.77 (Holding=226.77, Backorder=360.00, Ordering=25150.00)
# Episode 423/1000 | Tổng chi phí: 28522.90 (Holding=232.90, Backorder=240.00, Ordering=24650.00)
# Episode 424/1000 | Tổng chi phí: 29957.84 (Holding=217.84, Backorder=440.00, Ordering=25300.00)
# Episode 425/1000 | Tổng chi phí: 29135.51 (Holding=235.51, Backorder=100.00, Ordering=25000.00)
# Episode 426/1000 | Tổng chi phí: 29606.93 (Holding=236.93, Backorder=620.00, Ordering=24750.00)
# Episode 427/1000 | Tổng chi phí: 29946.30 (Holding=226.30, Backorder=520.00, Ordering=24400.00)
# Episode 428/1000 | Tổng chi phí: 29339.89 (Holding=229.89, Backorder=460.00, Ordering=24850.00)
# Episode 429/1000 | Tổng chi phí: 28226.19 (Holding=246.19, Backorder=180.00, Ordering=24800.00)
# Episode 430/1000 | Tổng chi phí: 27748.60 (Holding=238.60, Backorder=160.00, Ordering=24750.00)
# Episode 431/1000 | Tổng chi phí: 29864.79 (Holding=244.79, Backorder=220.00, Ordering=25000.00)
# Episode 432/1000 | Tổng chi phí: 30227.62 (Holding=237.62, Backorder=840.00, Ordering=24950.00)
# Episode 433/1000 | Tổng chi phí: 30026.16 (Holding=236.16, Backorder=640.00, Ordering=25350.00)
# Episode 434/1000 | Tổng chi phí: 29539.95 (Holding=239.95, Backorder=400.00, Ordering=25500.00)
# Episode 435/1000 | Tổng chi phí: 27220.52 (Holding=250.52, Backorder=220.00, Ordering=24750.00)
# Episode 436/1000 | Tổng chi phí: 27949.81 (Holding=249.81, Backorder=100.00, Ordering=25200.00)
# Episode 437/1000 | Tổng chi phí: 30210.14 (Holding=220.14, Backorder=640.00, Ordering=24950.00)
# Episode 438/1000 | Tổng chi phí: 30434.03 (Holding=224.03, Backorder=460.00, Ordering=24550.00)
# Episode 439/1000 | Tổng chi phí: 28268.99 (Holding=238.99, Backorder=280.00, Ordering=25350.00)
# Episode 440/1000 | Tổng chi phí: 30050.85 (Holding=220.85, Backorder=280.00, Ordering=25150.00)
# Episode 441/1000 | Tổng chi phí: 28126.30 (Holding=246.30, Backorder=80.00, Ordering=25200.00)
# Episode 442/1000 | Tổng chi phí: 29165.92 (Holding=225.92, Backorder=340.00, Ordering=25000.00)
# Episode 443/1000 | Tổng chi phí: 29346.58 (Holding=236.58, Backorder=360.00, Ordering=24550.00)
# Episode 444/1000 | Tổng chi phí: 29433.04 (Holding=233.04, Backorder=300.00, Ordering=24900.00)
# Episode 445/1000 | Tổng chi phí: 29195.73 (Holding=225.73, Backorder=520.00, Ordering=25250.00)
# Episode 446/1000 | Tổng chi phí: 29335.23 (Holding=245.23, Backorder=240.00, Ordering=25250.00)
# Episode 447/1000 | Tổng chi phí: 28931.18 (Holding=221.18, Backorder=260.00, Ordering=24650.00)
# Episode 448/1000 | Tổng chi phí: 30123.86 (Holding=233.86, Backorder=340.00, Ordering=25350.00)
# Episode 449/1000 | Tổng chi phí: 28867.51 (Holding=237.51, Backorder=280.00, Ordering=25150.00)
# Episode 450/1000 | Tổng chi phí: 30521.26 (Holding=221.26, Backorder=400.00, Ordering=25300.00)
# Episode 451/1000 | Tổng chi phí: 28986.22 (Holding=236.22, Backorder=200.00, Ordering=24950.00)
# Episode 452/1000 | Tổng chi phí: 28541.64 (Holding=221.64, Backorder=120.00, Ordering=24800.00)
# Episode 453/1000 | Tổng chi phí: 29791.56 (Holding=221.56, Backorder=220.00, Ordering=24950.00)
# Episode 454/1000 | Tổng chi phí: 30066.36 (Holding=246.36, Backorder=520.00, Ordering=25300.00)
# Episode 455/1000 | Tổng chi phí: 32333.81 (Holding=223.81, Backorder=660.00, Ordering=25450.00)
# Episode 456/1000 | Tổng chi phí: 29450.38 (Holding=230.38, Backorder=420.00, Ordering=24600.00)
# Episode 457/1000 | Tổng chi phí: 32004.38 (Holding=224.38, Backorder=880.00, Ordering=25500.00)
# Episode 458/1000 | Tổng chi phí: 29786.52 (Holding=236.52, Backorder=300.00, Ordering=25250.00)
# Episode 459/1000 | Tổng chi phí: 29154.88 (Holding=234.88, Backorder=420.00, Ordering=25300.00)
# Episode 460/1000 | Tổng chi phí: 30222.08 (Holding=222.08, Backorder=400.00, Ordering=25200.00)
# Episode 461/1000 | Tổng chi phí: 32765.18 (Holding=235.18, Backorder=980.00, Ordering=25350.00)
# Episode 462/1000 | Tổng chi phí: 30331.62 (Holding=241.62, Backorder=840.00, Ordering=25250.00)
# Episode 463/1000 | Tổng chi phí: 29254.60 (Holding=234.60, Backorder=420.00, Ordering=25200.00)
# Episode 464/1000 | Tổng chi phí: 30640.30 (Holding=220.30, Backorder=520.00, Ordering=25500.00)
# Episode 465/1000 | Tổng chi phí: 28844.74 (Holding=244.74, Backorder=300.00, Ordering=24900.00)
# Episode 466/1000 | Tổng chi phí: 30796.47 (Holding=216.47, Backorder=1080.00, Ordering=24900.00)
# Episode 467/1000 | Tổng chi phí: 28340.71 (Holding=230.71, Backorder=460.00, Ordering=25050.00)
# Episode 468/1000 | Tổng chi phí: 28415.84 (Holding=235.84, Backorder=180.00, Ordering=25200.00)
# Episode 469/1000 | Tổng chi phí: 29271.01 (Holding=231.01, Backorder=240.00, Ordering=25600.00)
# Episode 470/1000 | Tổng chi phí: 29467.21 (Holding=247.21, Backorder=520.00, Ordering=25100.00)
# Episode 471/1000 | Tổng chi phí: 29898.85 (Holding=218.85, Backorder=380.00, Ordering=25700.00)
# Episode 472/1000 | Tổng chi phí: 30642.36 (Holding=212.36, Backorder=680.00, Ordering=24750.00)
# Episode 473/1000 | Tổng chi phí: 29240.05 (Holding=240.05, Backorder=200.00, Ordering=25400.00)
# Episode 474/1000 | Tổng chi phí: 28943.45 (Holding=223.45, Backorder=320.00, Ordering=25400.00)
# Episode 475/1000 | Tổng chi phí: 30458.99 (Holding=238.99, Backorder=720.00, Ordering=25300.00)
# Episode 476/1000 | Tổng chi phí: 27841.73 (Holding=231.73, Backorder=360.00, Ordering=24650.00)
# Episode 477/1000 | Tổng chi phí: 27750.14 (Holding=240.14, Backorder=160.00, Ordering=25150.00)
# Episode 478/1000 | Tổng chi phí: 29241.95 (Holding=241.95, Backorder=500.00, Ordering=25100.00)
# Episode 479/1000 | Tổng chi phí: 30762.22 (Holding=222.22, Backorder=340.00, Ordering=25200.00)
# Episode 480/1000 | Tổng chi phí: 30838.27 (Holding=228.27, Backorder=560.00, Ordering=25250.00)
# Episode 481/1000 | Tổng chi phí: 30132.22 (Holding=232.22, Backorder=500.00, Ordering=25600.00)
# Episode 482/1000 | Tổng chi phí: 29504.60 (Holding=234.60, Backorder=520.00, Ordering=25350.00)
# Episode 483/1000 | Tổng chi phí: 29483.37 (Holding=233.37, Backorder=300.00, Ordering=24750.00)
# Episode 484/1000 | Tổng chi phí: 29182.58 (Holding=252.58, Backorder=380.00, Ordering=24950.00)
# Episode 485/1000 | Tổng chi phí: 30096.90 (Holding=226.90, Backorder=420.00, Ordering=25250.00)
# Episode 486/1000 | Tổng chi phí: 31897.21 (Holding=217.21, Backorder=880.00, Ordering=25200.00)
# Episode 487/1000 | Tổng chi phí: 31324.03 (Holding=214.03, Backorder=860.00, Ordering=25450.00)
# Episode 488/1000 | Tổng chi phí: 29384.99 (Holding=234.99, Backorder=300.00, Ordering=25450.00)
# Episode 489/1000 | Tổng chi phí: 29819.07 (Holding=239.07, Backorder=480.00, Ordering=25100.00)
# Episode 490/1000 | Tổng chi phí: 29746.79 (Holding=226.79, Backorder=520.00, Ordering=25200.00)
# Episode 491/1000 | Tổng chi phí: 26659.12 (Holding=269.12, Backorder=140.00, Ordering=25050.00)
# Episode 492/1000 | Tổng chi phí: 29743.26 (Holding=233.26, Backorder=260.00, Ordering=25450.00)
# Episode 493/1000 | Tổng chi phí: 27385.64 (Holding=245.64, Backorder=240.00, Ordering=24300.00)
# Episode 494/1000 | Tổng chi phí: 27564.05 (Holding=254.05, Backorder=160.00, Ordering=24550.00)
# Episode 495/1000 | Tổng chi phí: 29725.32 (Holding=245.32, Backorder=380.00, Ordering=24900.00)
# Episode 496/1000 | Tổng chi phí: 29846.96 (Holding=226.96, Backorder=420.00, Ordering=25200.00)
# Episode 497/1000 | Tổng chi phí: 29111.53 (Holding=231.53, Backorder=180.00, Ordering=24700.00)
# Episode 498/1000 | Tổng chi phí: 30115.59 (Holding=235.59, Backorder=680.00, Ordering=25400.00)
# Episode 499/1000 | Tổng chi phí: 29647.04 (Holding=247.04, Backorder=200.00, Ordering=25200.00)
# Episode 500/1000 | Tổng chi phí: 30008.33 (Holding=228.33, Backorder=580.00, Ordering=24800.00)
# Episode 501/1000 | Tổng chi phí: 28770.82 (Holding=230.82, Backorder=140.00, Ordering=25200.00)
# ...
# Episode 835/1000 | Tổng chi phí: 27939.95 (Holding=229.95, Backorder=160.00, Ordering=25150.00)
# Episode 836/1000 | Tổng chi phí: 28717.75 (Holding=237.75, Backorder=380.00, Ordering=24500.00)
# Episode 837/1000 | Tổng chi phí: 29135.81 (Holding=225.81, Backorder=560.00, Ordering=24950.00)
# Episode 838/1000 | Tổng chi phí: 29167.34 (Holding=237.34, Backorder=280.00, Ordering=25250.00)
# Episode 839/1000 | Tổng chi phí: 28252.74 (Holding=232.74, Backorder=320.00, Ordering=24500.00)
# Episode 840/1000 | Tổng chi phí: 31167.40 (Holding=217.40, Backorder=900.00, Ordering=24650.00)
# Episode 841/1000 | Tổng chi phí: 31499.86 (Holding=219.86, Backorder=980.00, Ordering=25500.00)
# Episode 842/1000 | Tổng chi phí: 29190.05 (Holding=220.05, Backorder=120.00, Ordering=24850.00)
# Episode 843/1000 | Tổng chi phí: 28428.16 (Holding=228.16, Backorder=300.00, Ordering=25300.00)
# Episode 844/1000 | Tổng chi phí: 29330.82 (Holding=230.82, Backorder=300.00, Ordering=25400.00)
# Episode 845/1000 | Tổng chi phí: 29362.19 (Holding=232.19, Backorder=480.00, Ordering=24650.00)
# Episode 846/1000 | Tổng chi phí: 29375.86 (Holding=225.86, Backorder=500.00, Ordering=24650.00)
# Episode 847/1000 | Tổng chi phí: 29133.53 (Holding=233.53, Backorder=200.00, Ordering=25100.00)
# Episode 848/1000 | Tổng chi phí: 31182.77 (Holding=232.77, Backorder=900.00, Ordering=25450.00)
# Episode 849/1000 | Tổng chi phí: 29643.26 (Holding=243.26, Backorder=400.00, Ordering=25000.00)
# Episode 850/1000 | Tổng chi phí: 29029.21 (Holding=239.21, Backorder=240.00, Ordering=25150.00)
# Episode 851/1000 | Tổng chi phí: 28877.78 (Holding=227.78, Backorder=200.00, Ordering=24850.00)
# Episode 852/1000 | Tổng chi phí: 29313.95 (Holding=233.95, Backorder=380.00, Ordering=24900.00)
# Episode 853/1000 | Tổng chi phí: 28038.52 (Holding=238.52, Backorder=100.00, Ordering=24700.00)
# Episode 854/1000 | Tổng chi phí: 28499.10 (Holding=239.10, Backorder=360.00, Ordering=24300.00)
# Episode 855/1000 | Tổng chi phí: 29224.93 (Holding=234.93, Backorder=440.00, Ordering=25150.00)
# Episode 856/1000 | Tổng chi phí: 27131.59 (Holding=251.59, Backorder=80.00, Ordering=24600.00)
# Episode 857/1000 | Tổng chi phí: 28103.59 (Holding=243.59, Backorder=260.00, Ordering=25000.00)
# Episode 858/1000 | Tổng chi phí: 29845.32 (Holding=225.32, Backorder=220.00, Ordering=25400.00)
# Episode 859/1000 | Tổng chi phí: 29224.03 (Holding=234.03, Backorder=240.00, Ordering=25350.00)
# Episode 860/1000 | Tổng chi phí: 29551.21 (Holding=231.21, Backorder=320.00, Ordering=25000.00)
# Episode 861/1000 | Tổng chi phí: 26706.47 (Holding=236.47, Backorder=20.00, Ordering=24850.00)
# Episode 862/1000 | Tổng chi phí: 29789.86 (Holding=239.86, Backorder=300.00, Ordering=25250.00)
# Episode 863/1000 | Tổng chi phí: 29139.84 (Holding=229.84, Backorder=260.00, Ordering=24650.00)
# Episode 864/1000 | Tổng chi phí: 29761.97 (Holding=221.97, Backorder=240.00, Ordering=24500.00)
# Episode 865/1000 | Tổng chi phí: 28291.75 (Holding=231.75, Backorder=260.00, Ordering=25000.00)
# Episode 866/1000 | Tổng chi phí: 29001.29 (Holding=221.29, Backorder=380.00, Ordering=24800.00)
# Episode 867/1000 | Tổng chi phí: 29338.85 (Holding=228.85, Backorder=460.00, Ordering=25050.00)
# Episode 868/1000 | Tổng chi phí: 30729.12 (Holding=229.12, Backorder=500.00, Ordering=25200.00)
# Episode 869/1000 | Tổng chi phí: 30267.15 (Holding=227.15, Backorder=540.00, Ordering=24900.00)
# Episode 870/1000 | Tổng chi phí: 29534.55 (Holding=224.55, Backorder=460.00, Ordering=25050.00)
# Episode 871/1000 | Tổng chi phí: 30070.41 (Holding=220.41, Backorder=300.00, Ordering=25150.00)
# Episode 872/1000 | Tổng chi phí: 29134.71 (Holding=234.71, Backorder=600.00, Ordering=25300.00)
# Episode 873/1000 | Tổng chi phí: 29686.99 (Holding=226.99, Backorder=260.00, Ordering=25000.00)
# Episode 874/1000 | Tổng chi phí: 29130.03 (Holding=240.03, Backorder=240.00, Ordering=24650.00)
# Episode 875/1000 | Tổng chi phí: 29357.37 (Holding=217.37, Backorder=440.00, Ordering=24900.00)
# Episode 876/1000 | Tổng chi phí: 30312.82 (Holding=222.82, Backorder=840.00, Ordering=24850.00)
# Episode 877/1000 | Tổng chi phí: 29168.90 (Holding=208.90, Backorder=360.00, Ordering=25000.00)
# Episode 878/1000 | Tổng chi phí: 30198.52 (Holding=238.52, Backorder=360.00, Ordering=25400.00)
# Episode 879/1000 | Tổng chi phí: 27731.37 (Holding=251.37, Backorder=80.00, Ordering=25000.00)
# Episode 880/1000 | Tổng chi phí: 28611.42 (Holding=231.42, Backorder=280.00, Ordering=24900.00)
# Episode 881/1000 | Tổng chi phí: 30152.16 (Holding=232.16, Backorder=220.00, Ordering=25100.00)
# Episode 882/1000 | Tổng chi phí: 28334.41 (Holding=254.41, Backorder=280.00, Ordering=25000.00)
# Episode 883/1000 | Tổng chi phí: 31479.45 (Holding=229.45, Backorder=700.00, Ordering=25150.00)
# Episode 884/1000 | Tổng chi phí: 31389.01 (Holding=219.01, Backorder=620.00, Ordering=24750.00)
# Episode 885/1000 | Tổng chi phí: 30292.52 (Holding=222.52, Backorder=420.00, Ordering=24850.00)
# Episode 886/1000 | Tổng chi phí: 30464.85 (Holding=244.85, Backorder=320.00, Ordering=25700.00)
# Episode 887/1000 | Tổng chi phí: 29370.58 (Holding=240.58, Backorder=380.00, Ordering=25350.00)
# Episode 888/1000 | Tổng chi phí: 29270.74 (Holding=230.74, Backorder=340.00, Ordering=25100.00)
# Episode 889/1000 | Tổng chi phí: 28628.58 (Holding=248.58, Backorder=80.00, Ordering=25100.00)
# Episode 890/1000 | Tổng chi phí: 29997.62 (Holding=227.62, Backorder=620.00, Ordering=24950.00)
# Episode 891/1000 | Tổng chi phí: 30298.11 (Holding=228.11, Backorder=320.00, Ordering=25150.00)
# Episode 892/1000 | Tổng chi phí: 29158.79 (Holding=228.79, Backorder=280.00, Ordering=25050.00)
# Episode 893/1000 | Tổng chi phí: 29003.26 (Holding=233.26, Backorder=420.00, Ordering=25150.00)
# Episode 894/1000 | Tổng chi phí: 30466.44 (Holding=226.44, Backorder=640.00, Ordering=25000.00)
# Episode 895/1000 | Tổng chi phí: 29700.55 (Holding=220.55, Backorder=380.00, Ordering=25100.00)
# Episode 896/1000 | Tổng chi phí: 28211.40 (Holding=231.40, Backorder=80.00, Ordering=24700.00)
# Episode 897/1000 | Tổng chi phí: 29209.01 (Holding=239.01, Backorder=220.00, Ordering=24950.00)
# Episode 898/1000 | Tổng chi phí: 31643.53 (Holding=223.53, Backorder=1020.00, Ordering=24600.00)
# Episode 899/1000 | Tổng chi phí: 29745.97 (Holding=225.97, Backorder=220.00, Ordering=24900.00)
# Episode 900/1000 | Tổng chi phí: 29778.03 (Holding=228.03, Backorder=600.00, Ordering=24750.00)
# Episode 901/1000 | Tổng chi phí: 30166.66 (Holding=236.66, Backorder=380.00, Ordering=25750.00)
# Episode 902/1000 | Tổng chi phí: 29713.97 (Holding=253.97, Backorder=360.00, Ordering=24700.00)
# Episode 903/1000 | Tổng chi phí: 29564.96 (Holding=234.96, Backorder=580.00, Ordering=24750.00)
# Episode 904/1000 | Tổng chi phí: 28443.78 (Holding=243.78, Backorder=100.00, Ordering=25300.00)
# Episode 905/1000 | Tổng chi phí: 30150.79 (Holding=220.79, Backorder=280.00, Ordering=25250.00)
# Episode 906/1000 | Tổng chi phí: 28943.73 (Holding=243.73, Backorder=200.00, Ordering=24700.00)
# Episode 907/1000 | Tổng chi phí: 30176.27 (Holding=226.27, Backorder=400.00, Ordering=25150.00)
# Episode 908/1000 | Tổng chi phí: 29422.33 (Holding=232.33, Backorder=140.00, Ordering=25250.00)
# Episode 909/1000 | Tổng chi phí: 29417.59 (Holding=227.59, Backorder=340.00, Ordering=25850.00)
# Episode 910/1000 | Tổng chi phí: 28966.99 (Holding=236.99, Backorder=480.00, Ordering=24850.00)
# Episode 911/1000 | Tổng chi phí: 30954.90 (Holding=214.90, Backorder=640.00, Ordering=25100.00)
# Episode 912/1000 | Tổng chi phí: 28721.81 (Holding=241.81, Backorder=180.00, Ordering=24900.00)
# Episode 913/1000 | Tổng chi phí: 30166.66 (Holding=236.66, Backorder=380.00, Ordering=25350.00)
# Episode 914/1000 | Tổng chi phí: 29494.74 (Holding=234.74, Backorder=460.00, Ordering=25000.00)
# Episode 915/1000 | Tổng chi phí: 31294.25 (Holding=234.25, Backorder=560.00, Ordering=25100.00)
# Episode 916/1000 | Tổng chi phí: 29404.68 (Holding=234.68, Backorder=420.00, Ordering=24750.00)
# Episode 917/1000 | Tổng chi phí: 30469.23 (Holding=229.23, Backorder=340.00, Ordering=25300.00)
# Episode 918/1000 | Tổng chi phí: 27281.01 (Holding=251.01, Backorder=80.00, Ordering=25150.00)
# Episode 919/1000 | Tổng chi phí: 30511.62 (Holding=221.62, Backorder=340.00, Ordering=24950.00)
# Episode 920/1000 | Tổng chi phí: 28710.38 (Holding=230.38, Backorder=380.00, Ordering=24900.00)
# Episode 921/1000 | Tổng chi phí: 29959.32 (Holding=229.32, Backorder=480.00, Ordering=24850.00)
# Episode 922/1000 | Tổng chi phí: 28745.32 (Holding=235.32, Backorder=160.00, Ordering=25150.00)
# Episode 923/1000 | Tổng chi phí: 31474.88 (Holding=214.88, Backorder=1060.00, Ordering=25400.00)
# Episode 924/1000 | Tổng chi phí: 28835.78 (Holding=235.78, Backorder=200.00, Ordering=25800.00)
# Episode 925/1000 | Tổng chi phí: 28936.16 (Holding=236.16, Backorder=400.00, Ordering=25100.00)
# Episode 926/1000 | Tổng chi phí: 28145.95 (Holding=225.95, Backorder=120.00, Ordering=24800.00)
# Episode 927/1000 | Tổng chi phí: 30644.11 (Holding=234.11, Backorder=660.00, Ordering=25350.00)
# Episode 928/1000 | Tổng chi phí: 28164.41 (Holding=244.41, Backorder=220.00, Ordering=25300.00)
# Episode 929/1000 | Tổng chi phí: 29424.36 (Holding=224.36, Backorder=300.00, Ordering=24900.00)
# Episode 930/1000 | Tổng chi phí: 28612.55 (Holding=232.55, Backorder=280.00, Ordering=24900.00)
# Episode 931/1000 | Tổng chi phí: 30821.51 (Holding=231.51, Backorder=640.00, Ordering=25150.00)
# Episode 932/1000 | Tổng chi phí: 29781.29 (Holding=241.29, Backorder=340.00, Ordering=25600.00)
# Episode 933/1000 | Tổng chi phí: 30779.67 (Holding=219.67, Backorder=660.00, Ordering=25300.00)
# Episode 934/1000 | Tổng chi phí: 28266.00 (Holding=226.00, Backorder=40.00, Ordering=25000.00)
# Episode 935/1000 | Tổng chi phí: 27743.86 (Holding=243.86, Backorder=100.00, Ordering=25200.00)
# Episode 936/1000 | Tổng chi phí: 29008.27 (Holding=228.27, Backorder=280.00, Ordering=25300.00)
# Episode 937/1000 | Tổng chi phí: 30369.86 (Holding=229.86, Backorder=540.00, Ordering=24400.00)
# Episode 938/1000 | Tổng chi phí: 27631.34 (Holding=231.34, Backorder=0.00, Ordering=25200.00)
# Episode 939/1000 | Tổng chi phí: 29494.30 (Holding=224.30, Backorder=320.00, Ordering=24950.00)
# Episode 940/1000 | Tổng chi phí: 31148.74 (Holding=228.74, Backorder=420.00, Ordering=25300.00)
# Episode 941/1000 | Tổng chi phí: 29699.37 (Holding=229.37, Backorder=420.00, Ordering=25050.00)
# Episode 942/1000 | Tổng chi phí: 32327.07 (Holding=227.07, Backorder=800.00, Ordering=25300.00)
# Episode 943/1000 | Tổng chi phí: 27852.14 (Holding=232.14, Backorder=120.00, Ordering=25100.00)
# Episode 944/1000 | Tổng chi phí: 29883.56 (Holding=233.56, Backorder=100.00, Ordering=25150.00)
# Episode 945/1000 | Tổng chi phí: 29388.00 (Holding=238.00, Backorder=300.00, Ordering=25050.00)
# Episode 946/1000 | Tổng chi phí: 32435.42 (Holding=225.42, Backorder=660.00, Ordering=25150.00)
# Episode 947/1000 | Tổng chi phí: 30026.90 (Holding=236.90, Backorder=340.00, Ordering=25250.00)
# Episode 948/1000 | Tổng chi phí: 29166.38 (Holding=216.38, Backorder=200.00, Ordering=25350.00)
# Episode 949/1000 | Tổng chi phí: 28793.34 (Holding=253.34, Backorder=240.00, Ordering=25300.00)
# Episode 950/1000 | Tổng chi phí: 30999.78 (Holding=219.78, Backorder=780.00, Ordering=25600.00)
# Episode 951/1000 | Tổng chi phí: 30855.10 (Holding=225.10, Backorder=380.00, Ordering=24850.00)
# Episode 952/1000 | Tổng chi phí: 30580.27 (Holding=230.27, Backorder=500.00, Ordering=25450.00)
# Episode 953/1000 | Tổng chi phí: 29711.29 (Holding=231.29, Backorder=180.00, Ordering=25500.00)
# Episode 954/1000 | Tổng chi phí: 28247.97 (Holding=237.97, Backorder=160.00, Ordering=24850.00)
# Episode 955/1000 | Tổng chi phí: 31300.22 (Holding=220.22, Backorder=580.00, Ordering=24900.00)
# Episode 956/1000 | Tổng chi phí: 28391.62 (Holding=241.62, Backorder=100.00, Ordering=24650.00)
# Episode 957/1000 | Tổng chi phí: 29605.70 (Holding=235.70, Backorder=220.00, Ordering=25150.00)
# Episode 958/1000 | Tổng chi phí: 30466.27 (Holding=226.27, Backorder=740.00, Ordering=25100.00)
# Episode 959/1000 | Tổng chi phí: 29306.58 (Holding=236.58, Backorder=320.00, Ordering=24750.00)
# Episode 960/1000 | Tổng chi phí: 30138.03 (Holding=228.03, Backorder=560.00, Ordering=24550.00)
# Episode 961/1000 | Tổng chi phí: 29020.41 (Holding=230.41, Backorder=240.00, Ordering=24750.00)
# Episode 962/1000 | Tổng chi phí: 29476.82 (Holding=216.82, Backorder=360.00, Ordering=25100.00)
# Episode 963/1000 | Tổng chi phí: 29140.19 (Holding=240.19, Backorder=300.00, Ordering=25200.00)
# Episode 964/1000 | Tổng chi phí: 30916.30 (Holding=226.30, Backorder=640.00, Ordering=24850.00)
# Episode 965/1000 | Tổng chi phí: 28566.60 (Holding=236.60, Backorder=380.00, Ordering=24950.00)
# Episode 966/1000 | Tổng chi phí: 29938.08 (Holding=238.08, Backorder=300.00, Ordering=25600.00)
# Episode 967/1000 | Tổng chi phí: 29320.79 (Holding=240.79, Backorder=580.00, Ordering=25100.00)
# Episode 968/1000 | Tổng chi phí: 29374.60 (Holding=234.60, Backorder=240.00, Ordering=25300.00)
# Episode 969/1000 | Tổng chi phí: 29813.84 (Holding=233.84, Backorder=280.00, Ordering=25100.00)
# Episode 970/1000 | Tổng chi phí: 29299.18 (Holding=249.18, Backorder=400.00, Ordering=24850.00)
# Episode 971/1000 | Tổng chi phí: 30121.10 (Holding=231.10, Backorder=640.00, Ordering=24650.00)
# Episode 972/1000 | Tổng chi phí: 29733.95 (Holding=243.95, Backorder=640.00, Ordering=25050.00)
# Episode 973/1000 | Tổng chi phí: 29792.30 (Holding=242.30, Backorder=100.00, Ordering=25250.00)
# Episode 974/1000 | Tổng chi phí: 28663.21 (Holding=233.21, Backorder=180.00, Ordering=24850.00)
# Episode 975/1000 | Tổng chi phí: 28872.71 (Holding=232.71, Backorder=340.00, Ordering=24900.00)
# Episode 976/1000 | Tổng chi phí: 29275.29 (Holding=225.29, Backorder=400.00, Ordering=24850.00)
# Episode 977/1000 | Tổng chi phí: 28330.05 (Holding=240.05, Backorder=140.00, Ordering=24950.00)
# Episode 978/1000 | Tổng chi phí: 30717.53 (Holding=227.53, Backorder=540.00, Ordering=25550.00)
# Episode 979/1000 | Tổng chi phí: 29661.86 (Holding=221.86, Backorder=540.00, Ordering=24900.00)
# Episode 980/1000 | Tổng chi phí: 31079.07 (Holding=229.07, Backorder=800.00, Ordering=25250.00)
# Episode 981/1000 | Tổng chi phí: 28953.62 (Holding=243.62, Backorder=660.00, Ordering=25250.00)
# Episode 982/1000 | Tổng chi phí: 29049.10 (Holding=229.10, Backorder=320.00, Ordering=25300.00)
# Episode 983/1000 | Tổng chi phí: 28192.00 (Holding=232.00, Backorder=260.00, Ordering=24700.00)
# Episode 984/1000 | Tổng chi phí: 31695.40 (Holding=225.40, Backorder=720.00, Ordering=25150.00)
# Episode 985/1000 | Tổng chi phí: 28435.97 (Holding=235.97, Backorder=200.00, Ordering=24800.00)
# Episode 986/1000 | Tổng chi phí: 27343.32 (Holding=253.32, Backorder=40.00, Ordering=25050.00)
# Episode 987/1000 | Tổng chi phí: 30154.41 (Holding=224.41, Backorder=780.00, Ordering=25350.00)
# Episode 988/1000 | Tổng chi phí: 28090.27 (Holding=240.27, Backorder=300.00, Ordering=24750.00)
# Episode 989/1000 | Tổng chi phí: 28948.90 (Holding=228.90, Backorder=320.00, Ordering=25400.00)
# Episode 990/1000 | Tổng chi phí: 29205.92 (Holding=235.92, Backorder=120.00, Ordering=25050.00)
# Episode 991/1000 | Tổng chi phí: 28087.45 (Holding=247.45, Backorder=340.00, Ordering=25100.00)
# Episode 992/1000 | Tổng chi phí: 29924.52 (Holding=224.52, Backorder=300.00, Ordering=25600.00)
# Episode 993/1000 | Tổng chi phí: 29235.18 (Holding=235.18, Backorder=400.00, Ordering=25200.00)
# Episode 994/1000 | Tổng chi phí: 29755.51 (Holding=225.51, Backorder=580.00, Ordering=25150.00)
# Episode 995/1000 | Tổng chi phí: 28294.44 (Holding=254.44, Backorder=140.00, Ordering=24700.00)
# Episode 996/1000 | Tổng chi phí: 29728.71 (Holding=238.71, Backorder=340.00, Ordering=25350.00)
# Episode 997/1000 | Tổng chi phí: 29436.47 (Holding=226.47, Backorder=260.00, Ordering=25150.00)
# Episode 998/1000 | Tổng chi phí: 30266.27 (Holding=226.27, Backorder=540.00, Ordering=25100.00)
# Episode 999/1000 | Tổng chi phí: 28527.26 (Holding=247.26, Backorder=80.00, Ordering=24800.00)
# Episode 1000/1000 | Tổng chi phí: 28599.01 (Holding=239.01, Backorder=260.00, Ordering=24500.00)
#
# ✅ Huấn luyện hoàn tất.

# %%
# Lấy chỉ số hành động tốt nhất cho mỗi trạng thái
policy_idx = np.argmax(Q, axis=1)

# Chuyển sang hành động thực (0/1) và ánh xạ về giá trị inventory position
policy_actions = [actions[i] for i in policy_idx]
policy_map = dict(zip(states, policy_actions))  # {inventory_position: best_action}

# Hiển thị dưới dạng DataFrame (tuỳ chọn)
import pandas as pd
policy_df = pd.DataFrame({
    'ip': states,
    'best_action_idx': policy_idx,
    'best_action': policy_actions,
    'Q0': Q[:,0],
    'Q1': Q[:,1],
})
policy_df.head()
# Out:
#    ip  best_action_idx  best_action           Q0          Q1
# 0 -20                1            1 -1082.592773 -740.393791
# 1 -19                0            0     0.000000 -205.000000
# 2 -18                1            1  -455.000000 -267.500000
# 3 -17                0            0     0.000000 -225.000000
# 4 -16                0            0     0.000000 -145.000000

# %%
# ...existing code...
policy_df.head()

# định nghĩa policy để hàm learned_policy có thể sử dụng
policy = policy_actions
# ...existing code...

# %%
# Mô phỏng đánh giá chính sách
def learned_policy(ip):
    """Chính sách do mô hình học được."""
    return int(policy[ip_to_index(ip)])


def rq_policy(ip):
    """Chính sách (r,q) truyền thống."""
    return 1 if ip <= r else 0


def evaluate(policy_func, days=365 * 5, seed=42):
    """Mô phỏng thực tế trong nhiều ngày để tính chi phí trung bình/ngày."""
    np.random.seed(seed)
    total_cost = 0
    ip = r
    orders_in_transit = 0
    for day in range(days):
        a = policy_func(ip)
        next_ip, _, orders_in_transit, cost = step(ip, orders_in_transit, a)
        ip = next_ip
        total_cost += cost
    return total_cost / days

# %%
# Đánh giá chính sách học được
learned_cost = evaluate(learned_policy)
rq_cost = evaluate(rq_policy)
reduction = (rq_cost - learned_cost) / rq_cost * 100

print(f"\n📊 Kết quả so sánh:")
print(f" - Chính sách học được: {learned_cost:.2f} €/ngày")
print(f" - Chính sách (r,q) truyền thống: {rq_cost:.2f} €/ngày")
print(f" - Tỷ lệ cải thiện: {reduction:.2f}%")
# Out:
# 📊 Kết quả so sánh:
#  - Chính sách học được: 25.76 €/ngày
#  - Chính sách (r,q) truyền thống: 48.44 €/ngày
#  - Tỷ lệ cải thiện: 46.81%

# %%
# Hiển thị chính sách học được
policy_df = pd.DataFrame({
    "inventory_position": states,
    "action (0=no order,1=order)": policy
})

print("\n🔎 Một phần của chính sách học được:")
print(policy_df)
# Out:
# 🔎 Một phần của chính sách học được:
#     inventory_position  action (0=no order,1=order)
# 0                  -20                            1
# 1                  -19                            0
# 2                  -18                            1
# 3                  -17                            0
# 4                  -16                            0
# 5                  -15                            1
# 6                  -14                            0
# 7                  -13                            0
# 8                  -12                            1
# 9                  -11                            1
# 10                 -10                            1
# 11                  -9                            1
# 12                  -8                            1
# 13                  -7                            1
# 14                  -6                            1
# 15                  -5                            1
# 16                  -4                            1
# 17                  -3                            1
# 18                  -2                            1
# 19                  -1                            1
# 20                   0                            1
# 21                   1                            1
# 22                   2                            1
# 23                   3                            1
# 24                   4                            1
# 25                   5                            1
# 26                   6                            1
# 27                   7                            1
# 28                   8                            1
# 29                   9                            1
# 30                  10                            0
# 31                  11                            0
# 32                  12                            0
# 33                  13                            0
# 34                  14                            0
# 35                  15                            0
# 36                  16                            0
# 37                  17                            0
# 38                  18                            0
# 39                  19                            0
# 40                  20                            0

# %%
# ===============================================================
# 🔟 Mô phỏng 30 ngày – đầy đủ các biến để quan sát (giống bài báo)
# ===============================================================
np.random.seed(123)
days = np.arange(1, 31)  # mô phỏng 30 ngày
ip = r
orders_in_transit = 0
records = []

for day in days:
    a = learned_policy(ip)   # hành động theo chính sách đã học
    d = sample_demand()      # nhu cầu ngẫu nhiên mỗi ngày
    arrivals = 0

    # Nếu hôm nay có hàng về (lead time = 1)
    if orders_in_transit > 0:
        arrivals = orders_in_transit
        orders_in_transit = 0

    inventory_before = ip
    ip_after = ip + arrivals - d

    # Nếu hôm nay đặt hàng, hàng sẽ đến ngày sau
    if a == 1:
        orders_in_transit = q

    # 🔹 Tính chi phí hằng ngày
    holding_cost = h * max(ip_after, 0)
    backorder_cost = b * max(-ip_after, 0)
    ordering_cost = O if a == 1 else 0
    total_cost = holding_cost + backorder_cost + ordering_cost

    # Ghi lại dữ liệu từng ngày
    records.append({
        "day": day,
        "demand": d,
        "inventory_before": inventory_before,
        "order_action": a,
        "arrivals_today": arrivals,
        "inventory_after": ip_after,
        "daily_cost": total_cost
    })

    ip = ip_after

# 🔸 Tạo DataFrame kết quả
df_sim = pd.DataFrame(records)
print("\n📅 Dữ liệu mô phỏng 30 ngày đầu:")
print(df_sim.to_string(index=False))
# Out:
# 📅 Dữ liệu mô phỏng 30 ngày đầu:
#  day  demand  inventory_before  order_action  arrivals_today  inventory_after  daily_cost
#    1       2                 5             1               0                3   50.082192
#    2       4                 3             1               6                5   50.136986
#    3       3                 5             1               6                8   50.219178
#    4       1                 8             1               6               13   50.356164
#    5       2                13             0               6               17    0.465753
#    6       5                17             0               0               12    0.328767
#    7       1                12             0               0               11    0.301370
#    8       3                11             0               0                8    0.219178
#    9       4                 8             1               0                4   50.109589
#   10       2                 4             1               6                8   50.219178
#   11       2                 8             1               6               12   50.328767
#   12       3                12             0               6               15    0.410959
#   13       4                15             0               0               11    0.301370
#   14       2                11             0               0                9    0.246575
#   15       3                 9             1               0                6   50.164384
#   16       3                 6             1               6                9   50.246575
#   17       5                 9             1               6               10   50.273973
#   18       5                10             0               6               11    0.301370
#   19       4                11             0               0                7    0.191781
#   20       3                 7             1               0                4   50.109589
#   21       4                 4             1               6                6   50.164384
#   22       4                 6             1               6                8   50.219178
#   23       2                 8             1               6               12   50.328767
#   24       4                12             0               6               14    0.383562
#   25       2                14             0               0               12    0.328767
#   26       2                12             0               0               10    0.273973
#   27       4                10             0               0                6    0.164384
#   28       2                 6             1               0                4   50.109589
#   29       3                 4             1               6                7   50.191781
#   30       2                 7             1               6               11   50.301370
