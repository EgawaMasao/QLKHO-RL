# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Vấn đề:
# - Xem xét bộ phận máy móc CNC (Computer Numerical Control), nơi các máy cần nguyên liệu thô để hoàn thành quá trình gia công. Để đáp ứng yêu cầu nguyên vật liệu thô từ các máy, đơn đặt hàng nguyên vật liệu thô được đặt tại kho nguyên vật liệu thô, được giả định có công suất vô hạn. Các công nhân vận hành máy kiểm tra mức tồn kho nguyên vật liệu thô mỗi chu kỳ t (mỗi ngày) và nhận nguyên vật liệu thô được yêu cầu sau một chu kỳ (tức là thời gian giao hàng - procurement lead time), được giả định là hằng số và bằng một ngày (nguyên vật liệu thô luôn được giao vào ngày làm việc tiếp theo). Phân tích này được thực hiện cho máy móc quan trọng (critical machine) và lượng tiêu thụ nguyên vật liệu thô là độc lập và được phân phối theo phân phối chuẩn (normal distribution) với giá trị trung bình μ và độ lệch chuẩn σ
#
# # Input:
# ## Chi phí kho
# - O = 50.0 # Chi phí đặt hàng
# - h_year = 10.0 # Chi phí lưu trữ (10 đô cho 1 sản phẩm / năm)
# - b = 20.0 # Chi phí thiếu hàng (20 đô cho 1 mỗi sản phẩm tồn đọng)
# - LT = 1 # Lead Time = 1 ngày (đơn hàng được đặt hôm nay sẽ đến vào ngày kế tiếp)
# - days_per_year = 365 # Số ngày trong một năm
# - h = h_year/days_per_year # Chi phí lưu trữ quy đổi theo ngày
# - q = 6 # Số lượng đặt hàng mỗi lần
# - r = 3 # Mức tồn kho đặt hàng lại (reorder point) => đây là miêu tả bài toán không phải chi phí kho
#
# ## Nhu cầu
# - mu = 3.0        # Nhu cầu trung bình mỗi ngày
# - sigma = 1.0     # Độ lệch chuẩn của nhu cầu
#
# ## Tham số của Q-learning
# - alpha = 0.2 # Tốc độ học
# - gamma = 0.9 # Hệ số chiết khấu (gamma trong khoảng từ 0=>1)
# - num_episodes = 1000      # tổng số chu kỳ học
# - episode_length = 1000    # mỗi chu kỳ = 1000 ngày mô phỏng
#
# # Output:
# - Chính sách nhập hàng tối ưu gồm:
# + Số lượng hàng trong kho không quá nhiều, đủ để máy chạy mà không thiếu nguyên liệu => Chi phí lưu kho và chi phí thiếu hàng sẽ giảm
# + không bị thiếu hàng quá nhiều => Dẫn đến máy không có nguyên liệu và hình phạt nặng do chi phí thiếu hàng lớn sẽ làm cho daily cost tăng
# +
#
# # Độ đo: trong bài báo không đề cập

# %%
# Khởi tạo tham số cho mô hình
# Chi phí kho
O = 50.0 # Chi phí đặt hàng
h_year = 10.0 # Chi phí lưu trữ (10 đô cho 1 sản phẩm / năm)
b = 20.0 # Chi phí thiếu hàng (20 đô cho 1 mỗi sản phẩm tồn đọng)
LT = 1 # Lead Time = 1 ngày (đơn hàng được đặt hôm nay sẽ đến vào ngày kế tiếp)
days_per_year = 365 # Số ngày trong một năm
h = h_year/days_per_year # Chi phí lưu trữ quy đổi theo ngày
q = 6 # Số lượng đặt hàng mỗi lần
r = 3 # Mức tồn kho đặt hàng lại (reorder point)

# Nhu cầu
mu = 3.0        # Nhu cầu trung bình mỗi ngày
sigma = 1.0     # Độ lệch chuẩn của nhu cầu

# Tham số của Q-learning
alpha = 0.2 # Tốc độ học
gamma = 0.9 # Hệ số chiết khấu (0<gamma<1)
epsilon = 0.1 # Hệ số khám phá là 10%
num_episodes = 1000      # tổng số chu kỳ học
episode_length = 1000    # mỗi chu kỳ = 1000 ngày mô phỏng

# %%
# Môi trường học (state, action)

# Trạng thái: vị trí tồn kho (inventory position)
# Dải giá trị tồn kho [-20, 20] (âm = thiếu hàng)
min_IP, max_IP = -20, 20
states = np.arange(min_IP, max_IP + 1)

# Hành động: 0 = không đặt hàng, 1 = đặt hàng (số lượng q)
actions = [0, 1]

# Khởi tạo bảng Q-table (số trạng thái x số hành động)
Q = np.zeros((len(states), len(actions)))

def ip_to_index(ip):
    """Chuyển giá trị tồn kho sang chỉ số mảng Q-table """
    return int(np.clip(round(ip), min_IP, max_IP)) - min_IP


def sample_demand():
    """Tạo nhu cầu ngẫu nhiên theo phân phối chuẩn N(μ, σ), không âm."""
    d = np.random.normal(mu, sigma)
    return max(0, int(round(d)))


def step(ip, orders_in_transit, action):
    # Nhập hàng đến
    arrivals = 0
    if orders_in_transit > 0:
        arrivals = orders_in_transit
        orders_in_transit = 0

    # Cập nhật tồn kho sau khi nhận hàng
    ip_after_arrival = ip + arrivals

    # Trừ đi nhu cầu
    d = sample_demand()
    ip_after_demand = ip_after_arrival - d

    # Nếu hành động = đặt hàng → đơn hàng sẽ đến vào ngày sau
    order_placed = False
    if action == 1:
        order_placed = True
        orders_in_transit = q
    
    # Tính chi phí
    holding_cost = h * max(ip_after_demand, 0)
    backorder_cost = b * max(-ip_after_demand, 0)
    ordering_cost = O if order_placed else 0

    # HÌNH PHẠT: nếu tồn kho < r và không đặt hàng thì phạt 200
    penalty = 0.0
    if ip_after_demand < r and not order_placed:
        penalty = 200.0

    total_cost = holding_cost + backorder_cost + ordering_cost + penalty

    # Phần thưởng = -chi phí (RL muốn tối đa hóa reward)
    reward = -total_cost
    next_ip = ip_after_demand

    return next_ip, reward, orders_in_transit, total_cost

# %%
# ...existing code...
# -----------------------------
# 5️⃣ Vòng lặp huấn luyện Q-learning (epsilon cố định = 0.1, in log từng episode)
# -----------------------------
episode_costs = []
episode_holding = []
episode_backorder = []
episode_ordering = []

epsilon = 0.1  # Xác suất khám phá cố định

for ep in range(num_episodes):

    ip = r  # tồn kho ban đầu = điểm đặt hàng lại
    orders_in_transit = 0
    total_cost_ep = 0
    holding_ep = 0
    backorder_ep = 0
    ordering_ep = 0

    for day in range(episode_length):
        s_idx = ip_to_index(ip)

        # Epsilon-greedy: khám phá hoặc khai thác
        if np.random.rand() < epsilon:
            a = np.random.choice(actions)
        else:
            qvals = Q[s_idx, :]
            a = np.random.choice(np.flatnonzero(qvals == qvals.max()))

        # --- Mô phỏng một bước ---
        arrivals = 0
        if orders_in_transit > 0:
            arrivals = orders_in_transit
            orders_in_transit = 0

        ip_after_arrival = ip + arrivals
        d = sample_demand()
        ip_after_demand = ip_after_arrival - d

        order_placed = False
        if a == 1:
            order_placed = True
            orders_in_transit = q

        holding_cost = h * max(ip_after_demand, 0)
        backorder_cost = b * max(-ip_after_demand, 0)
        ordering_cost = O if order_placed else 0

        # HÌNH PHẠT: nếu tồn kho < r và không đặt hàng thì phạt 200
        penalty = 0.0
        if ip_after_demand < r and not order_placed:
            penalty = 200.0

        total_cost = holding_cost + backorder_cost + ordering_cost + penalty

        reward = -total_cost
        next_ip = ip_after_demand

        # --- Cập nhật Q-learning ---
        s_next = ip_to_index(next_ip)
        Q[s_idx, a] += alpha * (reward + gamma * np.max(Q[s_next, :]) - Q[s_idx, a])

        # --- Cộng dồn chi phí ---
        total_cost_ep += total_cost
        holding_ep += holding_cost
        backorder_ep += backorder_cost
        ordering_ep += ordering_cost

        ip = next_ip

    # Lưu kết quả của episode này
    episode_costs.append(total_cost_ep)
    episode_holding.append(holding_ep)
    episode_backorder.append(backorder_ep)
    episode_ordering.append(ordering_ep)

    # ✅ In ra từng episode
    print(f"Episode {ep + 1}/{num_episodes} | Tổng chi phí: {total_cost_ep:.2f} "
          f"(Holding={holding_ep:.2f}, Backorder={backorder_ep:.2f}, Ordering={ordering_ep:.2f})")

print("\n✅ Huấn luyện hoàn tất.")
# ...existing code...
# Out:
# Episode 1/1000 | Tổng chi phí: 146334.16 (Holding=124.16, Backorder=89060.00, Ordering=25350.00)
# Episode 2/1000 | Tổng chi phí: 42845.37 (Holding=175.37, Backorder=8820.00, Ordering=24650.00)
# Episode 3/1000 | Tổng chi phí: 38716.33 (Holding=166.33, Backorder=5000.00, Ordering=24750.00)
# Episode 4/1000 | Tổng chi phí: 38453.70 (Holding=153.70, Backorder=3900.00, Ordering=25400.00)
# Episode 5/1000 | Tổng chi phí: 31458.77 (Holding=168.77, Backorder=1740.00, Ordering=25150.00)
# Episode 6/1000 | Tổng chi phí: 65584.19 (Holding=154.19, Backorder=27580.00, Ordering=25450.00)
# Episode 7/1000 | Tổng chi phí: 31886.82 (Holding=166.82, Backorder=1220.00, Ordering=25300.00)
# Episode 8/1000 | Tổng chi phí: 31461.78 (Holding=181.78, Backorder=2280.00, Ordering=24800.00)
# Episode 9/1000 | Tổng chi phí: 30781.26 (Holding=171.26, Backorder=1160.00, Ordering=25450.00)
# Episode 10/1000 | Tổng chi phí: 32765.97 (Holding=175.97, Backorder=2340.00, Ordering=24850.00)
# Episode 11/1000 | Tổng chi phí: 39050.52 (Holding=160.52, Backorder=5540.00, Ordering=25350.00)
# Episode 12/1000 | Tổng chi phí: 30226.27 (Holding=166.27, Backorder=1260.00, Ordering=24800.00)
# Episode 13/1000 | Tổng chi phí: 34780.00 (Holding=160.00, Backorder=2220.00, Ordering=25400.00)
# Episode 14/1000 | Tổng chi phí: 43605.81 (Holding=185.81, Backorder=11720.00, Ordering=24700.00)
# Episode 15/1000 | Tổng chi phí: 28258.03 (Holding=178.03, Backorder=880.00, Ordering=25000.00)
# Episode 16/1000 | Tổng chi phí: 34290.47 (Holding=150.47, Backorder=2840.00, Ordering=25300.00)
# Episode 17/1000 | Tổng chi phí: 33869.07 (Holding=169.07, Backorder=3100.00, Ordering=25200.00)
# Episode 18/1000 | Tổng chi phí: 31743.04 (Holding=173.04, Backorder=1620.00, Ordering=24950.00)
# Episode 19/1000 | Tổng chi phí: 32097.51 (Holding=167.51, Backorder=1680.00, Ordering=25050.00)
# Episode 20/1000 | Tổng chi phí: 32121.26 (Holding=181.26, Backorder=1540.00, Ordering=25200.00)
# Episode 21/1000 | Tổng chi phí: 32203.95 (Holding=163.95, Backorder=1840.00, Ordering=24800.00)
# Episode 22/1000 | Tổng chi phí: 34725.70 (Holding=165.70, Backorder=3260.00, Ordering=25100.00)
# Episode 23/1000 | Tổng chi phí: 31816.14 (Holding=166.14, Backorder=1800.00, Ordering=24450.00)
# Episode 24/1000 | Tổng chi phí: 34771.21 (Holding=161.21, Backorder=2660.00, Ordering=24950.00)
# Episode 25/1000 | Tổng chi phí: 31420.88 (Holding=160.88, Backorder=1560.00, Ordering=25500.00)
# Episode 26/1000 | Tổng chi phí: 35771.78 (Holding=161.78, Backorder=3260.00, Ordering=25350.00)
# Episode 27/1000 | Tổng chi phí: 31231.15 (Holding=171.15, Backorder=1560.00, Ordering=24900.00)
# Episode 28/1000 | Tổng chi phí: 29164.19 (Holding=194.19, Backorder=620.00, Ordering=25350.00)
# Episode 29/1000 | Tổng chi phí: 28022.38 (Holding=182.38, Backorder=740.00, Ordering=25100.00)
# Episode 30/1000 | Tổng chi phí: 35208.44 (Holding=168.44, Backorder=2840.00, Ordering=25400.00)
# Episode 31/1000 | Tổng chi phí: 31637.07 (Holding=167.07, Backorder=1620.00, Ordering=25050.00)
# Episode 32/1000 | Tổng chi phí: 30175.48 (Holding=175.48, Backorder=1200.00, Ordering=25000.00)
# Episode 33/1000 | Tổng chi phí: 36566.68 (Holding=146.68, Backorder=3420.00, Ordering=25600.00)
# Episode 34/1000 | Tổng chi phí: 32944.47 (Holding=154.47, Backorder=1640.00, Ordering=24950.00)
# Episode 35/1000 | Tổng chi phí: 33073.84 (Holding=173.84, Backorder=1800.00, Ordering=25300.00)
# Episode 36/1000 | Tổng chi phí: 29793.40 (Holding=163.40, Backorder=880.00, Ordering=24950.00)
# Episode 37/1000 | Tổng chi phí: 33020.96 (Holding=150.96, Backorder=2220.00, Ordering=25450.00)
# Episode 38/1000 | Tổng chi phí: 30370.93 (Holding=170.93, Backorder=1200.00, Ordering=25000.00)
# Episode 39/1000 | Tổng chi phí: 30910.63 (Holding=170.63, Backorder=1140.00, Ordering=25400.00)
# Episode 40/1000 | Tổng chi phí: 34644.19 (Holding=144.19, Backorder=2700.00, Ordering=24800.00)
# Episode 41/1000 | Tổng chi phí: 34209.86 (Holding=149.86, Backorder=2260.00, Ordering=25200.00)
# Episode 42/1000 | Tổng chi phí: 33989.07 (Holding=159.07, Backorder=2380.00, Ordering=24850.00)
# Episode 43/1000 | Tổng chi phí: 30296.82 (Holding=176.82, Backorder=1220.00, Ordering=25300.00)
# Episode 44/1000 | Tổng chi phí: 27981.18 (Holding=171.18, Backorder=760.00, Ordering=25050.00)
# Episode 45/1000 | Tổng chi phí: 27460.74 (Holding=180.74, Backorder=580.00, Ordering=24700.00)
# Episode 46/1000 | Tổng chi phí: 29858.58 (Holding=168.58, Backorder=1340.00, Ordering=25150.00)
# Episode 47/1000 | Tổng chi phí: 31917.97 (Holding=157.97, Backorder=1760.00, Ordering=25400.00)
# Episode 48/1000 | Tổng chi phí: 36624.60 (Holding=154.60, Backorder=4120.00, Ordering=24950.00)
# Episode 49/1000 | Tổng chi phí: 30681.23 (Holding=161.23, Backorder=1220.00, Ordering=24900.00)
# Episode 50/1000 | Tổng chi phí: 34788.19 (Holding=148.19, Backorder=3240.00, Ordering=24600.00)
# Episode 51/1000 | Tổng chi phí: 33286.14 (Holding=166.14, Backorder=2720.00, Ordering=25200.00)
# Episode 52/1000 | Tổng chi phí: 34930.88 (Holding=140.88, Backorder=3040.00, Ordering=25150.00)
# Episode 53/1000 | Tổng chi phí: 28172.79 (Holding=182.79, Backorder=540.00, Ordering=25050.00)
# Episode 54/1000 | Tổng chi phí: 32328.36 (Holding=158.36, Backorder=1720.00, Ordering=24850.00)
# Episode 55/1000 | Tổng chi phí: 32318.96 (Holding=168.96, Backorder=1800.00, Ordering=25550.00)
# Episode 56/1000 | Tổng chi phí: 33929.26 (Holding=149.26, Backorder=2080.00, Ordering=25500.00)
# Episode 57/1000 | Tổng chi phí: 34186.85 (Holding=146.85, Backorder=2740.00, Ordering=25100.00)
# Episode 58/1000 | Tổng chi phí: 34023.67 (Holding=163.67, Backorder=1960.00, Ordering=25100.00)
# Episode 59/1000 | Tổng chi phí: 28586.93 (Holding=186.93, Backorder=600.00, Ordering=25200.00)
# Episode 60/1000 | Tổng chi phí: 32588.74 (Holding=188.74, Backorder=2600.00, Ordering=24800.00)
# Episode 61/1000 | Tổng chi phí: 29000.47 (Holding=180.47, Backorder=1120.00, Ordering=24900.00)
# Episode 62/1000 | Tổng chi phí: 35324.77 (Holding=174.77, Backorder=4000.00, Ordering=24750.00)
# Episode 63/1000 | Tổng chi phí: 32419.70 (Holding=189.70, Backorder=1980.00, Ordering=24850.00)
# Episode 64/1000 | Tổng chi phí: 29906.00 (Holding=176.00, Backorder=780.00, Ordering=24950.00)
# Episode 65/1000 | Tổng chi phí: 32029.32 (Holding=169.32, Backorder=1360.00, Ordering=25100.00)
# Episode 66/1000 | Tổng chi phí: 35560.08 (Holding=160.08, Backorder=3100.00, Ordering=24700.00)
# Episode 67/1000 | Tổng chi phí: 28359.01 (Holding=189.01, Backorder=620.00, Ordering=24750.00)
# Episode 68/1000 | Tổng chi phí: 32198.14 (Holding=188.14, Backorder=1760.00, Ordering=25250.00)
# Episode 69/1000 | Tổng chi phí: 28972.14 (Holding=172.14, Backorder=900.00, Ordering=25300.00)
# Episode 70/1000 | Tổng chi phí: 30923.48 (Holding=173.48, Backorder=1300.00, Ordering=24850.00)
# Episode 71/1000 | Tổng chi phí: 30113.32 (Holding=173.32, Backorder=1540.00, Ordering=24600.00)
# Episode 72/1000 | Tổng chi phí: 32460.14 (Holding=160.14, Backorder=2000.00, Ordering=24900.00)
# Episode 73/1000 | Tổng chi phí: 31583.12 (Holding=163.12, Backorder=2120.00, Ordering=24900.00)
# Episode 74/1000 | Tổng chi phí: 33260.85 (Holding=160.85, Backorder=2000.00, Ordering=25500.00)
# Episode 75/1000 | Tổng chi phí: 32919.92 (Holding=169.92, Backorder=2400.00, Ordering=25350.00)
# Episode 76/1000 | Tổng chi phí: 31222.93 (Holding=172.93, Backorder=1500.00, Ordering=25350.00)
# Episode 77/1000 | Tổng chi phí: 29712.11 (Holding=182.11, Backorder=680.00, Ordering=25450.00)
# Episode 78/1000 | Tổng chi phí: 30938.05 (Holding=178.05, Backorder=1760.00, Ordering=24600.00)
# Episode 79/1000 | Tổng chi phí: 33160.52 (Holding=160.52, Backorder=2500.00, Ordering=25300.00)
# Episode 80/1000 | Tổng chi phí: 32866.41 (Holding=166.41, Backorder=2100.00, Ordering=25000.00)
# Episode 81/1000 | Tổng chi phí: 34830.47 (Holding=150.47, Backorder=2180.00, Ordering=25100.00)
# Episode 82/1000 | Tổng chi phí: 29150.30 (Holding=170.30, Backorder=980.00, Ordering=25000.00)
# Episode 83/1000 | Tổng chi phí: 34186.47 (Holding=146.47, Backorder=2640.00, Ordering=25200.00)
# Episode 84/1000 | Tổng chi phí: 32869.12 (Holding=159.12, Backorder=1960.00, Ordering=24750.00)
# Episode 85/1000 | Tổng chi phí: 33527.04 (Holding=157.04, Backorder=2220.00, Ordering=24750.00)
# Episode 86/1000 | Tổng chi phí: 31032.60 (Holding=162.60, Backorder=1720.00, Ordering=25150.00)
# Episode 87/1000 | Tổng chi phí: 31598.63 (Holding=158.63, Backorder=2040.00, Ordering=24600.00)
# Episode 88/1000 | Tổng chi phí: 35052.60 (Holding=162.60, Backorder=2840.00, Ordering=25050.00)
# Episode 89/1000 | Tổng chi phí: 30778.19 (Holding=168.19, Backorder=1360.00, Ordering=25250.00)
# Episode 90/1000 | Tổng chi phí: 38565.59 (Holding=155.59, Backorder=4660.00, Ordering=24950.00)
# Episode 91/1000 | Tổng chi phí: 29308.85 (Holding=168.85, Backorder=940.00, Ordering=25400.00)
# Episode 92/1000 | Tổng chi phí: 34339.78 (Holding=159.78, Backorder=3280.00, Ordering=24900.00)
# Episode 93/1000 | Tổng chi phí: 32252.82 (Holding=172.82, Backorder=1380.00, Ordering=25100.00)
# Episode 94/1000 | Tổng chi phí: 32883.70 (Holding=173.70, Backorder=2560.00, Ordering=25350.00)
# Episode 95/1000 | Tổng chi phí: 31993.21 (Holding=153.21, Backorder=1740.00, Ordering=25300.00)
# Episode 96/1000 | Tổng chi phí: 34694.60 (Holding=154.60, Backorder=2640.00, Ordering=24700.00)
# Episode 97/1000 | Tổng chi phí: 37954.63 (Holding=154.63, Backorder=7000.00, Ordering=24800.00)
# Episode 98/1000 | Tổng chi phí: 32995.89 (Holding=155.89, Backorder=2040.00, Ordering=25600.00)
# Episode 99/1000 | Tổng chi phí: 32590.77 (Holding=180.77, Backorder=1960.00, Ordering=25050.00)
# Episode 100/1000 | Tổng chi phí: 30649.32 (Holding=179.32, Backorder=1420.00, Ordering=24850.00)
# Episode 101/1000 | Tổng chi phí: 32179.56 (Holding=159.56, Backorder=1820.00, Ordering=25000.00)
# Episode 102/1000 | Tổng chi phí: 27331.18 (Holding=201.18, Backorder=380.00, Ordering=24950.00)
# Episode 103/1000 | Tổng chi phí: 30908.66 (Holding=188.66, Backorder=1520.00, Ordering=25200.00)
# Episode 104/1000 | Tổng chi phí: 29058.27 (Holding=178.27, Backorder=980.00, Ordering=24700.00)
# Episode 105/1000 | Tổng chi phí: 27438.63 (Holding=198.63, Backorder=540.00, Ordering=24500.00)
# Episode 106/1000 | Tổng chi phí: 28964.63 (Holding=174.63, Backorder=1040.00, Ordering=24350.00)
# Episode 107/1000 | Tổng chi phí: 30026.58 (Holding=166.58, Backorder=1360.00, Ordering=24700.00)
# Episode 108/1000 | Tổng chi phí: 32039.15 (Holding=169.15, Backorder=2020.00, Ordering=24850.00)
# Episode 109/1000 | Tổng chi phí: 31702.58 (Holding=172.58, Backorder=1980.00, Ordering=24950.00)
# Episode 110/1000 | Tổng chi phí: 30456.58 (Holding=166.58, Backorder=1440.00, Ordering=25050.00)
# Episode 111/1000 | Tổng chi phí: 29470.85 (Holding=180.85, Backorder=840.00, Ordering=24650.00)
# Episode 112/1000 | Tổng chi phí: 34878.55 (Holding=158.55, Backorder=2720.00, Ordering=25200.00)
# Episode 113/1000 | Tổng chi phí: 34496.03 (Holding=156.03, Backorder=2440.00, Ordering=25500.00)
# Episode 114/1000 | Tổng chi phí: 33800.03 (Holding=160.03, Backorder=2040.00, Ordering=25200.00)
# Episode 115/1000 | Tổng chi phí: 30869.81 (Holding=189.81, Backorder=1180.00, Ordering=25500.00)
# Episode 116/1000 | Tổng chi phí: 31400.99 (Holding=170.99, Backorder=1380.00, Ordering=25250.00)
# Episode 117/1000 | Tổng chi phí: 30788.77 (Holding=178.77, Backorder=860.00, Ordering=24950.00)
# Episode 118/1000 | Tổng chi phí: 31053.92 (Holding=183.92, Backorder=1220.00, Ordering=25050.00)
# Episode 119/1000 | Tổng chi phí: 31038.82 (Holding=168.82, Backorder=1420.00, Ordering=25050.00)
# Episode 120/1000 | Tổng chi phí: 29442.79 (Holding=182.79, Backorder=1160.00, Ordering=25100.00)
# Episode 121/1000 | Tổng chi phí: 32153.34 (Holding=163.34, Backorder=1640.00, Ordering=25150.00)
# Episode 122/1000 | Tổng chi phí: 35363.97 (Holding=153.97, Backorder=2560.00, Ordering=24850.00)
# Episode 123/1000 | Tổng chi phí: 29368.16 (Holding=168.16, Backorder=900.00, Ordering=24900.00)
# Episode 124/1000 | Tổng chi phí: 29963.10 (Holding=173.10, Backorder=1340.00, Ordering=25050.00)
# Episode 125/1000 | Tổng chi phí: 30358.77 (Holding=168.77, Backorder=1340.00, Ordering=25050.00)
# Episode 126/1000 | Tổng chi phí: 35005.70 (Holding=155.70, Backorder=2900.00, Ordering=25550.00)
# Episode 127/1000 | Tổng chi phí: 33266.08 (Holding=156.08, Backorder=2160.00, Ordering=25150.00)
# Episode 128/1000 | Tổng chi phí: 33066.96 (Holding=176.96, Backorder=1940.00, Ordering=25150.00)
# Episode 129/1000 | Tổng chi phí: 32169.95 (Holding=179.95, Backorder=2140.00, Ordering=25050.00)
# Episode 130/1000 | Tổng chi phí: 31180.52 (Holding=180.52, Backorder=1600.00, Ordering=25200.00)
# Episode 131/1000 | Tổng chi phí: 33447.26 (Holding=167.26, Backorder=2180.00, Ordering=25100.00)
# Episode 132/1000 | Tổng chi phí: 29320.60 (Holding=180.60, Backorder=740.00, Ordering=25600.00)
# Episode 133/1000 | Tổng chi phí: 32858.19 (Holding=168.19, Backorder=1740.00, Ordering=25150.00)
# Episode 134/1000 | Tổng chi phí: 30100.19 (Holding=170.19, Backorder=1180.00, Ordering=24950.00)
# Episode 135/1000 | Tổng chi phí: 35790.63 (Holding=150.63, Backorder=3740.00, Ordering=25100.00)
# Episode 136/1000 | Tổng chi phí: 33183.10 (Holding=163.10, Backorder=2020.00, Ordering=25400.00)
# Episode 137/1000 | Tổng chi phí: 31499.15 (Holding=179.15, Backorder=1820.00, Ordering=24900.00)
# Episode 138/1000 | Tổng chi phí: 28916.68 (Holding=176.68, Backorder=940.00, Ordering=25000.00)
# Episode 139/1000 | Tổng chi phí: 31260.85 (Holding=160.85, Backorder=1500.00, Ordering=25200.00)
# Episode 140/1000 | Tổng chi phí: 32885.37 (Holding=155.37, Backorder=1880.00, Ordering=24650.00)
# Episode 141/1000 | Tổng chi phí: 31356.96 (Holding=166.96, Backorder=1440.00, Ordering=25150.00)
# Episode 142/1000 | Tổng chi phí: 32652.79 (Holding=162.79, Backorder=2240.00, Ordering=25050.00)
# Episode 143/1000 | Tổng chi phí: 29707.15 (Holding=177.15, Backorder=1080.00, Ordering=25050.00)
# Episode 144/1000 | Tổng chi phí: 34098.16 (Holding=148.16, Backorder=2600.00, Ordering=24750.00)
# Episode 145/1000 | Tổng chi phí: 34044.79 (Holding=154.79, Backorder=2140.00, Ordering=25550.00)
# Episode 146/1000 | Tổng chi phí: 30123.32 (Holding=173.32, Backorder=1100.00, Ordering=24650.00)
# Episode 147/1000 | Tổng chi phí: 27477.26 (Holding=177.26, Backorder=500.00, Ordering=25000.00)
# Episode 148/1000 | Tổng chi phí: 31580.22 (Holding=160.22, Backorder=1620.00, Ordering=25400.00)
# Episode 149/1000 | Tổng chi phí: 32972.44 (Holding=162.44, Backorder=2460.00, Ordering=25150.00)
# Episode 150/1000 | Tổng chi phí: 31919.67 (Holding=179.67, Backorder=1640.00, Ordering=25100.00)
# Episode 151/1000 | Tổng chi phí: 34069.67 (Holding=159.67, Backorder=2560.00, Ordering=25150.00)
# Episode 152/1000 | Tổng chi phí: 30494.66 (Holding=164.66, Backorder=1080.00, Ordering=25050.00)
# Episode 153/1000 | Tổng chi phí: 32583.64 (Holding=163.64, Backorder=2120.00, Ordering=24700.00)
# Episode 154/1000 | Tổng chi phí: 32691.51 (Holding=161.51, Backorder=2280.00, Ordering=25050.00)
# Episode 155/1000 | Tổng chi phí: 41260.14 (Holding=150.14, Backorder=8460.00, Ordering=25250.00)
# Episode 156/1000 | Tổng chi phí: 32138.00 (Holding=168.00, Backorder=1820.00, Ordering=24950.00)
# Episode 157/1000 | Tổng chi phí: 31395.86 (Holding=165.86, Backorder=1880.00, Ordering=25150.00)
# Episode 158/1000 | Tổng chi phí: 41829.51 (Holding=149.51, Backorder=5480.00, Ordering=25000.00)
# Episode 159/1000 | Tổng chi phí: 38969.86 (Holding=149.86, Backorder=4020.00, Ordering=25400.00)
# Episode 160/1000 | Tổng chi phí: 29761.12 (Holding=171.12, Backorder=1240.00, Ordering=25350.00)
# Episode 161/1000 | Tổng chi phí: 32341.40 (Holding=151.40, Backorder=2640.00, Ordering=25350.00)
# Episode 162/1000 | Tổng chi phí: 33355.48 (Holding=165.48, Backorder=2340.00, Ordering=24850.00)
# Episode 163/1000 | Tổng chi phí: 33954.44 (Holding=154.44, Backorder=2400.00, Ordering=25200.00)
# Episode 164/1000 | Tổng chi phí: 29751.92 (Holding=171.92, Backorder=980.00, Ordering=25200.00)
# Episode 165/1000 | Tổng chi phí: 33154.52 (Holding=164.52, Backorder=1740.00, Ordering=25050.00)
# Episode 166/1000 | Tổng chi phí: 30448.79 (Holding=178.79, Backorder=1620.00, Ordering=24850.00)
# Episode 167/1000 | Tổng chi phí: 35110.74 (Holding=150.74, Backorder=3360.00, Ordering=24800.00)
# Episode 168/1000 | Tổng chi phí: 30241.70 (Holding=181.70, Backorder=1660.00, Ordering=24800.00)
# Episode 169/1000 | Tổng chi phí: 32414.55 (Holding=174.55, Backorder=2340.00, Ordering=24700.00)
# Episode 170/1000 | Tổng chi phí: 38627.32 (Holding=147.32, Backorder=4180.00, Ordering=25100.00)
# Episode 171/1000 | Tổng chi phí: 35674.82 (Holding=154.82, Backorder=2920.00, Ordering=25400.00)
# Episode 172/1000 | Tổng chi phí: 30976.03 (Holding=166.03, Backorder=1460.00, Ordering=24950.00)
# Episode 173/1000 | Tổng chi phí: 32590.93 (Holding=150.93, Backorder=1740.00, Ordering=24700.00)
# Episode 174/1000 | Tổng chi phí: 35975.59 (Holding=155.59, Backorder=3320.00, Ordering=25100.00)
# Episode 175/1000 | Tổng chi phí: 31936.14 (Holding=166.14, Backorder=1420.00, Ordering=25150.00)
# Episode 176/1000 | Tổng chi phí: 33068.85 (Holding=168.85, Backorder=2000.00, Ordering=25300.00)
# Episode 177/1000 | Tổng chi phí: 30401.10 (Holding=181.10, Backorder=1420.00, Ordering=25000.00)
# Episode 178/1000 | Tổng chi phí: 30713.26 (Holding=173.26, Backorder=1240.00, Ordering=24900.00)
# Episode 179/1000 | Tổng chi phí: 31449.78 (Holding=169.78, Backorder=1380.00, Ordering=24900.00)
# Episode 180/1000 | Tổng chi phí: 31561.26 (Holding=151.26, Backorder=1560.00, Ordering=24850.00)
# Episode 181/1000 | Tổng chi phí: 27385.81 (Holding=175.81, Backorder=560.00, Ordering=24850.00)
# Episode 182/1000 | Tổng chi phí: 32886.63 (Holding=166.63, Backorder=1720.00, Ordering=24800.00)
# Episode 183/1000 | Tổng chi phí: 28642.22 (Holding=182.22, Backorder=460.00, Ordering=25000.00)
# Episode 184/1000 | Tổng chi phí: 31348.36 (Holding=158.36, Backorder=1440.00, Ordering=25350.00)
# Episode 185/1000 | Tổng chi phí: 34261.15 (Holding=161.15, Backorder=2400.00, Ordering=25300.00)
# Episode 186/1000 | Tổng chi phí: 30619.18 (Holding=169.18, Backorder=1500.00, Ordering=24950.00)
# Episode 187/1000 | Tổng chi phí: 31104.19 (Holding=164.19, Backorder=1340.00, Ordering=25000.00)
# Episode 188/1000 | Tổng chi phí: 32445.40 (Holding=165.40, Backorder=2380.00, Ordering=24900.00)
# Episode 189/1000 | Tổng chi phí: 31651.07 (Holding=161.07, Backorder=1540.00, Ordering=25150.00)
# Episode 190/1000 | Tổng chi phí: 37410.36 (Holding=140.36, Backorder=3220.00, Ordering=25050.00)
# Episode 191/1000 | Tổng chi phí: 34805.89 (Holding=155.89, Backorder=2700.00, Ordering=24550.00)
# Episode 192/1000 | Tổng chi phí: 29674.22 (Holding=184.22, Backorder=1040.00, Ordering=25450.00)
# Episode 193/1000 | Tổng chi phí: 31024.85 (Holding=164.85, Backorder=1560.00, Ordering=25500.00)
# Episode 194/1000 | Tổng chi phí: 32285.53 (Holding=155.53, Backorder=1780.00, Ordering=24750.00)
# Episode 195/1000 | Tổng chi phí: 33231.73 (Holding=151.73, Backorder=1880.00, Ordering=25400.00)
# Episode 196/1000 | Tổng chi phí: 31907.56 (Holding=177.56, Backorder=1580.00, Ordering=24550.00)
# Episode 197/1000 | Tổng chi phí: 30718.58 (Holding=168.58, Backorder=2200.00, Ordering=24550.00)
# Episode 198/1000 | Tổng chi phí: 33597.04 (Holding=137.04, Backorder=2260.00, Ordering=25600.00)
# Episode 199/1000 | Tổng chi phí: 33821.81 (Holding=161.81, Backorder=2260.00, Ordering=25000.00)
# Episode 200/1000 | Tổng chi phí: 30670.82 (Holding=180.82, Backorder=840.00, Ordering=25450.00)
# Episode 201/1000 | Tổng chi phí: 33503.81 (Holding=153.81, Backorder=2700.00, Ordering=24650.00)
# Episode 202/1000 | Tổng chi phí: 30802.47 (Holding=182.47, Backorder=1520.00, Ordering=24900.00)
# Episode 203/1000 | Tổng chi phí: 29024.03 (Holding=194.03, Backorder=880.00, Ordering=25350.00)
# Episode 204/1000 | Tổng chi phí: 33365.21 (Holding=165.21, Backorder=2100.00, Ordering=24900.00)
# Episode 205/1000 | Tổng chi phí: 31984.25 (Holding=164.25, Backorder=2020.00, Ordering=25200.00)
# Episode 206/1000 | Tổng chi phí: 36617.32 (Holding=147.32, Backorder=2820.00, Ordering=25450.00)
# Episode 207/1000 | Tổng chi phí: 35975.75 (Holding=155.75, Backorder=3220.00, Ordering=25000.00)
# Episode 208/1000 | Tổng chi phí: 31531.07 (Holding=171.07, Backorder=1360.00, Ordering=25200.00)
# Episode 209/1000 | Tổng chi phí: 28338.96 (Holding=198.96, Backorder=540.00, Ordering=25000.00)
# Episode 210/1000 | Tổng chi phí: 31799.15 (Holding=189.15, Backorder=1660.00, Ordering=25150.00)
# Episode 211/1000 | Tổng chi phí: 29790.33 (Holding=170.33, Backorder=920.00, Ordering=25500.00)
# Episode 212/1000 | Tổng chi phí: 35882.41 (Holding=162.41, Backorder=3720.00, Ordering=24800.00)
# Episode 213/1000 | Tổng chi phí: 33186.14 (Holding=156.14, Backorder=2180.00, Ordering=25050.00)
# Episode 214/1000 | Tổng chi phí: 30671.32 (Holding=161.32, Backorder=1360.00, Ordering=24750.00)
# Episode 215/1000 | Tổng chi phí: 29777.95 (Holding=177.95, Backorder=1000.00, Ordering=25000.00)
# Episode 216/1000 | Tổng chi phí: 29797.01 (Holding=187.01, Backorder=660.00, Ordering=24950.00)
# Episode 217/1000 | Tổng chi phí: 32794.66 (Holding=164.66, Backorder=1380.00, Ordering=25450.00)
# Episode 218/1000 | Tổng chi phí: 32157.01 (Holding=167.01, Backorder=2040.00, Ordering=25150.00)
# Episode 219/1000 | Tổng chi phí: 31678.16 (Holding=168.16, Backorder=1360.00, Ordering=25350.00)
# Episode 220/1000 | Tổng chi phí: 32238.68 (Holding=168.68, Backorder=1220.00, Ordering=24850.00)
# Episode 221/1000 | Tổng chi phí: 34957.78 (Holding=167.78, Backorder=2740.00, Ordering=25250.00)
# Episode 222/1000 | Tổng chi phí: 29593.81 (Holding=173.81, Backorder=1220.00, Ordering=25000.00)
# Episode 223/1000 | Tổng chi phí: 35551.56 (Holding=151.56, Backorder=3100.00, Ordering=25100.00)
# Episode 224/1000 | Tổng chi phí: 31401.32 (Holding=161.32, Backorder=1940.00, Ordering=24700.00)
# Episode 225/1000 | Tổng chi phí: 29289.51 (Holding=179.51, Backorder=1760.00, Ordering=24750.00)
# Episode 226/1000 | Tổng chi phí: 29794.03 (Holding=174.03, Backorder=1120.00, Ordering=25100.00)
# Episode 227/1000 | Tổng chi phí: 31541.26 (Holding=171.26, Backorder=1520.00, Ordering=24650.00)
# Episode 228/1000 | Tổng chi phí: 34583.34 (Holding=163.34, Backorder=2420.00, Ordering=25000.00)
# Episode 229/1000 | Tổng chi phí: 29486.68 (Holding=176.68, Backorder=760.00, Ordering=25150.00)
# Episode 230/1000 | Tổng chi phí: 31565.84 (Holding=165.84, Backorder=1300.00, Ordering=25100.00)
# Episode 231/1000 | Tổng chi phí: 32509.75 (Holding=169.75, Backorder=1940.00, Ordering=25200.00)
# Episode 232/1000 | Tổng chi phí: 33357.45 (Holding=157.45, Backorder=2200.00, Ordering=24800.00)
# Episode 233/1000 | Tổng chi phí: 35192.27 (Holding=162.27, Backorder=2980.00, Ordering=25050.00)
# Episode 234/1000 | Tổng chi phí: 30041.89 (Holding=171.89, Backorder=1520.00, Ordering=25150.00)
# Episode 235/1000 | Tổng chi phí: 28150.49 (Holding=180.49, Backorder=520.00, Ordering=25450.00)
# Episode 236/1000 | Tổng chi phí: 34030.77 (Holding=160.77, Backorder=2420.00, Ordering=25050.00)
# Episode 237/1000 | Tổng chi phí: 31053.32 (Holding=173.32, Backorder=1980.00, Ordering=24500.00)
# Episode 238/1000 | Tổng chi phí: 32597.75 (Holding=157.75, Backorder=1840.00, Ordering=25400.00)
# Episode 239/1000 | Tổng chi phí: 29426.05 (Holding=176.05, Backorder=1500.00, Ordering=24750.00)
# Episode 240/1000 | Tổng chi phí: 32879.07 (Holding=159.07, Backorder=2420.00, Ordering=25300.00)
# Episode 241/1000 | Tổng chi phí: 31460.77 (Holding=160.77, Backorder=1500.00, Ordering=25000.00)
# Episode 242/1000 | Tổng chi phí: 31356.00 (Holding=156.00, Backorder=1300.00, Ordering=24700.00)
# Episode 243/1000 | Tổng chi phí: 28325.01 (Holding=185.01, Backorder=740.00, Ordering=25400.00)
# Episode 244/1000 | Tổng chi phí: 31182.99 (Holding=162.99, Backorder=1820.00, Ordering=24800.00)
# Episode 245/1000 | Tổng chi phí: 34156.71 (Holding=156.71, Backorder=2100.00, Ordering=25300.00)
# Episode 246/1000 | Tổng chi phí: 29351.42 (Holding=191.42, Backorder=860.00, Ordering=25100.00)
# Episode 247/1000 | Tổng chi phí: 31796.96 (Holding=166.96, Backorder=1780.00, Ordering=25250.00)
# Episode 248/1000 | Tổng chi phí: 30822.74 (Holding=182.74, Backorder=1640.00, Ordering=25000.00)
# Episode 249/1000 | Tổng chi phí: 31012.82 (Holding=172.82, Backorder=1540.00, Ordering=25300.00)
# Episode 250/1000 | Tổng chi phí: 30670.44 (Holding=180.44, Backorder=1440.00, Ordering=25050.00)
# Episode 251/1000 | Tổng chi phí: 33627.62 (Holding=177.62, Backorder=2100.00, Ordering=25350.00)
# Episode 252/1000 | Tổng chi phí: 35463.53 (Holding=163.53, Backorder=3400.00, Ordering=25100.00)
# Episode 253/1000 | Tổng chi phí: 33832.85 (Holding=162.85, Backorder=2620.00, Ordering=25050.00)
# Episode 254/1000 | Tổng chi phí: 30299.81 (Holding=179.81, Backorder=1220.00, Ordering=24700.00)
# Episode 255/1000 | Tổng chi phí: 29508.41 (Holding=178.41, Backorder=980.00, Ordering=25150.00)
# Episode 256/1000 | Tổng chi phí: 36554.27 (Holding=144.27, Backorder=3060.00, Ordering=25350.00)
# Episode 257/1000 | Tổng chi phí: 30662.66 (Holding=152.66, Backorder=1360.00, Ordering=24750.00)
# Episode 258/1000 | Tổng chi phí: 34045.18 (Holding=165.18, Backorder=1980.00, Ordering=25500.00)
# Episode 259/1000 | Tổng chi phí: 28428.14 (Holding=188.14, Backorder=640.00, Ordering=25200.00)
# Episode 260/1000 | Tổng chi phí: 31933.64 (Holding=163.64, Backorder=1820.00, Ordering=25350.00)
# Episode 261/1000 | Tổng chi phí: 34862.88 (Holding=152.88, Backorder=2060.00, Ordering=25050.00)
# Episode 262/1000 | Tổng chi phí: 30209.15 (Holding=179.15, Backorder=1080.00, Ordering=24950.00)
# Episode 263/1000 | Tổng chi phí: 32940.22 (Holding=160.22, Backorder=1880.00, Ordering=25100.00)
# Episode 264/1000 | Tổng chi phí: 33156.90 (Holding=156.90, Backorder=2000.00, Ordering=25400.00)
# Episode 265/1000 | Tổng chi phí: 36858.99 (Holding=158.99, Backorder=4000.00, Ordering=24700.00)
# Episode 266/1000 | Tổng chi phí: 30119.15 (Holding=179.15, Backorder=1340.00, Ordering=25000.00)
# Episode 267/1000 | Tổng chi phí: 32489.84 (Holding=169.84, Backorder=1920.00, Ordering=24800.00)
# Episode 268/1000 | Tổng chi phí: 29718.96 (Holding=178.96, Backorder=840.00, Ordering=25300.00)
# Episode 269/1000 | Tổng chi phí: 31629.01 (Holding=159.01, Backorder=1220.00, Ordering=25250.00)
# Episode 270/1000 | Tổng chi phí: 33385.42 (Holding=145.42, Backorder=2240.00, Ordering=25200.00)
# Episode 271/1000 | Tổng chi phí: 31865.53 (Holding=165.53, Backorder=1900.00, Ordering=24800.00)
# Episode 272/1000 | Tổng chi phí: 35331.84 (Holding=151.84, Backorder=2580.00, Ordering=25400.00)
# Episode 273/1000 | Tổng chi phí: 29344.63 (Holding=174.63, Backorder=1020.00, Ordering=25150.00)
# Episode 274/1000 | Tổng chi phí: 32748.82 (Holding=168.82, Backorder=2080.00, Ordering=24900.00)
# Episode 275/1000 | Tổng chi phí: 30855.86 (Holding=155.86, Backorder=1400.00, Ordering=25300.00)
# Episode 276/1000 | Tổng chi phí: 27653.84 (Holding=193.84, Backorder=460.00, Ordering=24600.00)
# Episode 277/1000 | Tổng chi phí: 31731.86 (Holding=181.86, Backorder=2100.00, Ordering=24650.00)
# Episode 278/1000 | Tổng chi phí: 34512.90 (Holding=152.90, Backorder=2760.00, Ordering=25200.00)
# Episode 279/1000 | Tổng chi phí: 27753.37 (Holding=173.37, Backorder=480.00, Ordering=24900.00)
# Episode 280/1000 | Tổng chi phí: 34292.05 (Holding=152.05, Backorder=2140.00, Ordering=25600.00)
# Episode 281/1000 | Tổng chi phí: 34254.11 (Holding=164.11, Backorder=2340.00, Ordering=25350.00)
# Episode 282/1000 | Tổng chi phí: 31323.59 (Holding=163.59, Backorder=1860.00, Ordering=25100.00)
# Episode 283/1000 | Tổng chi phí: 31402.77 (Holding=162.77, Backorder=1840.00, Ordering=24800.00)
# Episode 284/1000 | Tổng chi phí: 31497.04 (Holding=157.04, Backorder=1440.00, Ordering=24900.00)
# Episode 285/1000 | Tổng chi phí: 31197.15 (Holding=177.15, Backorder=1320.00, Ordering=24900.00)
# Episode 286/1000 | Tổng chi phí: 34941.45 (Holding=161.45, Backorder=2480.00, Ordering=25100.00)
# Episode 287/1000 | Tổng chi phí: 29732.55 (Holding=172.55, Backorder=760.00, Ordering=25000.00)
# Episode 288/1000 | Tổng chi phí: 30858.63 (Holding=168.63, Backorder=1440.00, Ordering=25250.00)
# Episode 289/1000 | Tổng chi phí: 29730.00 (Holding=180.00, Backorder=1200.00, Ordering=24550.00)
# Episode 290/1000 | Tổng chi phí: 29246.05 (Holding=166.05, Backorder=1080.00, Ordering=24800.00)
# Episode 291/1000 | Tổng chi phí: 28837.34 (Holding=167.34, Backorder=920.00, Ordering=24750.00)
# Episode 292/1000 | Tổng chi phí: 33274.77 (Holding=164.77, Backorder=2360.00, Ordering=25350.00)
# Episode 293/1000 | Tổng chi phí: 34157.89 (Holding=147.89, Backorder=2360.00, Ordering=25850.00)
# Episode 294/1000 | Tổng chi phí: 33011.51 (Holding=161.51, Backorder=1900.00, Ordering=24950.00)
# Episode 295/1000 | Tổng chi phí: 33239.12 (Holding=149.12, Backorder=2340.00, Ordering=24950.00)
# Episode 296/1000 | Tổng chi phí: 33672.38 (Holding=172.38, Backorder=2300.00, Ordering=25200.00)
# Episode 297/1000 | Tổng chi phí: 28887.97 (Holding=177.97, Backorder=860.00, Ordering=25450.00)
# Episode 298/1000 | Tổng chi phí: 31497.89 (Holding=157.89, Backorder=1440.00, Ordering=25500.00)
# Episode 299/1000 | Tổng chi phí: 31008.25 (Holding=178.25, Backorder=1680.00, Ordering=24950.00)
# Episode 300/1000 | Tổng chi phí: 30769.92 (Holding=169.92, Backorder=1300.00, Ordering=24900.00)
# Episode 301/1000 | Tổng chi phí: 31227.21 (Holding=187.21, Backorder=1840.00, Ordering=24800.00)
# Episode 302/1000 | Tổng chi phí: 31602.41 (Holding=172.41, Backorder=1880.00, Ordering=25150.00)
# Episode 303/1000 | Tổng chi phí: 29507.10 (Holding=177.10, Backorder=780.00, Ordering=24950.00)
# Episode 304/1000 | Tổng chi phí: 30724.66 (Holding=164.66, Backorder=960.00, Ordering=25600.00)
# Episode 305/1000 | Tổng chi phí: 33274.58 (Holding=164.58, Backorder=1960.00, Ordering=25150.00)
# Episode 306/1000 | Tổng chi phí: 32466.60 (Holding=166.60, Backorder=1600.00, Ordering=25100.00)
# Episode 307/1000 | Tổng chi phí: 34216.44 (Holding=156.44, Backorder=2460.00, Ordering=25200.00)
# Episode 308/1000 | Tổng chi phí: 34977.26 (Holding=157.26, Backorder=3020.00, Ordering=25000.00)
# Episode 309/1000 | Tổng chi phí: 31137.12 (Holding=167.12, Backorder=1320.00, Ordering=25050.00)
# Episode 310/1000 | Tổng chi phí: 31542.58 (Holding=182.58, Backorder=1360.00, Ordering=24800.00)
# Episode 311/1000 | Tổng chi phí: 33148.11 (Holding=168.11, Backorder=2380.00, Ordering=25200.00)
# Episode 312/1000 | Tổng chi phí: 30954.36 (Holding=164.36, Backorder=1340.00, Ordering=24850.00)
# Episode 313/1000 | Tổng chi phí: 31930.77 (Holding=160.77, Backorder=2120.00, Ordering=24850.00)
# Episode 314/1000 | Tổng chi phí: 29219.75 (Holding=189.75, Backorder=1080.00, Ordering=24950.00)
# Episode 315/1000 | Tổng chi phí: 30575.12 (Holding=175.12, Backorder=800.00, Ordering=25000.00)
# Episode 316/1000 | Tổng chi phí: 32361.23 (Holding=171.23, Backorder=1840.00, Ordering=25150.00)
# Episode 317/1000 | Tổng chi phí: 30727.73 (Holding=167.73, Backorder=1460.00, Ordering=25100.00)
# Episode 318/1000 | Tổng chi phí: 32163.21 (Holding=163.21, Backorder=1900.00, Ordering=24900.00)
# Episode 319/1000 | Tổng chi phí: 36499.89 (Holding=149.89, Backorder=3100.00, Ordering=25050.00)
# Episode 320/1000 | Tổng chi phí: 35887.95 (Holding=147.95, Backorder=2740.00, Ordering=25200.00)
# Episode 321/1000 | Tổng chi phí: 33866.90 (Holding=156.90, Backorder=2060.00, Ordering=25250.00)
# Episode 322/1000 | Tổng chi phí: 31366.60 (Holding=166.60, Backorder=1100.00, Ordering=25300.00)
# Episode 323/1000 | Tổng chi phí: 34452.55 (Holding=152.55, Backorder=2100.00, Ordering=25200.00)
# Episode 324/1000 | Tổng chi phí: 32309.73 (Holding=159.73, Backorder=2100.00, Ordering=24850.00)
# Episode 325/1000 | Tổng chi phí: 33265.78 (Holding=165.78, Backorder=1700.00, Ordering=25200.00)
# Episode 326/1000 | Tổng chi phí: 32082.90 (Holding=162.90, Backorder=1720.00, Ordering=25000.00)
# Episode 327/1000 | Tổng chi phí: 30394.41 (Holding=174.41, Backorder=1820.00, Ordering=25000.00)
# Episode 328/1000 | Tổng chi phí: 30974.60 (Holding=164.60, Backorder=1260.00, Ordering=24950.00)
# Episode 329/1000 | Tổng chi phí: 32887.01 (Holding=167.01, Backorder=1820.00, Ordering=25100.00)
# Episode 330/1000 | Tổng chi phí: 29460.68 (Holding=170.68, Backorder=940.00, Ordering=24950.00)
# Episode 331/1000 | Tổng chi phí: 32794.30 (Holding=164.30, Backorder=2380.00, Ordering=24850.00)
# Episode 332/1000 | Tổng chi phí: 32022.27 (Holding=162.27, Backorder=1460.00, Ordering=25200.00)
# Episode 333/1000 | Tổng chi phí: 31936.44 (Holding=166.44, Backorder=1620.00, Ordering=24950.00)
# Episode 334/1000 | Tổng chi phí: 32190.74 (Holding=160.74, Backorder=1480.00, Ordering=25550.00)
# Episode 335/1000 | Tổng chi phí: 32930.77 (Holding=150.77, Backorder=1980.00, Ordering=24800.00)
# Episode 336/1000 | Tổng chi phí: 34805.04 (Holding=145.04, Backorder=2960.00, Ordering=25300.00)
# Episode 337/1000 | Tổng chi phí: 32419.73 (Holding=169.73, Backorder=1600.00, Ordering=25650.00)
# Episode 338/1000 | Tổng chi phí: 30396.41 (Holding=166.41, Backorder=1080.00, Ordering=25150.00)
# Episode 339/1000 | Tổng chi phí: 32214.58 (Holding=174.58, Backorder=1940.00, Ordering=25300.00)
# Episode 340/1000 | Tổng chi phí: 29949.78 (Holding=199.78, Backorder=900.00, Ordering=25450.00)
# Episode 341/1000 | Tổng chi phí: 32904.16 (Holding=164.16, Backorder=1340.00, Ordering=25400.00)
# Episode 342/1000 | Tổng chi phí: 30717.56 (Holding=167.56, Backorder=1400.00, Ordering=24350.00)
# Episode 343/1000 | Tổng chi phí: 30250.96 (Holding=170.96, Backorder=1980.00, Ordering=24700.00)
# Episode 344/1000 | Tổng chi phí: 28848.68 (Holding=208.68, Backorder=740.00, Ordering=25300.00)
# Episode 345/1000 | Tổng chi phí: 30581.18 (Holding=181.18, Backorder=1500.00, Ordering=25300.00)
# Episode 346/1000 | Tổng chi phí: 31938.55 (Holding=158.55, Backorder=1680.00, Ordering=25500.00)
# Episode 347/1000 | Tổng chi phí: 32553.26 (Holding=173.26, Backorder=1880.00, Ordering=25100.00)
# Episode 348/1000 | Tổng chi phí: 28001.56 (Holding=191.56, Backorder=860.00, Ordering=25350.00)
# Episode 349/1000 | Tổng chi phí: 33466.11 (Holding=146.11, Backorder=2220.00, Ordering=25500.00)
# Episode 350/1000 | Tổng chi phí: 29572.22 (Holding=162.22, Backorder=1060.00, Ordering=25150.00)
# Episode 351/1000 | Tổng chi phí: 31568.52 (Holding=158.52, Backorder=1960.00, Ordering=24850.00)
# Episode 352/1000 | Tổng chi phí: 33080.88 (Holding=160.88, Backorder=1620.00, Ordering=25300.00)
# Episode 353/1000 | Tổng chi phí: 31055.59 (Holding=175.59, Backorder=1280.00, Ordering=25400.00)
# Episode 354/1000 | Tổng chi phí: 30067.89 (Holding=187.89, Backorder=1780.00, Ordering=25100.00)
# Episode 355/1000 | Tổng chi phí: 34640.90 (Holding=160.90, Backorder=2680.00, Ordering=25400.00)
# Episode 356/1000 | Tổng chi phí: 29764.82 (Holding=194.82, Backorder=1320.00, Ordering=25050.00)
# Episode 357/1000 | Tổng chi phí: 30423.37 (Holding=173.37, Backorder=1600.00, Ordering=25050.00)
# Episode 358/1000 | Tổng chi phí: 31970.82 (Holding=160.82, Backorder=1860.00, Ordering=24750.00)
# Episode 359/1000 | Tổng chi phí: 31107.34 (Holding=167.34, Backorder=1540.00, Ordering=24800.00)
# Episode 360/1000 | Tổng chi phí: 29861.15 (Holding=181.15, Backorder=1080.00, Ordering=25400.00)
# Episode 361/1000 | Tổng chi phí: 32860.14 (Holding=160.14, Backorder=2400.00, Ordering=25100.00)
# Episode 362/1000 | Tổng chi phí: 34367.26 (Holding=157.26, Backorder=2860.00, Ordering=24550.00)
# Episode 363/1000 | Tổng chi phí: 31664.82 (Holding=164.82, Backorder=2000.00, Ordering=25100.00)
# Episode 364/1000 | Tổng chi phí: 31956.47 (Holding=176.47, Backorder=1580.00, Ordering=25400.00)
# Episode 365/1000 | Tổng chi phí: 36266.82 (Holding=156.82, Backorder=3660.00, Ordering=24650.00)
# Episode 366/1000 | Tổng chi phí: 31187.56 (Holding=157.56, Backorder=1580.00, Ordering=25250.00)
# Episode 367/1000 | Tổng chi phí: 34455.84 (Holding=165.84, Backorder=1940.00, Ordering=25150.00)
# Episode 368/1000 | Tổng chi phí: 32302.58 (Holding=172.58, Backorder=1980.00, Ordering=24750.00)
# Episode 369/1000 | Tổng chi phí: 34110.44 (Holding=170.44, Backorder=2340.00, Ordering=24600.00)
# Episode 370/1000 | Tổng chi phí: 35511.07 (Holding=151.07, Backorder=3560.00, Ordering=25200.00)
# Episode 371/1000 | Tổng chi phí: 29965.84 (Holding=185.84, Backorder=1380.00, Ordering=24600.00)
# Episode 372/1000 | Tổng chi phí: 35168.82 (Holding=168.82, Backorder=2100.00, Ordering=24700.00)
# Episode 373/1000 | Tổng chi phí: 27794.82 (Holding=204.82, Backorder=340.00, Ordering=24450.00)
# Episode 374/1000 | Tổng chi phí: 26045.89 (Holding=195.89, Backorder=200.00, Ordering=24650.00)
# Episode 375/1000 | Tổng chi phí: 29268.96 (Holding=178.96, Backorder=740.00, Ordering=25150.00)
# Episode 376/1000 | Tổng chi phí: 27960.49 (Holding=200.49, Backorder=860.00, Ordering=24700.00)
# Episode 377/1000 | Tổng chi phí: 33680.85 (Holding=170.85, Backorder=2460.00, Ordering=25050.00)
# Episode 378/1000 | Tổng chi phí: 35123.18 (Holding=153.18, Backorder=3320.00, Ordering=24850.00)
# Episode 379/1000 | Tổng chi phí: 28562.30 (Holding=172.30, Backorder=940.00, Ordering=24650.00)
# Episode 380/1000 | Tổng chi phí: 31906.93 (Holding=166.93, Backorder=2040.00, Ordering=24900.00)
# Episode 381/1000 | Tổng chi phí: 31499.51 (Holding=169.51, Backorder=1380.00, Ordering=25150.00)
# Episode 382/1000 | Tổng chi phí: 33676.68 (Holding=156.68, Backorder=1920.00, Ordering=24800.00)
# Episode 383/1000 | Tổng chi phí: 30942.71 (Holding=162.71, Backorder=1680.00, Ordering=24900.00)
# Episode 384/1000 | Tổng chi phí: 37420.74 (Holding=150.74, Backorder=3120.00, Ordering=24950.00)
# Episode 385/1000 | Tổng chi phí: 32990.47 (Holding=150.47, Backorder=2140.00, Ordering=24700.00)
# Episode 386/1000 | Tổng chi phí: 31398.36 (Holding=168.36, Backorder=1780.00, Ordering=25050.00)
# Episode 387/1000 | Tổng chi phí: 30373.07 (Holding=183.07, Backorder=1440.00, Ordering=24950.00)
# Episode 388/1000 | Tổng chi phí: 36236.41 (Holding=156.41, Backorder=3280.00, Ordering=25200.00)
# Episode 389/1000 | Tổng chi phí: 28969.42 (Holding=179.42, Backorder=740.00, Ordering=25050.00)
# Episode 390/1000 | Tổng chi phí: 29476.27 (Holding=166.27, Backorder=1260.00, Ordering=24850.00)
# Episode 391/1000 | Tổng chi phí: 35735.04 (Holding=155.04, Backorder=2780.00, Ordering=25200.00)
# Episode 392/1000 | Tổng chi phí: 31652.55 (Holding=162.55, Backorder=1940.00, Ordering=24950.00)
# Episode 393/1000 | Tổng chi phí: 33620.99 (Holding=170.99, Backorder=2300.00, Ordering=25350.00)
# Episode 394/1000 | Tổng chi phí: 32710.30 (Holding=170.30, Backorder=1640.00, Ordering=25300.00)
# Episode 395/1000 | Tổng chi phí: 33826.71 (Holding=176.71, Backorder=2600.00, Ordering=25250.00)
# Episode 396/1000 | Tổng chi phí: 27484.22 (Holding=204.22, Backorder=480.00, Ordering=25000.00)
# Episode 397/1000 | Tổng chi phí: 27938.60 (Holding=188.60, Backorder=400.00, Ordering=24750.00)
# Episode 398/1000 | Tổng chi phí: 31347.29 (Holding=167.29, Backorder=2080.00, Ordering=25500.00)
# Episode 399/1000 | Tổng chi phí: 33716.77 (Holding=166.77, Backorder=2000.00, Ordering=25150.00)
# Episode 400/1000 | Tổng chi phí: 29848.38 (Holding=178.38, Backorder=1020.00, Ordering=25050.00)
# Episode 401/1000 | Tổng chi phí: 31030.05 (Holding=180.05, Backorder=1400.00, Ordering=25050.00)
# Episode 402/1000 | Tổng chi phí: 34321.97 (Holding=151.97, Backorder=2120.00, Ordering=25050.00)
# Episode 403/1000 | Tổng chi phí: 31246.16 (Holding=166.16, Backorder=1480.00, Ordering=25400.00)
# Episode 404/1000 | Tổng chi phí: 31885.73 (Holding=165.73, Backorder=1320.00, Ordering=25200.00)
# Episode 405/1000 | Tổng chi phí: 37624.58 (Holding=144.58, Backorder=3480.00, Ordering=24800.00)
# Episode 406/1000 | Tổng chi phí: 32697.01 (Holding=167.01, Backorder=2380.00, Ordering=24550.00)
# Episode 407/1000 | Tổng chi phí: 34729.73 (Holding=169.73, Backorder=2060.00, Ordering=25300.00)
# Episode 408/1000 | Tổng chi phí: 28680.33 (Holding=180.33, Backorder=1100.00, Ordering=24600.00)
# Episode 409/1000 | Tổng chi phí: 28926.47 (Holding=176.47, Backorder=1000.00, Ordering=24750.00)
# Episode 410/1000 | Tổng chi phí: 35734.03 (Holding=154.03, Backorder=2780.00, Ordering=24600.00)
# Episode 411/1000 | Tổng chi phí: 32885.15 (Holding=165.15, Backorder=1820.00, Ordering=25300.00)
# Episode 412/1000 | Tổng chi phí: 26334.49 (Holding=184.49, Backorder=400.00, Ordering=24750.00)
# Episode 413/1000 | Tổng chi phí: 31194.55 (Holding=164.55, Backorder=2080.00, Ordering=24550.00)
# Episode 414/1000 | Tổng chi phí: 30904.03 (Holding=174.03, Backorder=1680.00, Ordering=25250.00)
# Episode 415/1000 | Tổng chi phí: 28031.23 (Holding=181.23, Backorder=600.00, Ordering=25050.00)
# Episode 416/1000 | Tổng chi phí: 31763.15 (Holding=163.15, Backorder=1700.00, Ordering=24700.00)
# Episode 417/1000 | Tổng chi phí: 33032.19 (Holding=162.19, Backorder=1720.00, Ordering=25750.00)
# Episode 418/1000 | Tổng chi phí: 31264.33 (Holding=154.33, Backorder=1460.00, Ordering=25250.00)
# Episode 419/1000 | Tổng chi phí: 28675.70 (Holding=175.70, Backorder=600.00, Ordering=24700.00)
# Episode 420/1000 | Tổng chi phí: 28638.55 (Holding=178.55, Backorder=760.00, Ordering=24900.00)
# Episode 421/1000 | Tổng chi phí: 32604.60 (Holding=164.60, Backorder=1840.00, Ordering=25600.00)
# Episode 422/1000 | Tổng chi phí: 41109.70 (Holding=149.70, Backorder=6760.00, Ordering=25200.00)
# Episode 423/1000 | Tổng chi phí: 29594.08 (Holding=174.08, Backorder=920.00, Ordering=25300.00)
# Episode 424/1000 | Tổng chi phí: 29790.68 (Holding=170.68, Backorder=1620.00, Ordering=24600.00)
# Episode 425/1000 | Tổng chi phí: 31884.36 (Holding=164.36, Backorder=1620.00, Ordering=25300.00)
# Episode 426/1000 | Tổng chi phí: 30370.05 (Holding=170.05, Backorder=1600.00, Ordering=24800.00)
# Episode 427/1000 | Tổng chi phí: 28670.96 (Holding=170.96, Backorder=1000.00, Ordering=25100.00)
# Episode 428/1000 | Tổng chi phí: 32214.77 (Holding=154.77, Backorder=1860.00, Ordering=25000.00)
# Episode 429/1000 | Tổng chi phí: 33660.60 (Holding=160.60, Backorder=2400.00, Ordering=25100.00)
# Episode 430/1000 | Tổng chi phí: 33320.08 (Holding=160.08, Backorder=2360.00, Ordering=24800.00)
# Episode 431/1000 | Tổng chi phí: 30227.34 (Holding=167.34, Backorder=1160.00, Ordering=24900.00)
# Episode 432/1000 | Tổng chi phí: 33219.18 (Holding=159.18, Backorder=1960.00, Ordering=25500.00)
# Episode 433/1000 | Tổng chi phí: 28398.27 (Holding=178.27, Backorder=820.00, Ordering=24400.00)
# Episode 434/1000 | Tổng chi phí: 30798.36 (Holding=168.36, Backorder=1180.00, Ordering=24650.00)
# Episode 435/1000 | Tổng chi phí: 28710.49 (Holding=170.49, Backorder=840.00, Ordering=24700.00)
# Episode 436/1000 | Tổng chi phí: 35747.42 (Holding=157.42, Backorder=3040.00, Ordering=24750.00)
# Episode 437/1000 | Tổng chi phí: 34692.27 (Holding=172.27, Backorder=2520.00, Ordering=25000.00)
# Episode 438/1000 | Tổng chi phí: 29476.68 (Holding=176.68, Backorder=900.00, Ordering=25200.00)
# Episode 439/1000 | Tổng chi phí: 32341.26 (Holding=171.26, Backorder=1820.00, Ordering=25150.00)
# Episode 440/1000 | Tổng chi phí: 33932.05 (Holding=162.05, Backorder=2620.00, Ordering=25150.00)
# Episode 441/1000 | Tổng chi phí: 37899.62 (Holding=149.62, Backorder=4400.00, Ordering=25550.00)
# Episode 442/1000 | Tổng chi phí: 30972.96 (Holding=172.96, Backorder=1500.00, Ordering=25100.00)
# Episode 443/1000 | Tổng chi phí: 30907.75 (Holding=167.75, Backorder=1440.00, Ordering=25100.00)
# Episode 444/1000 | Tổng chi phí: 33243.23 (Holding=163.23, Backorder=1880.00, Ordering=24600.00)
# Episode 445/1000 | Tổng chi phí: 34529.73 (Holding=169.73, Backorder=2260.00, Ordering=24900.00)
# Episode 446/1000 | Tổng chi phí: 30932.93 (Holding=172.93, Backorder=1260.00, Ordering=24900.00)
# Episode 447/1000 | Tổng chi phí: 33313.75 (Holding=153.75, Backorder=2260.00, Ordering=25300.00)
# Episode 448/1000 | Tổng chi phí: 34125.56 (Holding=155.56, Backorder=2420.00, Ordering=25550.00)
# Episode 449/1000 | Tổng chi phí: 30685.26 (Holding=165.26, Backorder=1320.00, Ordering=24800.00)
# Episode 450/1000 | Tổng chi phí: 30194.19 (Holding=184.19, Backorder=1160.00, Ordering=25250.00)
# Episode 451/1000 | Tổng chi phí: 39321.21 (Holding=151.21, Backorder=3720.00, Ordering=25250.00)
# Episode 452/1000 | Tổng chi phí: 32425.62 (Holding=175.62, Backorder=1800.00, Ordering=25050.00)
# Episode 453/1000 | Tổng chi phí: 33743.10 (Holding=153.10, Backorder=1840.00, Ordering=25150.00)
# Episode 454/1000 | Tổng chi phí: 31681.89 (Holding=171.89, Backorder=1560.00, Ordering=24950.00)
# Episode 455/1000 | Tổng chi phí: 27287.12 (Holding=177.12, Backorder=660.00, Ordering=24650.00)
# Episode 456/1000 | Tổng chi phí: 30181.26 (Holding=171.26, Backorder=1360.00, Ordering=25250.00)
# Episode 457/1000 | Tổng chi phí: 32915.42 (Holding=165.42, Backorder=1600.00, Ordering=25350.00)
# Episode 458/1000 | Tổng chi phí: 29217.56 (Holding=187.56, Backorder=780.00, Ordering=25050.00)
# Episode 459/1000 | Tổng chi phí: 28733.73 (Holding=193.73, Backorder=1040.00, Ordering=24700.00)
# Episode 460/1000 | Tổng chi phí: 32957.62 (Holding=177.62, Backorder=2380.00, Ordering=25400.00)
# Episode 461/1000 | Tổng chi phí: 32513.67 (Holding=163.67, Backorder=1900.00, Ordering=25050.00)
# Episode 462/1000 | Tổng chi phí: 36798.05 (Holding=148.05, Backorder=3700.00, Ordering=24950.00)
# Episode 463/1000 | Tổng chi phí: 28374.47 (Holding=184.47, Backorder=740.00, Ordering=25050.00)
# Episode 464/1000 | Tổng chi phí: 31280.11 (Holding=190.11, Backorder=1640.00, Ordering=25450.00)
# Episode 465/1000 | Tổng chi phí: 30367.53 (Holding=187.53, Backorder=980.00, Ordering=25200.00)
# Episode 466/1000 | Tổng chi phí: 32971.56 (Holding=161.56, Backorder=1860.00, Ordering=25550.00)
# Episode 467/1000 | Tổng chi phí: 30411.95 (Holding=171.95, Backorder=1340.00, Ordering=25500.00)
# Episode 468/1000 | Tổng chi phí: 33399.78 (Holding=159.78, Backorder=1940.00, Ordering=24900.00)
# Episode 469/1000 | Tổng chi phí: 30897.34 (Holding=167.34, Backorder=1180.00, Ordering=24950.00)
# Episode 470/1000 | Tổng chi phí: 29391.70 (Holding=181.70, Backorder=860.00, Ordering=25150.00)
# Episode 471/1000 | Tổng chi phí: 33192.71 (Holding=162.71, Backorder=2180.00, Ordering=25250.00)
# Episode 472/1000 | Tổng chi phí: 32777.86 (Holding=157.86, Backorder=2920.00, Ordering=25300.00)
# Episode 473/1000 | Tổng chi phí: 31544.47 (Holding=154.47, Backorder=1740.00, Ordering=25250.00)
# Episode 474/1000 | Tổng chi phí: 31940.33 (Holding=180.33, Backorder=1560.00, Ordering=25600.00)
# Episode 475/1000 | Tổng chi phí: 31148.71 (Holding=168.71, Backorder=1480.00, Ordering=25300.00)
# Episode 476/1000 | Tổng chi phí: 35930.22 (Holding=150.22, Backorder=2980.00, Ordering=25800.00)
# Episode 477/1000 | Tổng chi phí: 32050.30 (Holding=170.30, Backorder=1680.00, Ordering=25200.00)
# Episode 478/1000 | Tổng chi phí: 32500.77 (Holding=170.77, Backorder=1780.00, Ordering=25150.00)
# Episode 479/1000 | Tổng chi phí: 33129.34 (Holding=169.34, Backorder=1660.00, Ordering=25500.00)
# Episode 480/1000 | Tổng chi phí: 30312.68 (Holding=172.68, Backorder=940.00, Ordering=24800.00)
# Episode 481/1000 | Tổng chi phí: 29404.52 (Holding=174.52, Backorder=580.00, Ordering=24650.00)
# Episode 482/1000 | Tổng chi phí: 27768.08 (Holding=178.08, Backorder=840.00, Ordering=24750.00)
# Episode 483/1000 | Tổng chi phí: 35858.74 (Holding=138.74, Backorder=3120.00, Ordering=25400.00)
# Episode 484/1000 | Tổng chi phí: 34198.25 (Holding=158.25, Backorder=2340.00, Ordering=24900.00)
# Episode 485/1000 | Tổng chi phí: 28372.00 (Holding=182.00, Backorder=740.00, Ordering=25050.00)
# Episode 486/1000 | Tổng chi phí: 29199.62 (Holding=169.62, Backorder=880.00, Ordering=24750.00)
# Episode 487/1000 | Tổng chi phí: 30218.49 (Holding=178.49, Backorder=1340.00, Ordering=24900.00)
# Episode 488/1000 | Tổng chi phí: 32627.48 (Holding=167.48, Backorder=2060.00, Ordering=25200.00)
# Episode 489/1000 | Tổng chi phí: 33281.97 (Holding=171.97, Backorder=2660.00, Ordering=25050.00)
# Episode 490/1000 | Tổng chi phí: 35202.60 (Holding=152.60, Backorder=2500.00, Ordering=25150.00)
# Episode 491/1000 | Tổng chi phí: 33118.77 (Holding=168.77, Backorder=3000.00, Ordering=25350.00)
# Episode 492/1000 | Tổng chi phí: 29875.04 (Holding=165.04, Backorder=1160.00, Ordering=24950.00)
# Episode 493/1000 | Tổng chi phí: 30041.67 (Holding=171.67, Backorder=1620.00, Ordering=24650.00)
# Episode 494/1000 | Tổng chi phí: 29836.22 (Holding=176.22, Backorder=1160.00, Ordering=24900.00)
# Episode 495/1000 | Tổng chi phí: 30211.78 (Holding=181.78, Backorder=880.00, Ordering=25150.00)
# Episode 496/1000 | Tổng chi phí: 31170.49 (Holding=170.49, Backorder=1500.00, Ordering=24900.00)
# ...
# Episode 837/1000 | Tổng chi phí: 31790.85 (Holding=170.85, Backorder=1920.00, Ordering=24900.00)
# Episode 838/1000 | Tổng chi phí: 30743.81 (Holding=173.81, Backorder=1320.00, Ordering=24650.00)
# Episode 839/1000 | Tổng chi phí: 32831.73 (Holding=161.73, Backorder=2120.00, Ordering=24950.00)
# Episode 840/1000 | Tổng chi phí: 39319.92 (Holding=139.92, Backorder=3580.00, Ordering=24800.00)
# Episode 841/1000 | Tổng chi phí: 36029.92 (Holding=139.92, Backorder=2840.00, Ordering=25250.00)
# Episode 842/1000 | Tổng chi phí: 34032.14 (Holding=152.14, Backorder=2480.00, Ordering=25200.00)
# Episode 843/1000 | Tổng chi phí: 34199.26 (Holding=159.26, Backorder=2340.00, Ordering=25300.00)
# Episode 844/1000 | Tổng chi phí: 32255.18 (Holding=175.18, Backorder=1980.00, Ordering=24500.00)
# Episode 845/1000 | Tổng chi phí: 31420.44 (Holding=170.44, Backorder=1500.00, Ordering=25150.00)
# Episode 846/1000 | Tổng chi phí: 32340.05 (Holding=160.05, Backorder=1980.00, Ordering=24600.00)
# Episode 847/1000 | Tổng chi phí: 30441.97 (Holding=161.97, Backorder=880.00, Ordering=25400.00)
# Episode 848/1000 | Tổng chi phí: 33601.67 (Holding=161.67, Backorder=2440.00, Ordering=25000.00)
# Episode 849/1000 | Tổng chi phí: 34178.90 (Holding=148.90, Backorder=2380.00, Ordering=25050.00)
# Episode 850/1000 | Tổng chi phí: 35078.14 (Holding=158.14, Backorder=2920.00, Ordering=25200.00)
# Episode 851/1000 | Tổng chi phí: 31054.79 (Holding=174.79, Backorder=1280.00, Ordering=24600.00)
# Episode 852/1000 | Tổng chi phí: 28976.96 (Holding=166.96, Backorder=1160.00, Ordering=24850.00)
# Episode 853/1000 | Tổng chi phí: 34011.78 (Holding=151.78, Backorder=1960.00, Ordering=25500.00)
# Episode 854/1000 | Tổng chi phí: 33004.16 (Holding=164.16, Backorder=1940.00, Ordering=25300.00)
# Episode 855/1000 | Tổng chi phí: 29258.38 (Holding=178.38, Backorder=880.00, Ordering=24800.00)
# Episode 856/1000 | Tổng chi phí: 29821.04 (Holding=181.04, Backorder=940.00, Ordering=25300.00)
# Episode 857/1000 | Tổng chi phí: 32103.48 (Holding=173.48, Backorder=1580.00, Ordering=25150.00)
# Episode 858/1000 | Tổng chi phí: 32538.11 (Holding=168.11, Backorder=1520.00, Ordering=25050.00)
# Episode 859/1000 | Tổng chi phí: 30767.86 (Holding=167.86, Backorder=1200.00, Ordering=25200.00)
# Episode 860/1000 | Tổng chi phí: 29969.81 (Holding=179.81, Backorder=1240.00, Ordering=24750.00)
# Episode 861/1000 | Tổng chi phí: 29732.96 (Holding=162.96, Backorder=1420.00, Ordering=24750.00)
# Episode 862/1000 | Tổng chi phí: 33503.01 (Holding=163.01, Backorder=2040.00, Ordering=24700.00)
# Episode 863/1000 | Tổng chi phí: 28535.86 (Holding=175.86, Backorder=760.00, Ordering=25200.00)
# Episode 864/1000 | Tổng chi phí: 30044.99 (Holding=174.99, Backorder=1420.00, Ordering=24850.00)
# Episode 865/1000 | Tổng chi phí: 31135.40 (Holding=165.40, Backorder=1620.00, Ordering=25350.00)
# Episode 866/1000 | Tổng chi phí: 33050.85 (Holding=170.85, Backorder=1780.00, Ordering=25100.00)
# Episode 867/1000 | Tổng chi phí: 34710.41 (Holding=160.41, Backorder=2500.00, Ordering=24850.00)
# Episode 868/1000 | Tổng chi phí: 31101.42 (Holding=171.42, Backorder=1580.00, Ordering=25150.00)
# Episode 869/1000 | Tổng chi phí: 38286.71 (Holding=156.71, Backorder=4280.00, Ordering=24850.00)
# Episode 870/1000 | Tổng chi phí: 29226.00 (Holding=186.00, Backorder=1140.00, Ordering=24900.00)
# Episode 871/1000 | Tổng chi phí: 32317.04 (Holding=167.04, Backorder=1900.00, Ordering=24650.00)
# Episode 872/1000 | Tổng chi phí: 31809.84 (Holding=159.84, Backorder=1700.00, Ordering=24950.00)
# Episode 873/1000 | Tổng chi phí: 30643.10 (Holding=163.10, Backorder=1480.00, Ordering=25400.00)
# Episode 874/1000 | Tổng chi phí: 34270.08 (Holding=170.08, Backorder=2200.00, Ordering=25100.00)
# Episode 875/1000 | Tổng chi phí: 29198.03 (Holding=178.03, Backorder=920.00, Ordering=25100.00)
# Episode 876/1000 | Tổng chi phí: 31320.44 (Holding=160.44, Backorder=1360.00, Ordering=25200.00)
# Episode 877/1000 | Tổng chi phí: 29019.45 (Holding=179.45, Backorder=840.00, Ordering=25000.00)
# Episode 878/1000 | Tổng chi phí: 29937.92 (Holding=167.92, Backorder=1020.00, Ordering=25150.00)
# Episode 879/1000 | Tổng chi phí: 28724.90 (Holding=174.90, Backorder=700.00, Ordering=24850.00)
# Episode 880/1000 | Tổng chi phí: 30522.85 (Holding=172.85, Backorder=1400.00, Ordering=25150.00)
# Episode 881/1000 | Tổng chi phí: 31030.49 (Holding=190.49, Backorder=1240.00, Ordering=25000.00)
# Episode 882/1000 | Tổng chi phí: 26934.93 (Holding=194.93, Backorder=540.00, Ordering=25000.00)
# Episode 883/1000 | Tổng chi phí: 28529.12 (Holding=169.12, Backorder=860.00, Ordering=24700.00)
# Episode 884/1000 | Tổng chi phí: 32004.19 (Holding=164.19, Backorder=1540.00, Ordering=25300.00)
# Episode 885/1000 | Tổng chi phí: 35853.34 (Holding=143.34, Backorder=3260.00, Ordering=25250.00)
# Episode 886/1000 | Tổng chi phí: 31777.10 (Holding=167.10, Backorder=2060.00, Ordering=24750.00)
# Episode 887/1000 | Tổng chi phí: 34942.58 (Holding=152.58, Backorder=2740.00, Ordering=24850.00)
# Episode 888/1000 | Tổng chi phí: 29289.89 (Holding=179.89, Backorder=1060.00, Ordering=25250.00)
# Episode 889/1000 | Tổng chi phí: 30868.11 (Holding=158.11, Backorder=1760.00, Ordering=24550.00)
# Episode 890/1000 | Tổng chi phí: 36899.84 (Holding=149.84, Backorder=3300.00, Ordering=25450.00)
# Episode 891/1000 | Tổng chi phí: 29933.15 (Holding=183.15, Backorder=800.00, Ordering=24950.00)
# Episode 892/1000 | Tổng chi phí: 33836.68 (Holding=156.68, Backorder=1980.00, Ordering=25100.00)
# Episode 893/1000 | Tổng chi phí: 30051.18 (Holding=171.18, Backorder=1180.00, Ordering=25300.00)
# Episode 894/1000 | Tổng chi phí: 31712.00 (Holding=162.00, Backorder=1300.00, Ordering=25050.00)
# Episode 895/1000 | Tổng chi phí: 34639.75 (Holding=159.75, Backorder=2480.00, Ordering=25000.00)
# Episode 896/1000 | Tổng chi phí: 34405.37 (Holding=165.37, Backorder=2240.00, Ordering=24600.00)
# Episode 897/1000 | Tổng chi phí: 28519.92 (Holding=179.92, Backorder=1040.00, Ordering=25100.00)
# Episode 898/1000 | Tổng chi phí: 31929.01 (Holding=169.01, Backorder=1860.00, Ordering=25100.00)
# Episode 899/1000 | Tổng chi phí: 30375.59 (Holding=175.59, Backorder=1100.00, Ordering=25300.00)
# Episode 900/1000 | Tổng chi phí: 27470.41 (Holding=200.41, Backorder=620.00, Ordering=25050.00)
# Episode 901/1000 | Tổng chi phí: 31089.70 (Holding=159.70, Backorder=1380.00, Ordering=24950.00)
# Episode 902/1000 | Tổng chi phí: 31718.82 (Holding=158.82, Backorder=1460.00, Ordering=25300.00)
# Episode 903/1000 | Tổng chi phí: 30105.81 (Holding=175.81, Backorder=1280.00, Ordering=25050.00)
# Episode 904/1000 | Tổng chi phí: 34541.81 (Holding=151.81, Backorder=2340.00, Ordering=25250.00)
# Episode 905/1000 | Tổng chi phí: 29656.52 (Holding=186.52, Backorder=1120.00, Ordering=25150.00)
# Episode 906/1000 | Tổng chi phí: 33564.85 (Holding=154.85, Backorder=2460.00, Ordering=24950.00)
# Episode 907/1000 | Tổng chi phí: 28751.92 (Holding=171.92, Backorder=780.00, Ordering=24800.00)
# Episode 908/1000 | Tổng chi phí: 32854.25 (Holding=164.25, Backorder=1640.00, Ordering=25050.00)
# Episode 909/1000 | Tổng chi phí: 30833.86 (Holding=183.86, Backorder=1500.00, Ordering=25150.00)
# Episode 910/1000 | Tổng chi phí: 32517.59 (Holding=167.59, Backorder=2100.00, Ordering=25050.00)
# Episode 911/1000 | Tổng chi phí: 31111.21 (Holding=171.21, Backorder=1440.00, Ordering=25100.00)
# Episode 912/1000 | Tổng chi phí: 31406.85 (Holding=186.85, Backorder=1420.00, Ordering=25400.00)
# Episode 913/1000 | Tổng chi phí: 31289.15 (Holding=179.15, Backorder=1360.00, Ordering=24950.00)
# Episode 914/1000 | Tổng chi phí: 31435.48 (Holding=155.48, Backorder=1680.00, Ordering=25200.00)
# Episode 915/1000 | Tổng chi phí: 30381.59 (Holding=171.59, Backorder=1260.00, Ordering=24950.00)
# Episode 916/1000 | Tổng chi phí: 31640.79 (Holding=160.79, Backorder=1680.00, Ordering=24800.00)
# Episode 917/1000 | Tổng chi phí: 36231.97 (Holding=151.97, Backorder=3080.00, Ordering=25400.00)
# Episode 918/1000 | Tổng chi phí: 31214.63 (Holding=154.63, Backorder=1560.00, Ordering=25300.00)
# Episode 919/1000 | Tổng chi phí: 32002.11 (Holding=172.11, Backorder=2480.00, Ordering=25150.00)
# Episode 920/1000 | Tổng chi phí: 31486.93 (Holding=176.93, Backorder=1860.00, Ordering=24650.00)
# Episode 921/1000 | Tổng chi phí: 31167.89 (Holding=167.89, Backorder=1200.00, Ordering=25400.00)
# Episode 922/1000 | Tổng chi phí: 30555.56 (Holding=165.56, Backorder=1340.00, Ordering=24650.00)
# Episode 923/1000 | Tổng chi phí: 29653.75 (Holding=173.75, Backorder=1080.00, Ordering=25200.00)
# Episode 924/1000 | Tổng chi phí: 30490.27 (Holding=170.27, Backorder=1120.00, Ordering=25400.00)
# Episode 925/1000 | Tổng chi phí: 33982.14 (Holding=162.14, Backorder=2420.00, Ordering=24800.00)
# Episode 926/1000 | Tổng chi phí: 34314.38 (Holding=164.38, Backorder=2600.00, Ordering=25350.00)
# Episode 927/1000 | Tổng chi phí: 32324.63 (Holding=154.63, Backorder=2220.00, Ordering=25150.00)
# Episode 928/1000 | Tổng chi phí: 30146.41 (Holding=166.41, Backorder=1480.00, Ordering=24900.00)
# Episode 929/1000 | Tổng chi phí: 32764.82 (Holding=154.82, Backorder=1960.00, Ordering=25250.00)
# Episode 930/1000 | Tổng chi phí: 31656.41 (Holding=156.41, Backorder=1500.00, Ordering=25000.00)
# Episode 931/1000 | Tổng chi phí: 29994.99 (Holding=194.99, Backorder=900.00, Ordering=25100.00)
# Episode 932/1000 | Tổng chi phí: 31305.07 (Holding=155.07, Backorder=1800.00, Ordering=24950.00)
# Episode 933/1000 | Tổng chi phí: 33406.52 (Holding=156.52, Backorder=2300.00, Ordering=24750.00)
# Episode 934/1000 | Tổng chi phí: 34239.23 (Holding=169.23, Backorder=2320.00, Ordering=24550.00)
# Episode 935/1000 | Tổng chi phí: 29461.26 (Holding=171.26, Backorder=1040.00, Ordering=25050.00)
# Episode 936/1000 | Tổng chi phí: 31852.79 (Holding=162.79, Backorder=1540.00, Ordering=24750.00)
# Episode 937/1000 | Tổng chi phí: 30906.77 (Holding=176.77, Backorder=1580.00, Ordering=25550.00)
# Episode 938/1000 | Tổng chi phí: 30701.64 (Holding=191.64, Backorder=1560.00, Ordering=25350.00)
# Episode 939/1000 | Tổng chi phí: 28677.89 (Holding=177.89, Backorder=900.00, Ordering=24400.00)
# Episode 940/1000 | Tổng chi phí: 28830.03 (Holding=190.03, Backorder=840.00, Ordering=24800.00)
# Episode 941/1000 | Tổng chi phí: 32938.93 (Holding=168.93, Backorder=2320.00, Ordering=25450.00)
# Episode 942/1000 | Tổng chi phí: 32370.03 (Holding=160.03, Backorder=1760.00, Ordering=25250.00)
# Episode 943/1000 | Tổng chi phí: 33610.25 (Holding=160.25, Backorder=2300.00, Ordering=24950.00)
# Episode 944/1000 | Tổng chi phí: 32337.62 (Holding=167.62, Backorder=2020.00, Ordering=25150.00)
# Episode 945/1000 | Tổng chi phí: 32961.23 (Holding=171.23, Backorder=1740.00, Ordering=25050.00)
# Episode 946/1000 | Tổng chi phí: 31376.11 (Holding=176.11, Backorder=1700.00, Ordering=24500.00)
# Episode 947/1000 | Tổng chi phí: 33860.05 (Holding=170.05, Backorder=2740.00, Ordering=24950.00)
# Episode 948/1000 | Tổng chi phí: 32775.95 (Holding=165.95, Backorder=1660.00, Ordering=25150.00)
# Episode 949/1000 | Tổng chi phí: 39135.26 (Holding=135.26, Backorder=3600.00, Ordering=25400.00)
# Episode 950/1000 | Tổng chi phí: 29622.38 (Holding=192.38, Backorder=1080.00, Ordering=24750.00)
# Episode 951/1000 | Tổng chi phí: 27607.23 (Holding=197.23, Backorder=560.00, Ordering=25050.00)
# Episode 952/1000 | Tổng chi phí: 29884.22 (Holding=184.22, Backorder=1200.00, Ordering=24900.00)
# Episode 953/1000 | Tổng chi phí: 31531.01 (Holding=161.01, Backorder=1420.00, Ordering=24950.00)
# Episode 954/1000 | Tổng chi phí: 30024.03 (Holding=164.03, Backorder=1560.00, Ordering=24700.00)
# Episode 955/1000 | Tổng chi phí: 34445.23 (Holding=145.23, Backorder=2300.00, Ordering=24800.00)
# Episode 956/1000 | Tổng chi phí: 33779.01 (Holding=169.01, Backorder=3060.00, Ordering=24750.00)
# Episode 957/1000 | Tổng chi phí: 33819.21 (Holding=159.21, Backorder=2360.00, Ordering=25300.00)
# Episode 958/1000 | Tổng chi phí: 34302.55 (Holding=152.55, Backorder=2300.00, Ordering=25450.00)
# Episode 959/1000 | Tổng chi phí: 32800.68 (Holding=150.68, Backorder=1600.00, Ordering=25650.00)
# Episode 960/1000 | Tổng chi phí: 30933.32 (Holding=163.32, Backorder=1420.00, Ordering=24950.00)
# Episode 961/1000 | Tổng chi phí: 28941.07 (Holding=171.07, Backorder=720.00, Ordering=25050.00)
# Episode 962/1000 | Tổng chi phí: 32021.23 (Holding=161.23, Backorder=1660.00, Ordering=24600.00)
# Episode 963/1000 | Tổng chi phí: 32687.56 (Holding=157.56, Backorder=2180.00, Ordering=24950.00)
# Episode 964/1000 | Tổng chi phí: 28135.53 (Holding=175.53, Backorder=760.00, Ordering=25000.00)
# Episode 965/1000 | Tổng chi phí: 30994.22 (Holding=154.22, Backorder=1640.00, Ordering=24800.00)
# Episode 966/1000 | Tổng chi phí: 32976.55 (Holding=156.55, Backorder=2220.00, Ordering=24800.00)
# Episode 967/1000 | Tổng chi phí: 31408.25 (Holding=178.25, Backorder=1380.00, Ordering=25050.00)
# Episode 968/1000 | Tổng chi phí: 29958.22 (Holding=168.22, Backorder=1340.00, Ordering=24850.00)
# Episode 969/1000 | Tổng chi phí: 32386.55 (Holding=166.55, Backorder=1720.00, Ordering=25500.00)
# Episode 970/1000 | Tổng chi phí: 34712.49 (Holding=142.49, Backorder=2420.00, Ordering=25150.00)
# Episode 971/1000 | Tổng chi phí: 32678.36 (Holding=158.36, Backorder=2320.00, Ordering=25000.00)
# Episode 972/1000 | Tổng chi phí: 32442.30 (Holding=162.30, Backorder=2080.00, Ordering=25200.00)
# Episode 973/1000 | Tổng chi phí: 31881.32 (Holding=181.32, Backorder=1600.00, Ordering=25100.00)
# Episode 974/1000 | Tổng chi phí: 28718.49 (Holding=168.49, Backorder=800.00, Ordering=24750.00)
# Episode 975/1000 | Tổng chi phí: 32593.12 (Holding=163.12, Backorder=2280.00, Ordering=25550.00)
# Episode 976/1000 | Tổng chi phí: 29170.16 (Holding=170.16, Backorder=1100.00, Ordering=25100.00)
# Episode 977/1000 | Tổng chi phí: 34524.82 (Holding=154.82, Backorder=2420.00, Ordering=24750.00)
# Episode 978/1000 | Tổng chi phí: 28931.07 (Holding=171.07, Backorder=860.00, Ordering=24500.00)
# Episode 979/1000 | Tổng chi phí: 31840.05 (Holding=160.05, Backorder=2180.00, Ordering=25100.00)
# Episode 980/1000 | Tổng chi phí: 30463.59 (Holding=183.59, Backorder=1480.00, Ordering=25400.00)
# Episode 981/1000 | Tổng chi phí: 30804.25 (Holding=174.25, Backorder=1280.00, Ordering=25350.00)
# Episode 982/1000 | Tổng chi phí: 29477.92 (Holding=177.92, Backorder=1000.00, Ordering=25100.00)
# Episode 983/1000 | Tổng chi phí: 27316.22 (Holding=186.22, Backorder=380.00, Ordering=24950.00)
# Episode 984/1000 | Tổng chi phí: 36315.95 (Holding=135.95, Backorder=3180.00, Ordering=25000.00)
# Episode 985/1000 | Tổng chi phí: 32357.04 (Holding=177.04, Backorder=2180.00, Ordering=25400.00)
# Episode 986/1000 | Tổng chi phí: 29061.45 (Holding=201.45, Backorder=760.00, Ordering=25300.00)
# Episode 987/1000 | Tổng chi phí: 27918.11 (Holding=178.11, Backorder=640.00, Ordering=25100.00)
# Episode 988/1000 | Tổng chi phí: 36012.27 (Holding=162.27, Backorder=2600.00, Ordering=25450.00)
# Episode 989/1000 | Tổng chi phí: 34080.60 (Holding=170.60, Backorder=2160.00, Ordering=25150.00)
# Episode 990/1000 | Tổng chi phí: 29187.07 (Holding=167.07, Backorder=1120.00, Ordering=25300.00)
# Episode 991/1000 | Tổng chi phí: 36065.21 (Holding=155.21, Backorder=3060.00, Ordering=25450.00)
# Episode 992/1000 | Tổng chi phí: 31510.58 (Holding=180.58, Backorder=1980.00, Ordering=24750.00)
# Episode 993/1000 | Tổng chi phí: 28584.66 (Holding=194.66, Backorder=740.00, Ordering=25050.00)
# Episode 994/1000 | Tổng chi phí: 30600.19 (Holding=170.19, Backorder=1380.00, Ordering=24850.00)
# Episode 995/1000 | Tổng chi phí: 34298.47 (Holding=158.47, Backorder=2540.00, Ordering=25200.00)
# Episode 996/1000 | Tổng chi phí: 30581.34 (Holding=161.34, Backorder=1020.00, Ordering=25600.00)
# Episode 997/1000 | Tổng chi phí: 28494.49 (Holding=164.49, Backorder=1180.00, Ordering=25150.00)
# Episode 998/1000 | Tổng chi phí: 31785.86 (Holding=165.86, Backorder=1820.00, Ordering=24600.00)
# Episode 999/1000 | Tổng chi phí: 32661.37 (Holding=161.37, Backorder=2300.00, Ordering=24800.00)
# Episode 1000/1000 | Tổng chi phí: 32917.29 (Holding=157.29, Backorder=2060.00, Ordering=25300.00)
#
# ✅ Huấn luyện hoàn tất.

# %%
# Lấy chỉ số hành động tốt nhất cho mỗi trạng thái
policy_idx = np.argmax(Q, axis=1)

# Chuyển sang hành động thực (0/1) và ánh xạ về giá trị inventory position
policy_actions = [actions[i] for i in policy_idx]
policy_map = dict(zip(states, policy_actions))  # {inventory_position: best_action}

# Hiển thị dưới dạng DataFrame (tuỳ chọn)
import pandas as pd
policy_df = pd.DataFrame({
    'ip': states,
    'best_action_idx': policy_idx,
    'best_action': policy_actions,
    'Q0': Q[:,0],
    'Q1': Q[:,1],
})
policy_df.head()
# Out:
#    ip  best_action_idx  best_action           Q0           Q1
# 0 -20                1            1 -3263.610957 -1484.173189
# 1 -19                0            0 -1023.675878 -1178.505941
# 2 -18                1            1 -1243.630403 -1220.707005
# 3 -17                1            1 -1202.819543 -1129.344101
# 4 -16                1            1  -939.921290  -931.486508

# %%
# ...existing code...
policy_df.head()

# định nghĩa policy để hàm learned_policy có thể sử dụng
policy = policy_actions
# ...existing code...

# %%
# Mô phỏng đánh giá chính sách
def learned_policy(ip):
    """Chính sách do mô hình học được."""
    return int(policy[ip_to_index(ip)])


def rq_policy(ip):
    """Chính sách (r,q) truyền thống."""
    return 1 if ip <= r else 0


def evaluate(policy_func, days=365 * 5, seed=42):
    """Mô phỏng thực tế trong nhiều ngày để tính chi phí trung bình/ngày."""
    np.random.seed(seed)
    total_cost = 0
    ip = r
    orders_in_transit = 0
    for day in range(days):
        a = policy_func(ip)
        next_ip, _, orders_in_transit, cost = step(ip, orders_in_transit, a)
        ip = next_ip
        total_cost += cost
    return total_cost / days

# %%
# Đánh giá chính sách học được
learned_cost = evaluate(learned_policy)
rq_cost = evaluate(rq_policy)
reduction = (rq_cost - learned_cost) / rq_cost * 100

print(f"\n📊 Kết quả so sánh:")
print(f" - Chính sách học được: {learned_cost:.2f} €/ngày")
print(f" - Chính sách (r,q) truyền thống: {rq_cost:.2f} €/ngày")
print(f" - Tỷ lệ cải thiện: {reduction:.2f}%")
# Out:
# 📊 Kết quả so sánh:
#  - Chính sách học được: 28.43 €/ngày
#  - Chính sách (r,q) truyền thống: 52.52 €/ngày
#  - Tỷ lệ cải thiện: 45.87%

# %%
# Hiển thị chính sách học được
policy_df = pd.DataFrame({
    "inventory_position": states,
    "action (0=no order,1=order)": policy
})

print("\n🔎 Một phần của chính sách học được:")
print(policy_df)
# Out:
# 🔎 Một phần của chính sách học được:
#     inventory_position  action (0=no order,1=order)
# 0                  -20                            1
# 1                  -19                            0
# 2                  -18                            1
# 3                  -17                            1
# 4                  -16                            1
# 5                  -15                            1
# 6                  -14                            0
# 7                  -13                            1
# 8                  -12                            1
# 9                  -11                            1
# 10                 -10                            1
# 11                  -9                            1
# 12                  -8                            1
# 13                  -7                            1
# 14                  -6                            1
# 15                  -5                            1
# 16                  -4                            1
# 17                  -3                            1
# 18                  -2                            1
# 19                  -1                            1
# 20                   0                            1
# 21                   1                            1
# 22                   2                            0
# 23                   3                            1
# 24                   4                            1
# 25                   5                            1
# 26                   6                            1
# 27                   7                            0
# 28                   8                            0
# 29                   9                            0
# 30                  10                            0
# 31                  11                            0
# 32                  12                            0
# 33                  13                            0
# 34                  14                            0
# 35                  15                            0
# 36                  16                            0
# 37                  17                            0
# 38                  18                            0
# 39                  19                            0
# 40                  20                            0

# %%
# ===============================================================
# 🔟 Mô phỏng 30 ngày – đầy đủ các biến để quan sát (giống bài báo)
# ===============================================================
np.random.seed(123)
days = np.arange(1, 31)  # mô phỏng 30 ngày
ip = r
orders_in_transit = 0
records = []

for day in days:
    a = learned_policy(ip)   # hành động theo chính sách đã học
    d = sample_demand()      # nhu cầu ngẫu nhiên mỗi ngày
    arrivals = 0

    # Nếu hôm nay có hàng về (lead time = 1)
    if orders_in_transit > 0:
        arrivals = orders_in_transit
        orders_in_transit = 0

    inventory_before = ip
    ip_after = ip + arrivals - d

    # Nếu hôm nay đặt hàng, hàng sẽ đến ngày sau
    if a == 1:
        orders_in_transit = q

    # 🔹 Tính chi phí hằng ngày
    holding_cost = h * max(ip_after, 0)
    backorder_cost = b * max(-ip_after, 0)
    ordering_cost = O if a == 1 else 0
    total_cost = holding_cost + backorder_cost + ordering_cost

    # Ghi lại dữ liệu từng ngày
    records.append({
        "day": day,
        "demand": d,
        "inventory_before": inventory_before,
        "order_action": a,
        "arrivals_today": arrivals,
        "inventory_after": ip_after,
        "daily_cost": total_cost
    })

    ip = ip_after

# 🔸 Tạo DataFrame kết quả
df_sim = pd.DataFrame(records)
print("\n📅 Dữ liệu mô phỏng 30 ngày đầu:")
print(df_sim.to_string(index=False))
# Out:
# 📅 Dữ liệu mô phỏng 30 ngày đầu:
#  day  demand  inventory_before  order_action  arrivals_today  inventory_after  daily_cost
#    1       2                 3             1               0                1   50.027397
#    2       4                 1             1               6                3   50.082192
#    3       3                 3             1               6                6   50.164384
#    4       1                 6             1               6               11   50.301370
#    5       2                11             0               6               15    0.410959
#    6       5                15             0               0               10    0.273973
#    7       1                10             0               0                9    0.246575
#    8       3                 9             0               0                6    0.164384
#    9       4                 6             1               0                2   50.054795
#   10       2                 2             0               6                6    0.164384
#   11       2                 6             1               0                4   50.109589
#   12       3                 4             1               6                7   50.191781
#   13       4                 7             0               6                9    0.246575
#   14       2                 9             0               0                7    0.191781
#   15       3                 7             0               0                4    0.109589
#   16       3                 4             1               0                1   50.027397
#   17       5                 1             1               6                2   50.054795
#   18       5                 2             0               6                3    0.082192
#   19       4                 3             1               0               -1   70.000000
#   20       3                -1             1               6                2   50.054795
#   21       4                 2             0               6                4    0.109589
#   22       4                 4             1               0                0   50.000000
#   23       2                 0             1               6                4   50.109589
#   24       4                 4             1               6                6   50.164384
#   25       2                 6             1               6               10   50.273973
#   26       2                10             0               6               14    0.383562
#   27       4                14             0               0               10    0.273973
#   28       2                10             0               0                8    0.219178
#   29       3                 8             0               0                5    0.136986
#   30       2                 5             1               0                3   50.082192
